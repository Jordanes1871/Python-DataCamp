# %% [markdown]
# # Intermediate - Importing Data into Python

# %% [markdown]
# ### 1. Importing flat files from the web

# %% [markdown]
# You are about to import your first file from the web! The flat file you will import will be 'winequality-red.csv' from the University of California, Irvine's Machine Learning repository. The flat file contains tabular data of physiochemical properties of red wine, such as pH, alcohol content and citric acid content, along with wine quality rating.
#
# The URL of the file is
#
# 'https://assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'
#
# After you import it, you'll check your working directory to confirm that it is there and then you'll load it into a pandas DataFrame.

# %%
#import package
from urllib.request import urlretrieve 

#import pandas
import pandas as pd

#assign url of file: url
url = 'https://assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'

#save file locally
urlretrieve(url, 'winequality-red.csv')

#read file into a DataFrame and print its head
df = pd.read_csv('winequality-red.csv', sep = ';')
print(df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Opening and reading flat files from the web

# %% [markdown]
# You have just imported a file from the web, saved it locally and loaded it into a DataFrame. If you just wanted to load a file from the web into a DataFrame without first saving it locally, you can do that easily using pandas. In particular, you can use the function pd.read_csv() with the URL as the first argument and the separator sep as the second argument.

# %%
#import packages
import matplotlib.pyplot as plt
import pandas as pd

#assign url of file: url
url = 'https://assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'

#read file into DataFrame: df
df = pd.read_csv(url, sep = ';') #without saving file locally parse in the url variable

#print head of DataFrame
print(df.head())

# Plot first column of df
df.iloc[:, 0].hist()
plt.xlabel('fixed acidity (g(tartaric acid)/dm$^3$)')
plt.ylabel('count')
plt.show()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Importing non-flat files from the web

# %% [markdown]
# In this interactive exercise, you'll use pd.read_excel() to import an Excel spreadsheet.
# Your job is to use pd.read_excel() to read in all of its sheets, print the sheet names and then print the head of the first sheet using its name, not its index.
#
# Note that the output of pd.read_excel() is a Python dictionary with sheet names as keys and corresponding DataFrames as corresponding values.

# %%
#import packag
import pandas as pd
import xlrd

#assign url of file: url
url = 'https://assets.datacamp.com/course/importing_data_into_r/latitude.xls'

#read in all of the sheets of excel file: xls
xls = pd.read_excel(url, 
                    sheet_name = None)

#print the sheetnames to the shell
print(xls.keys())

# Print the head of the first sheet (using its name, NOT its index)
print(xls['1700'].head())
# Out:
# dict_keys(['1700', '1900'])
#                  country       1700
# 0            Afghanistan  34.565000
# 1  Akrotiri and Dhekelia  34.616667
# 2                Albania  41.312000
# 3                Algeria  36.720000
# 4         American Samoa -14.307000

# %% [markdown]
# URL
#
# Stands for uniform/universal resource locator
#
# References to web resources
#
# focus: web address
#
# Ingredients
#
#     protocal identifier - https (hypertext transfer protocol
#
#     resource name - datacamp.com
#
# http - foundation of data communication for the web
#
# going to a website = sending http request this is known as a GET request
#
# We can get HTML data from a webpage
#
# HTML = hyper text markup language

# %% [markdown]
# ### Performing HTTP requests in Python using urllib

# %% [markdown]
# In this interactive exercise, you will ping our very own DataCamp servers to perform a GET request to extract information from the first coding exercise of this course, "https://campus.datacamp.com/courses/1606/4135?ex=2"

# %%
#Import packages
from urllib.request import urlopen, Request

# Specify the url
url = "https://campus.datacamp.com/courses/1606/4135?ex=2"

# This packages the request: request
request = Request(url) #sending GET request to url link

# Sends the request and catches the response: response
response = urlopen(request)

# Print the datatype of response
print(type(response))

# Be polite and close the response!
response.close()
# Out:
# <class 'http.client.HTTPResponse'>

# %% [markdown]
# ### Printing HTTP request results in Python using urllib

# %% [markdown]
# You have just packaged and sent a GET request to "https://campus.datacamp.com/courses/1606/4135?ex=2" and then caught the response. You saw that such a response is a http.client.HTTPResponse object. The question remains: what can you do with this response?
#
# Well, as it came from an HTML page, you could read it to extract the HTML and, in fact, such a http.client.HTTPResponse object has an associated read() method. In this exercise, you'll build on your previous great work to extract the response and print the HTML.

# %%
#import packages
from urllib.request import Request, urlopen

# Specify the url
url = "https://campus.datacamp.com/courses/1606/4135?ex=2"

# This packages the request
request = Request(url)

# Sends the request and catches the response: response
response = urlopen(request)

# Extract the response: html
html = response.read()

# Print the html
print(html)

# Be polite and close the response!
response.close()
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><title>Importing flat files from the web: your turn! | Python</title><meta content="Here is an example of Importing flat files from the web: your turn!: You are about to import your first file from the web! The flat file you will import will be &#x27;winequality-red" name="description"/><link href="https://campus.datacamp.com/courses/intermediate-importing-data-in-python/importing-data-from-the-internet-1?ex=2" rel="canonical"/><link href="https://campus.datacamp.com/courses/intermediate-importing-data-in-python/importing-data-from-the-internet-1?ex=2" hrefLang="x-default" rel="alternate"/><link href="https://campus.datacamp.com/courses/intermediate-importing-data-in-python/importing-data-from-the-internet-1?ex=2" hrefLang="en" rel="alternate"/><link href="https://campus.datacamp.com/es/courses/intermediate-importing-data-in-python/importing-data-from-the-internet-1?ex=2" hrefLang="es" rel="alternate"/><link href="https://campus.datacamp.com/pt/courses/intermediate-importing-data-in-python/importing-data-from-the-internet-1?ex=2" hrefLang="pt" rel="alternate"/><link href="https://campus.datacamp.com/de/courses/intermediate-importing-data-in-python/importing-data-from-the-internet-1?ex=2" hrefLang="de" rel="alternate"/><link href="https://campus.datacamp.com/fr/courses/intermediate-importing-data-in-python/importing-data-from-the-internet-1?ex=2" hrefLang="fr" rel="alternate"/><script type="application/ld+json">{&quot;@context&quot;:&quot;https://schema.org&quot;,&quot;@type&quot;:&quot;BreadcrumbList&quot;,&quot;itemListElement&quot;:[{&quot;@type&quot;:&quot;ListItem&quot;,&quot;item&quot;:&quot;https://www.datacamp.com&quot;,&quot;name&quot;:&quot;Home&quot;,&quot;position&quot;:1},{&quot;@type&quot;:&quot;ListItem&quot;,&quot;item&quot;:&quot;https://www.datacamp.com/courses-all&quot;,&quot;name&quot;:&quot;Courses&quot;,&quot;position&quot;:2},{&quot;@type&quot;:&quot;ListItem&quot;,&quot;item&quot;:&quot;https://www.datacamp.com/courses/intermediate-importing-data-in-python&quot;,&quot;name&quot;:&quot;Intermediate Importing Data in Python&quot;,&quot;position&quot;:3}]}</script><meta name="next-head-count" content="12"/><link as="font" crossorigin="anonymous" href="https://dcmfe.datacamp.com/assets/fonts/StudioFeixenSansRegular-english-v2.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://dcmfe.datacamp.com/assets/fonts/StudioFeixenSans-Semibold-english.woff2" rel="preload" type="font/woff2"/><link href="https://dcmfe.datacamp.com/assets/favicon.ico" rel="icon"/><link rel="preload" href="/_next/static/css/7e8383ad2d51100c.css" as="style"/><link rel="stylesheet" href="/_next/static/css/7e8383ad2d51100c.css" data-n-g=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-42372ed130431b0a.js"></script><script src="/_next/static/chunks/webpack-5b9eae0eeb3a0c20.js" defer=""></script><script src="/_next/static/chunks/framework-e952fed463eb8e34.js" defer=""></script><script src="/_next/static/chunks/main-5cc7b96eaf62efdd.js" defer=""></script><script src="/_next/static/chunks/pages/_app-92cc3508260ce5bd.js" defer=""></script><script src="/_next/static/chunks/5c0b189e-cee1fb1231bc8d86.js" defer=""></script><script src="/_next/static/chunks/883-e81ea3c084b8cb9e.js" defer=""></script><script src="/_next/static/chunks/827-5265c1ad0c5de802.js" defer=""></script><script src="/_next/static/chunks/416-e05cd4117ae81703.js" defer=""></script><script src="/_next/static/chunks/pages/courses/%5BcourseSlug%5D/%5BchapterSlug%5D-d2952d2efbc7d0b0.js" defer=""></script><script src="/_next/static/YFfsK0jJy6wetDEixq7nb/_buildManifest.js" defer=""></script><script src="/_next/static/YFfsK0jJy6wetDEixq7nb/_ssgManifest.js" defer=""></script></head><style data-emotion="css 8wqjsy">.css-8wqjsy{background-color:#05192D;margin:0;}</style><body class="c ...

# %% [markdown]
# ### Performing HTTP requests in Python using requests

# %% [markdown]
# Note that unlike in the previous exercises using urllib, you don't have to close the connection when using requests!

# %%
# Import package requests
import requests

# Specify the url: url
url = "http://www.datacamp.com/teach/documentation"

# Packages the request, send the request and catch the response: r
r = requests.get(url) #single code does all of this

# Extract the response: text
text = r.text #Use the text attribute of the object r to return the HTML of the webpage as a string;

# Print the html
print(text)
# Out:
# <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base64,...");background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme: dark){body{background-color:#222;color:#d9d9d9}}</style><meta http-equiv="refresh" content="360"></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt = {cvId: '3',cZone: 'www.datacamp.com',cType: 'non-interactive',cRay: '9724e6b3bb45f663',cH: '2YCK8zsqv_tzdSDYgmi4FEe23dwVNp3VzXRn__MyoqQ-1755724475-1.2.1.1-uBsVZaB4kyE3cvfZLKeg9DGkxjC.01l27T7F0QA6IBvFFwijPEgKaFN2Nl_V4cXf',cUPMDTk:"\/teach\/documentation?__cf_chl_tk=Utrzh9gSvl_piO7qlN2d7utCSKNwtfW_CXizWEboIIQ-1755724475-1.0.1.1-QE8PskCiFrmHx6Wz5lnFSg574dku3Ipyd1lqTuK9xWE",cFPWv: 'b',cITimeS: '1755724475',cTplC:0,cTplV:5,cTplB: 'cf',fa:"\/teach\/documentation?__cf_chl_f_tk=Utrzh9gSvl_piO7qlN2d7utCSKNwtfW_CXizWEboIIQ-1755724475-1.0.1.1-QE8PskCiFrmHx6Wz5lnFSg574dku3Ipyd1lqTuK9xWE",md: '6rTfefPhodh_Dwl907WHyztnmtgBVBCEnqzKmtEP1yw-1755724475-1.2.1.1-6gKN2t4H3RZhDId5QgTDNx_YmdmdGmKyRhI9yZuItM80wc9_ywGaGen3TMN5_oyxuF.6F8V4t80uobYc81TMzPID1sakyO0BLieKvVk70mMxCXxIphlt9D0SH_ESlGOzwg2nagr4tXvM524IEhVSu8qLYVKiqWzTjgvL5.plwQA2w7uXi6DZJuT9Nrq802D8vnzf9UTpU49n5zwweAS9xe4i5rNCqrxbvNS_0Zux63I2djtTnt2Wiv0WLR33FPE2Sr1YFj2KctwM_f9oIqvAzND9.H0jEZoWVI4gO2ZYkOKYCFpMT8FyRhRD4o6CXohDB.dvGxLPIsXOso7BkJixy9EVgME76yaAVfxz2h6MoYvy00MDEHqnWjEVwCn3_H1uibaejizz7fAbNUP6p4w5p4ULRzOCZiuWqmxjacjSOBQa_oFpRHsmouvyKMzl4y8I6RTYJKR0SzWxmhhVX28HzeGTYPYN2_7Qf4JdOF9rdAj9cZIAsY28BNsV7jJrveez2hyewD_lj2qqQoyrxmxObiwxrzAdVpH9EPTeRsa42FVSqmf7PwHk7YaqaeL8_8fauZovL4JhincNZNAnhHO2swUAGxqlCcqw9nCKfmOOv0XaP_G9JXhI4OKbZqBbob4zu7hs6kMW8UlhtolQbTgCdUUH2aiBGsW3VsKWSkkKkvhwNkGhIcAfcNCmxR9dbqhkEgjOMfr3_NOm0.LT_OjsVEOkK.pkOkxSwLAYY0Aa2oJ_RRNwo3u3MSwZ9gJdsF2FGv.IkGvHPXhJJivxGtGE347z6HOi3FJLseOjin3YntXS9oMqrh6cn3T8s5RW7XzMRdqTBWENTpa7NkfgnmEyNNUi4_DcJakKiVkjK9mS5py3bIzbf3UqlzN3Y8hAX4N84fE4.cLD941E9Zx5dytEMDnr9s.dyL2c_LJKtRIwKEp1.V1.xQOO7VawKwDBM4.T2vyqQwGGq7fy9nFO1MMgnw',mdrd: 'n.OFYNHbE5M.YciKyEsBL67KT.J34vXXNgUTgrOzUNA-1755724475-1.2.1.1-VoZEQA.DaeJHaxmLI_GlIpPJtI9bniLWWN_pQhG3sNvBvG5ENC4hTvOw0BxCcECC7j_FjghHRBz3sOolNpDR5W930JSUTsbyIGEIE_TxtDtdDIaF8ASOzTmwkD09Y_G7b7utrdAenx6TpVWny5SZzhLKP3ACmLgQ3EIZkZl4asMe9OBL71qnhx1D9gNzq2q6F9R4I7BSBmZgUvvxPozYcZja7e4zNbzEYsISjCmkMA_lePfPuK2pUi.OggdYtuvxt4CvUO5LHgCntXIGhccneSeweWpJiETPnXQNW37yjYyYXR_OJIBNp9q9EVQYelOCD60IapzGS.u74Fjn948EioNOdvpv8QbAE_mK4obSd2Vo9KPWxAB5qkes.CpvGaUzmmjTzOdL_ODRZ9RR0HzxLNnWFXCMQ3DdycT9YGjgALuoGt7moGvxYBXa7HRFN9tGEOTwi3SIdPejlGfSkB2Aaeuie32rcA7j1wCicqF2XGur.swno1SA0cKs7Gc0u9jskeoLnAKaWx2T_JByjKpTp7c0yaYWe.UcvTUwYDFcTSQYrI1S5tC0l5jiB_YDoPPTcXTKAIXTc2l3vj8aHmmjpS3SvunEdj59ZeBNkghFqDsz9dYsHCk72RLIL.0QMRVwSj.BQhjeUobVMJ.DedJZM3C9KOLLKaiHiqiJOq5KXlZxEM.hua9UXu9nzhSPZdvQIW49RfMx51mO1TQh3oAkGjOwuaZj.VuqZ7ZXEH_R89FT8K7U41iLZKOSASFzFl6_dgh96R8spw2xSgWEsm7F9f6D7aBzITiakCp1JT5M0BvCIVV0k_NNyHKbfV5DB7iOsDE2mh53 ...

# %% [markdown]
# ## Scraping the Web in Python

# %% [markdown]
# HTML
#
# - Mix of Structered and Unstructered data
#
# - Structered data = has per-defined data model or organised in a defined manner
#
# - Unstructered data = neither of these properties
#
# - Beautiful Soup Packagage - Parse and extract data from HTML used for web scraping

# %% [markdown]
# ## Parsing HTML with BeautifulSoup

# %%
#import packages
import requests
from bs4 import BeautifulSoup

# specify url: url is ebay UK homepage for instance
url = 'https://www.ebay.co.uk/'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extracts the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Prettify the BeautifulSoup object: pretty_soup
pretty_soup = soup.prettify() #to make output more readable

# Print the response
print(pretty_soup)
# Out:
# <!--vertlandweb#s0-1-0-->
# <!DOCTYPE html>
# <!--[if IE 9 ]>    <html class="ie9"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <!--vertlandweb^s0-1-0-4 s0-1-0 4-->
#   <!--vertlandweb/-->
#   <!--vertlandweb^s0-1-0-5 s0-1-0 5-->
#   <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#   <link href="//rover.ebay.com" rel="dns-prefetch"/>
#   <script>
#    $ssgST=new Date().getTime();
#   </script>
#   <!--vertlandweb/-->
#   <link as="image" crossorigin="" href="https://ir.ebaystatic.com/pictures/aw/pics/s_1x2.gif" rel="preload"/>
#   <meta charset="utf-8"/>
#   <link href="https://pages.ebay.com/favicon.ico" rel="icon"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=yes, minimum-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://srv.uk.ebayrtm.com" rel="preconnect"/>
#   <noscript>
#    <style>
#     .js-only {
#           display: none !important;
#         }
#    </style>
#   </noscript>
#   <script>
#    window.layoutStart = Date.now();
#       window.vertlandweb = {"isWebpSupported":false,"isLowBandwidth":false,"lazyLoadAll":true,"showSpeedInConsole":false,"isMobileLayout":false};
#       // We need a way to pass the global config setting for enabling/disabling cookie-observer
#       // inline script. Hence we get it from our global config and attach it to the window object.
#       // So that the inline script injected as a part of include-html tag below has access to it.
#       window.ENABLE_VLP_COOKIE_OBSERVER = false;
#   </script>
#   <script data-type="inline_js" type="text/javascript">
#    (()=>{var e={138:e=>{"use strict";var t=/(?:\d*\.)?\d+/g,n=[64,96,140,200,225,300,400,500,640,960,1200,1600],o={containsThumbs:function(e){return e.indexOf("thumbs")>-1},isZoomUrl:function(e){var t=this.containsThumbs(e)?8:7;return!(e.length!==t||!e[e.length-1].match("s-l"))||(console.debug("This image url is not valid Zoom format: ".concat(e.join("/"))),!1)},getParts:function(e,t){return e.split(t)},replaceType:function(e,t,n){var o=e,a=n?7:6,i=t.type||!t.cachedPage&&t.webp&&"webp";if(i){var r=this.getParts(o[a],".");r[1]=i,o[a]=r.join(".")}return o},getNearestSize:function(e){var t;for(t=0;t<n.length-1;t++)if(n[t]>=e)return n[t];return n[t]},getConnection:function(){return"undefined"!=typeof navigator&&navigator.connection&&navigator.connection.effectiveType},isLowBandwidth:function(e){var t=this.getConnection();return t?["slow-2g","2g","3g"].filter((function(e){return e===t})).length:!e.cachedPage&&e.lowBandwidth},replaceSize:function(e,n,o){var a,i=e,r=o?7:6;a=n.size?n.size:i[r].match(t)[0],window.innerWidth<a&&n.safeSizeImages&&(a=this.getNearestSize(window.innerWidth));var d=window.devicePixelRatio||1;return!n.disableHDSizing&&d>1&&!n.lowBandwidth&&(n.disable3xSizing?a*=2:a*=d),i[r]=i[r].replace(t,this.getNearestSize(a)),i},transformUrl:function(e){var t=this.getParts(e.src,"/"),n=this.containsThumbs(t);return this.isZoomUrl(t)?(t=this.replaceSize(t,e,n),(t=this.replaceType(t,e,n)).join("/")):e.src}};e.exports=function(){var e=arguments.length>0&&void 0!==arguments[0]?arguments[0]:{};return e.lowBandwidth=o.isLowBandwidth(e),function(t,n,a){try{var i=Object.create(e);return i.src=t,n&&(i.size=n),a&&(i.type=a),o.transformUrl(i)}catch(e){return console.debug("There was an error trying to transform this zoom url: ".concat(t,", size: ").concat(n,", type: ").concat(a,", ").concat(e.stack)),t}}},e.exports.helpers=o},519:e=>{e.exports=(e,t,n)=>{if(!e)return!1;const o=n||0,a=window.innerHeight,i=t||window.innerWidth,r=e.getBoundingClientRect(),d=r.top<=a+o&&r.top+r.height>=0,s=r.left<i&&r.left+r.width>0;return d&&s}},816:(e,t,n)=>{const o=n(519),a=n(138),i="load",r="error",d="lazyLoad",s="lazyLoadSwap",l="addEventListener",c="removeEventListener",u="removeAttribute",m="hasAttribute",g="data-load-time",p="setAttribute",w="getAttribute",h="getElementsByClassName",f="querySelectorAll",v="data-vl-atf",y=window.performance&&window.performance.timing,I=Array.prototype.slice,b=e=>parseInt(e[w](g)),L=e=>{const t=Date.now();return e[p](g,t),t},T="data-m-atf",E="vl-atf-module-js",S={hasSpeedMetricsReported:!1,queue:[],swapQueue:[],atfImageList:[],mainContentRect:{},startTime:"undefined"==typeof $ssgST?Date.now():$ssgST,init(){window.lazyLoadInit=Date.now(),S.zoomClient=a({webp:window.vertlandweb.isWebpSupported,lowBandwidth:window.vertlandweb.isLowBandwidth,cachedPage:!1,disableHDSizing:!window.vertlandweb.isMobileLayout}),window.lazyLoad=window.lazyLoad||{},window.lazyLoad.addToQueue=(e,t)=>{if(e[u]("onerror"),e[u]("onload"),"{}"===JSON.stringify(S.mainContentRect)&&(S.mainContentRect=S.getMainContentRect()),0===S.atfImageList.length&&(S.atfImageList=S.buildATFImageList()),e[m]("data-load-immediately"))return t?S.loadImageDiv({target:e.parentElement}):S.loadImage({target:e});if(S.shouldLoadImageInHighPriority(e))return S.loadImageInHighPriority(e,t);if(t){const t=e.parentElement;t[l](d,S.loadImageDiv),S.queue.unshift(t),S.loadImageIfVisible({image:t,immediate:e})}else e[l](d,S.loadImage),S.queue.unshift(e),S.loadImageIfVisible({image:e,immediate:e})},window[l](i,S.loadAll),window.tempLazyLoadQueue&&(window.tempLazyLoadQueue.forEach((e=>{let{el:t,fit:n}=e;window.lazyLoad.addToQueue(t,n)})),window.tempLazyLoadQueue=[]),window[l](i,S.reportATFTimeFromPageLoad)},tearDown(){window[c](i,S.loadAll),window[c](i,S.reportATFTimeFromPageLoad)},buildATFImageList:()=>I.call(document[h](E),0,2).reduce(((e,t)=>e.concat(I.call(t[h]("vl-image-js")))),[]),reportATFTimeFromPageLoad(){S.setOKToReport(!0),S.reportATFTime()},reportATFTime(){const e=S.getAT ...
#   </script>
#   <link href="https://ir.ebaystatic.com/rs/c/globalheaderweb/index_lcNW.20106f3c.css" rel="stylesheet" type="text/css"/>
#   <script>
#    window.$i18n = {"follow/follow":{"saveSearchHeading":"Save search","emailMeNewItems":"Email me when new items match my search","cancel":"Cancel","save":"Save","savedSellerClippedText":"seller","savedSearchClippedText":"search","linkSave":"Save","linkSaved":"Saved","nameLabel":"Name","postTooltip":"We'll send you an email when there's something new.","postTooltipInfoOn":"To help you keep up, we can email you when there's something new.","postTooltipOff":"Turn off email alerts","postTooltipOn":"Turn on email alerts","postTooltipOffSuccess":"Email alerts turned off.","postTooltipOnSuccess":"Email alerts turned on.","postTooltipDismiss":"Dismiss the save search message.","errorMaxedSaveSearch":"You've already saved the maximum number of searches. You need to unsave a search before adding another.","errorSave":"We had trouble saving this item. Please try again later.","errorUnsave":"We had trouble unsaving this item. Please try again later.","busy":"busy","loading":"Loading"},"locales":{"pageTitle":{"@target":{"Default":"Outlet","EBAY_DE":"eBay Marken Outlet - bis zu 70% Rabatt","EBAY_UK":"Brand Outlet"}},"pageDescription":{"@target":{"Default":"Get the best deals on Brand Outlet when you shop the largest online selection at eBay.com. Free postage on many items | Browse your favourite brands | affordable prices.","EBAY_DE":"Alle Fashion-Deals an einem Ort! Top-Marken ✓ bis zu 70% Rabatt ✓ attraktive Outlet-Preise ✓immer mit gratis Hin- und Rückversand ✓","EBAY_UK":"Buy from Brand Outlet and get the best fashion deals at the lowest prices on eBay! Save up to 70% on top brands and enjoy Free Delivery"}},"emptyState":"We weren't able to find your content. Please try again.","crumbA11y":"Page navigation","feedbackTextDWEB":"Feedback","feedbackTextDWEBA11Y":"What do you think of the new {vlpPageName} page?","openInNewTab":"Opens in a new window or tab","registerLiveEventError":"We had trouble setting an alert. Please try again later.","loggedOutNotice":"You've signed out. See you again soon.","loggedOutFeedbackWithLink":"How was your experience? <a href=\"{href}\">Leave Feedback</a>","signInAgainLink":"<a href=\"{href}\">Sign in again</a>","home":"Home","tooltipTitle":"Looking for your old homepage?","tooltipSubTitle":"Find updates to saved searches and sellers here.","expandCategory":"Expand:","more":"More","following":"Following","saved":"Saved","open":"Open","close":"Close","localSearchPlaceholder":"Search for items near you","localSearchPlaceholderNoZipcode":"Search for local items","recentlyViewedTitle":"Recently viewed","dealsTitle":"Today's deals","watchedItemsTitle":"Watched items","piyiTitle":"Picks for you","setReminderText":"Set reminder for event","removeReminderText":"Remove reminder for event","carouselPlay":"Play slideshow","carouselPause":"Pause slideshow","carouselPrevious":"Go to previous slide","carouselNext":"Go to next slide"}};
#   </script>
#   <!--vertlandweb^s0-1-0-20 s0-1-0 20-->
#   <script id="ebay-rum-web">
#   </script>
#   <!--vertlandweb/-->
#   <script>
#    window.tempLazyLoadQueue = [];
#       window.addtoLazyLoad = function (config) {
#         if (typeof lazyLoad !== "undefined") {
#           lazyLoad.addToQueue(config.el, config.fit);
#         } else {
#           tempLazyLoadQueue.push(config);
#         }
#       };
#   </script>
#   <!-- SEO METADATA START -->
#   <link href="https://pe.ebay.com" hreflang="es-PE" rel="alternate"/>
#   <link href="https://ni.ebay.com" hreflang="es-NI" rel="alternate"/>
#   <link href="https://ve.ebay.com" hreflang="es-VE" rel="alternate"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://ir.ebaystatic.com/cr/v/c1/ebay-logo-1-1200x630-margin.png" property="og:image"/>
#   <meta content="Buy &amp; sell electronics, cars, clothes, collectibles &amp; more on eBay UK's online marketplace. Top brands, low prices &amp; free shipping on many items." name="twitter:description"/>
#   <meta content="102628213125203" property="fb:app_id"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="eBay UK" property="og:site_name"/>
#   <link href="https://pa.ebay.com" hreflang="es-PA" rel="alternate"/>
#   <meta content="eBay UK | Electronics, Cars, Fashion, Collectibles &amp; More" property="og:title"/>
#   <link href="https://py.ebay.com" hreflang="es-PY" rel="alternate"/>
#   <link href="https://pr.ebay.com" hreflang="es-PR" rel="alternate"/>
#   <link href="https://www.ebay.com" hreflang="en-us" rel="alternate"/>
#   <link href="https://www.ebay.co.uk" hreflang="en-gb" rel="alternate"/>
#   <title>
#    eBay UK | Electronics, Cars, Fashion, Collectibles &amp; More
#   </title>
#   <link href="https://www.ebay.de" hreflang="de-de" rel="alternate"/>
#   <meta content="en-gb" http-equiv="content-language"/>
#   <link href="https://www.ebay.com.au" hreflang="en-au" rel="alternate"/>
#   <link href="https://www.ebay.fr" hreflang="fr-fr" rel="alternate"/>
#   <link href="https://www.ebay.it" hreflang="it-it" rel="alternate"/>
#   <link href="https://www.ebay.es" hreflang="es-es" rel="alternate"/>
#   <meta content="https://ir.ebaystatic.com/cr/v/c1/ebay-logo-1-1200x1200-margin.png" name="twitter:image"/>
#   <link href="https://www.ebay.co.uk" rel="canonical"/>
#   <meta content="Buy &amp; sell electronics, cars, clothes, collectibles &amp; more on eBay UK's online marketplace. Top brands, low prices &amp; free shipping on many items." name="description"/>
#   <meta content="Buy &amp; sell electronics, cars, clothes, collectibles &amp; more on eBay UK's online marketplace. Top brands, low prices &amp; free shipping on many items." property="og:description"/>
#   <link href="https://www.ebay.ca" hreflang="en-ca" rel="alternate"/>
#   <link href="https://www.ebay.nl" hreflang="nl-nl" rel="alternate"/>
#   <meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01"/>
#   <link href="https://www.ebay.pl" hreflang="pl-pl" rel="alternate"/>
#   <link href="https://www.benl.ebay.be" hreflang="nl-be" rel="alternate"/>
#   <link href="https://www.befr.ebay.be" hreflang="fr-be" rel="alternate"/>
#   <link href="https://www.ebay.at" hreflang="de-at" rel="alternate"/>
#   <link href="https://www.ebay.ch" hreflang="de-ch" rel="alternate"/>
#   <link href="https://www.ebay.ie" hreflang="en-ie" rel="alternate"/>
#   <link href="https://www.ebay.com.my" hreflang="en-my" rel="alternate"/>
#   <meta content="eBay UK | Electronics, Cars, Fashion, Collectibles &amp; More" name="twitter:title"/>
#   <meta content="@eBay" name="twitter:site"/>
#   <link href="https://i.ebayimg.com" rel="preconnect"/>
#   <link href="https://www.ebay.com.sg" hreflang="en-sg" rel="alternate"/>
#   <meta content="unsafe-url" name="referrer"/>
#   <link href="https://ir.ebaystatic.com" rel="preconnect"/>
#   <link href="https://www.cafr.ebay.ca" hreflang="fr-ca" rel="alternate"/>
#   <link href="https://www.ebay.com.hk" hreflang="zh-hk" rel="alternate"/>
#   <link href="https://cn.ebay.com" hreflang="zh-CN" rel="alternate"/>
#   <link href="https://il.ebay.com" hreflang="en-IL" rel="alternate"/>
#   <link href="https://pt.ebay.com" hreflang="pt-PT" rel="alternate"/>
#   <link href="https://by.ebay.com" hreflang="ru-BY" rel="alternate"/>
#   <meta content="0090e7e28a2554d4" name="y_key"/>
#   <link href="https://kz.ebay.com" hreflang="ru-KZ" rel="alternate"/>
#   <link href="https://br.ebay.com" hreflang="pt-BR" rel="alternate"/>
#   <link href="https://co.ebay.com" hreflang="es-CO" rel="alternate"/>
#   <meta content="N44szmI3uamPmsOzfSbiKbBd_834GucfjqGRRyXZ7wQ" name="google-site-verification"/>
#   <link href="https://mx.ebay.com" hreflang="es-MX" rel="alternate"/>
#   <link href="https://ar.ebay.com" hreflang="es-AR" rel="alternate"/>
#   <link href="https://bo.ebay.com" hreflang="es-BO" rel="alternate"/>
#   <link href="https://cl.ebay.com" hreflang="es-CL" rel="alternate"/>
#   <meta content="https://www.ebay.co.uk" property="og:url"/>
#   <meta content="sites-6603353820027325" name="google-adsense-account"/>
#   <link href="https://www.ebay.com" hreflang="x-default" rel="alternate"/>
#   <link href="https://cr.ebay.com" hreflang="es-CR" rel="alternate"/>
#   <link href="https://do.ebay.com" hreflang="es-DO" rel="alternate"/>
#   <link href="https://ec.ebay.com" hreflang="es-EC" rel="alternate"/>
#   <link href="https://sv.ebay.com" hreflang="es-SV" rel="alternate"/>
#   <link href="https://gt.ebay.com" hreflang="es-GT" rel="alternate"/>
#   <link href="https://hn.ebay.com" hreflang="es-HN" rel="alternate"/>
#   <link href="https://uy.ebay.com" hreflang="es-UY" rel="alternate"/>
#   <!-- SEO METADATA END -->
#   <script async="" crossorigin="" src="https://ir.ebaystatic.com/rs/c/vertlandweb/r.647ae55a.js">
#   </script>
#   <link href="https://ir.ebaystatic.com/rs/c/vertlandweb/r.df7f3342.css" rel="stylesheet"/>
#  </head>
#  <body class="desktop evo-css-changes" lang="en">
#   <!--vertlandweb^s0-1-0-25 s0-1-0 25-->
#   <div data-src="59322f29" id="s0-1-0-25-0-1-0-0">
#    <!--F#@_-->
#    <noscript id="afvertlandwebph0">
#    </noscript>
#    <!--F/-->
#   </div>
#   <div data-from="ads_platform_all_ads" data-slot="TRACKING_DATA" id="s0-1-0-25-0-2-0">
#    <!--F#@_-->
#    <noscript id="afvertlandwebph1">
#    </noscript>
#    <!--F/-->
#   </div>
#   <!--vertlandweb/-->
#   <script>
#    $mwp_vertlandweb="https://ir.ebaystatic.com/rs/c/vertlandweb/";(window.$ebay||($ebay = {})).tracking={pageId:'4432023',pageName:'vertlandweb_homepage'}
#   </script>
#   <!--vertlandweb#s0-1-0-26-10-->
#   <div class="vl-pushdown" data-m-id="4816" data-view='{"eventFamily":"VERTLAND","eventAction":"VIEW","operationId":"4375194","flushImmediately":false,"eventProperty":{"parentrq":"c9556dfe1980ab1fbab669bdffe25072","pageci":"aca67c6f-7e0a-11f0-9239-6229b4efe979","moduledtl":"mi:4816|c:1|iid:1|luid:1","vlpname":"vlp_homepage"}}' data-viewdtls='{"moduleInstance":"mi:4816|iid:1","parentrq":"c9556dfe1980ab1fbab669bdffe25072","trackViews":"true","trackPerf":"true"}' style="background-color:#FFFFFF">
#    <div class="vl-pushdown__wrapper">
#     <div class="vl-pushdown__container" id="vl-pushdown__shrinked">
#      <div data-from="ads_platform_all_ads" data-slot="PLACEMENT_100713" id="s0-1-0-26-10-18-0-@PLACEMENT_100713-0">
#       <!--F#@_-->
#       <!--F/-->
#      </div>
#     </div>
#     <div class="vl-pushdown__container transparent" id="vl-pushdown__expanded">
#     </div>
#     <button class="vl-pushdown__toggle" disabled="" style="background-color:#FFFFFF;color:inherit" type="button">
#      Open
#      <!--F#23-->
#      <svg height="8px" version="1.1" viewbox="0 0 14 8" width="14px" xmlns="https://www.w3.org/2000/svg">
#       <desc>
#        Expand Svg
#       </desc>
#       <defs>
#       </defs>
#       <g fill="none" fill-rule="evenodd" id="btn-expand" stroke="none" stroke-width="1">
#        <g fill="inherit" fill-rule="nonzero">
#         <g>
#          <polygon points="6.5355339 6.8994949 6.7071068 7.0710678 13.0710678 0.7071068 12.363961 0 6.5355339 5.8284271 0.7071068 0 0 0.7071068 6.363961 7.0710678">
#          </polygon>
#         </g>
#        </g>
#       </g>
#      </svg>
#      <!--F/-->
#     </button>
#    </div>
#    <div class="vl-pushdown__overlay">
#    </div>
#   </div>
#   <!--vertlandweb/-->
#   <div id="globalHeaderWrapper">
#    <div class="page-grid-container hp-grid-container">
#     <div class="page-grid hp-grid">
#      <div class="global-header-container">
#       <script type="text/javascript">
#        var GHpre = {"ghxc":[],"ghxs":[],"userAuth":false,"userId":"","fn":""}
#       </script>
#       <!--globalheaderweb#s0-1-4-->
#       <link href="https://www.ebay.co.uk/manifest.json" rel="manifest"/>
#       <!--globalheaderweb#s0-1-4-2-0-->
#       <script>
#        (function(){const e=window.GH||{};try{var o,i;const n=e=>e==="true";const a=n("false");const d=/[\W_]/g;const s=window.location.hostname.includes("sandbox");let l="https://www.ebay.co.uk";if(s){l=l.replace("www","sandbox")}e.__private=e.__private||{};e.C={siteId:"3",env:"production",lng:"en-GB",pageId:Number("4432023"),xhrBaseUrl:l};e.__private.risk={behavior_collection_interval:JSON.parse("{\"2500857\":5000,\"2507978\":5000,\"default\":15000}"),id:(o=window.GHpre)===null||o===void 0?void 0:o.userId};e.__private.fsom={linkUrl:"https://www.m.ebay.co.uk",linkText:"Switch to mobile site"};e.__private.ACinit={isGeo:n("false"),isQA:a,factors:JSON.parse("[]")};e.__private.isQA=a;try{var t,r;e.__private.ghx=[...(((t=window.GHpre)===null||t===void 0?void 0:t.ghxc)||[]).map((e=>e.replace(d,""))),...(((r=window.GHpre)===null||r===void 0?void 0:r.ghxs)||[]).map((e=>e.replace(d,"")))]}catch(o){e.__private.ghx=[]}e.resetCart=function(o){const i=new CustomEvent("updateCart",{detail:o});document.dispatchEvent(i);e.__private.cartCount=o};e.userAuth=((i=window.GHpre)===null||i===void 0?void 0:i.userAuth)||false;window.GH=e}catch(o){console.error(o);window.GH=e||{}}})();
#       </script>
#       <!--globalheaderweb/-->
#       <!--globalheaderweb#s0-1-4-2-2-->
#       <script>
#        window.GH.__private.scandal = {
#         isGeo: function() {return false;},
#         getPageID: function() {return 4432023;},
#         getSiteID: function() {return "3";}
#     };
#       </script>
#       <!--globalheaderweb/-->
#       <!--globalheaderweb#s0-1-4-3-0-->
#       <!--globalheaderweb/-->
#       <!--globalheaderweb^s0-1-4-4 s0-1-4 4-->
#       <!--globalheaderweb/-->
#       <!--globalheaderweb^s0-1-4-5 s0-1-4 5-->
#       <!--globalheaderweb/-->
#       <!--globalheaderweb^s0-1-4-6 s0-1-4 6-->
#       <div class="gh-sch-prom" data-marko-key="@gh-border s0-1-4-6" id="gh-gb" tabindex="-1">
#       </div>
#       <!--globalheaderweb/-->
#       <div class="ghw">
#        <header class="gh-header" data-marko-key="@gh s0-1-4" id="gh">
#         <div class="gh-a11y-skip-button">
#          <a class="gh-a11y-skip-button__link" href="#mainContent" tabindex="1">
#           Skip to main content
#          </a>
#         </div>
#         <nav class="gh-nav">
#          <div class="gh-nav__left-wrap">
#           <!--globalheaderweb#s0-1-4-9-3[0]-0-->
#           <span class="gh-identity">
#            <span class="gh-identity__srvr" data-marko-key="5 s0-1-4-9-3[0]-0" id="gh-ident-srvr-wrap">
#             <!--F#6-->
#             <span class="gh-identity__greeting">
#              Hi
#              <span>
#               <span id="gh-ident-srvr-name">
#               </span>
#               !
#              </span>
#             </span>
#             <!--F/-->
#             <!--F#7-->
#             <script>
#              (function(){
#         const pre = window.GHpre || {};
#         function hide() {
#             const wrap = document.getElementById('gh-ident-srvr-wrap');
#             if (wrap) { wrap.classList.add('gh-identity__srvr--unrec') };
#         }
#         if (pre.userAuth) {
#             const nm = document.getElementById('gh-ident-srvr-name');
#             const user = GH.C.siteId === '77' ? pre.userId || pre.fn : pre.fn || pre.userId;
#             nm && user ? nm.textContent = decodeURIComponent(user) : hide();
#         } else {
#             hide();
#         }
#     })();
#             </script>
#             <!--F/-->
#             <!--globalheaderweb^s0-1-4-9-3[0]-0-8 s0-1-4-9-3[0]-0 8-->
#             <span class="gh-identity-signed-out-unrecognized">
#              Hello.
#              <a _sp="m570.l1524" href="https://signin.ebay.co.uk/ws/eBayISAPI.dll?SignIn&amp;sgfl=gh">
#               Sign in
#              </a>
#              <span class="hide-at-md">
#               or
#               <a _sp="m570.l2621" href="https://signup.ebay.co.uk/pa/crte">
#                register
#               </a>
#              </span>
#             </span>
#             <!--globalheaderweb/-->
#            </span>
#           </span>
#           <!--globalheaderweb/-->
#           <span class="gh-nav-link">
#            <a _sp="m570.l184380" aria-label="Local" href="https://www.ebay.co.uk/vlp/local">
#             Local
#            </a>
#           </span>
#           <span class="gh-nav-link">
#            <a _sp="m570.l3188" aria-label="Daily Deals" href="https://www.ebay.co.uk/deals">
#             Daily Deals
#            </a>
#           </span>
#           <span class="gh-nav-link">
#            <a _sp="m570.l47233" aria-label="Fashion" href="https://www.ebay.co.uk/b/bn_7000259675">
#             Fashion
#            </a>
#           </span>
#           <span class="gh-nav-link">
#            <a _sp="m570.l1545" aria-label="Help &amp; Contact" href="https://www.ebay.co.uk/help/home">
#             Help &amp; Contact
#            </a>
#           </span>
#          </div>
#          <div class="gh-nav__right-wrap">
#           <!--globalheaderweb#s0-1-4-9-6-->
#           <!--globalheaderweb/-->
#           <!--globalheaderweb#s0-1-4-9-7-->
#           <!--globalheaderweb/-->
#           <span class="gh-nav-link" data-id="SELL_LINK">
#            <a _sp="m570.l1528" aria-label="Sell" href="https://www.ebay.co.uk/sl/sell">
#             <!--globalheaderweb#s0-1-4-9-8[0]-3-0-->
#             <svg aria-hidden="true" class="gh-nav__sell-icon icon icon--16" data-marko-key="@svg s0-1-4-9-8[0]-3-0" focusable="false">
#              <defs data-marko-key="@defs s0-1-4-9-8[0]-3-0">
#               <symbol id="icon-selling-16" viewbox="0 0 16 16">
#                <path clip-rule="evenodd" d="M3 4a1 1 0 0 1 1-1h3.379a.5.5 0 0 1 .353.146l5.12 5.12a.5.5 0 0 1 0 .708l-3.878 3.878a.5.5 0 0 1-.708 0l-5.12-5.12A.5.5 0 0 1 3 7.38V4Zm1-3a3 3 0 0 0-3 3v3.379a2.5 2.5 0 0 0 .732 1.767l5.12 5.12a2.5 2.5 0 0 0 3.536 0l3.878-3.878a2.5 2.5 0 0 0 0-3.536l-5.12-5.12A2.5 2.5 0 0 0 7.38 1H4Zm2 6.001a1 1 0 1 0 0-2 1 1 0 0 0 0 2Z" fill-rule="evenodd">
#                </path>
#               </symbol>
#              </defs>
#              <use href="#icon-selling-16">
#              </use>
#             </svg>
#             <!--globalheaderweb/-->
#             Sell
#            </a>
#           </span>
#           <!--globalheaderweb#s0-1-4-9-9-0-->
#           <div class="gh-flyout is-right-aligned gh-watchlist">
#            <!--F#1-->
#            <a _sp="m570.l47137" class="gh-flyout__target" href="https://www.ebay.co.uk/mye/myebay/watchlist">
#             <!--F#6-->
#             <span class="gh-watchlist__target">
#              Watch List
#             </span>
#             <!--F/-->
#             <!--F#7-->
#             <svg aria-hidden="true" class="gh-flyout__chevron icon icon--12" focusable="false" tabindex="-1">
#              <defs>
#               <symbol id="icon-chevron-down-12" viewbox="0 0 12 12">
#                <path clip-rule="evenodd" d="M1.808 4.188a.625.625 0 0 1 .884 0L6 7.495l3.308-3.307a.625.625 0 1 1 .884.885l-3.75 3.749a.625.625 0 0 1-.884 0l-3.75-3.749a.626.626 0 0 1 0-.885Z" fill-rule="evenodd">
#                </path>
#               </symbol>
#              </defs>
#              <use href="#icon-chevron-down-12">
#              </use>
#             </svg>
#             <!--F/-->
#            </a>
#            <button aria-controls="s0-1-4-9-9-0-0-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target-a11y-btn" tabindex="0">
#             Expand watch list
#            </button>
#            <!--F/-->
#            <div class="gh-flyout__dialog" id="s0-1-4-9-9-0-0-dialog">
#             <div class="gh-flyout__box">
#              <!--F#4-->
#              <!--F/-->
#             </div>
#            </div>
#           </div>
#           <!--globalheaderweb/-->
#           <!--globalheaderweb#s0-1-4-9-10-->
#           <!--globalheaderweb^s0-1-4-9-10-0 s0-1-4-9-10 0-->
#           <div class="gh-flyout is-left-aligned gh-my-ebay">
#            <!--F#1-->
#            <a _sp="m570.l2919" class="gh-flyout__target" href="https://www.ebay.co.uk/mys/home?source=GBH">
#             <!--F#6-->
#             <span class="gh-my-ebay__link gh-rvi-menu">
#              My eBay
#              <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron">
#              </i>
#             </span>
#             <!--F/-->
#             <!--F#7-->
#             <svg aria-hidden="true" class="gh-flyout__chevron icon icon--12" focusable="false" tabindex="-1">
#              <use href="#icon-chevron-down-12">
#              </use>
#             </svg>
#             <!--F/-->
#            </a>
#            <button aria-controls="s0-1-4-9-10-0-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target-a11y-btn" tabindex="0">
#             Expand My eBay
#            </button>
#            <!--F/-->
#            <div class="gh-flyout__dialog" id="s0-1-4-9-10-0-dialog">
#             <div class="gh-flyout__box">
#              <!--F#4-->
#              <ul class="gh-my-ebay__list">
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l1533" href="https://www.ebay.co.uk/mye/myebay/summary" tabindex="0">
#                 Summary
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l9225" href="https://www.ebay.co.uk/mye/myebay/rvi" tabindex="0">
#                 Recently Viewed
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l1535" href="https://www.ebay.co.uk/mye/myebay/bidsoffers" tabindex="0">
#                 Bids/Offers
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l1534" href="https://www.ebay.co.uk/mye/myebay/watchlist" tabindex="0">
#                 Watch List
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l1536" href="https://www.ebay.co.uk/mye/myebay/purchase" tabindex="0">
#                 Purchase History
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l1537" href="https://www.ebay.co.uk/mys/home?CurrentPage=MyeBayAllSelling&amp;ssPageName=STRK:ME:LNLK:MESX&amp;source=GBH" tabindex="0">
#                 Selling
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l187417" href="https://www.ebay.co.uk/mye/myebay/saved" tabindex="0">
#                 Saved feed
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l9503" href="https://www.ebay.co.uk/mye/myebay/savedsearches" tabindex="0">
#                 Saved Searches
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l9505" href="https://www.ebay.co.uk/mye/myebay/savedsellers" tabindex="0">
#                 Saved Sellers
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l143039" href="https://www.ebay.co.uk/g/mygarage" tabindex="0">
#                 My Garage
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l177358" href="https://www.ebay.co.uk/mysize/hub" tabindex="0">
#                 Sizes
#                </a>
#               </li>
#               <li class="gh-my-ebay__list-item">
#                <a _sp="m570.l1539" href="https://mesg.ebay.co.uk/mesgweb/ViewMessages/0" tabindex="0">
#                 Messages
#                </a>
#               </li>
#              </ul>
#              <!--F/-->
#             </div>
#            </div>
#           </div>
#           <!--globalheaderweb/-->
#           <!--globalheaderweb/-->
#           <!--globalheaderweb#s0-1-4-9-11-0-->
#           <div class="gh-notifications">
#            <div class="gh-flyout is-right-aligned gh-flyout--icon-target">
#             <!--F#2-->
#             <button aria-controls="s0-1-4-9-11-0-1-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target">
#              <!--F#10-->
#              <span class="gh-hidden">
#               Expand Notifications
#              </span>
#              <svg aria-hidden="true" class="icon icon--20" focusable="false">
#               <defs>
#                <symbol id="icon-notification-20" viewbox="0 0 20 20">
#                 <path clip-rule="evenodd" d="M6 6.982a4 4 0 0 1 8 0v2.68c0 .398.106.79.307 1.135l1.652 2.827a.25.25 0 0 1-.216.376H4.256a.25.25 0 0 1-.216-.376l1.653-2.827A2.25 2.25 0 0 0 6 9.662v-2.68ZM4 7a6 6 0 1 1 12 0v2.662a.25.25 0 0 0 .034.126l1.652 2.827c.877 1.5-.205 3.385-1.943 3.385H13a3 3 0 0 1-6 0H4.256c-1.737 0-2.819-1.885-1.942-3.385l1.652-2.827A.25.25 0 0 0 4 9.662V7Zm5 9h2a1 1 0 1 1-2 0Z" fill-rule="evenodd">
#                 </path>
#                </symbol>
#               </defs>
#               <use href="#icon-notification-20">
#               </use>
#              </svg>
#              <!--F/-->
#              <!--F#11-->
#              <!--F/-->
#             </button>
#             <!--F/-->
#             <div class="gh-flyout__dialog" id="s0-1-4-9-11-0-1-dialog">
#              <div class="gh-flyout__box">
#               <!--F#4-->
#               <div class="gh-notifications__dialog">
#                <div class="gh-notifications__notloaded">
#                 <span class="gh-notifications__signin">
#                  Please
#                  <a _sp="m570.l2881" href="https://signin.ebay.co.uk/ws/eBayISAPI.dll?SignIn&amp;sgfl=nf&amp;ru=">
#                   sign in
#                  </a>
#                  to view notifications.
#                 </span>
#                </div>
#                <div class="gh-notifications__loaded" data-marko-key="@dynamic s0-1-4-9-11-0">
#                </div>
#               </div>
#               <!--F/-->
#              </div>
#             </div>
#            </div>
#           </div>
#           <!--globalheaderweb/-->
#           <div class="gh-cart">
#            <!--globalheaderweb#s0-1-4-9-12-1-->
#            <div class="gh-flyout is-right-aligned gh-flyout--icon-target">
#             <!--F#1-->
#             <a _sp="m570.l2633" class="gh-flyout__target" href="https://cart.ebay.co.uk">
#              <!--F#6-->
#              <span aria-label="Your shopping basket contains 0 items" class="gh-cart__icon">
#               <svg aria-hidden="true" class="icon icon--20" focusable="false">
#                <defs>
#                 <symbol id="icon-cart-20" viewbox="0 0 20 20">
#                  <path clip-rule="evenodd" d="M2.236 4H1a1 1 0 1 1 0-2h1.97c.458-.014.884.296 1 .755L4.855 6H17c.654 0 1.141.646.962 1.274l-1.586 5.55A3 3 0 0 1 13.491 15H7.528a3 3 0 0 1-2.895-2.21L2.236 4Zm4.327 8.263L5.4 8h10.274l-1.221 4.274a1 1 0 0 1-.962.726H7.528a1 1 0 0 1-.965-.737Z" fill-rule="evenodd">
#                  </path>
#                  <path d="M8 18.5a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0Zm6.5 1.5a1.5 1.5 0 1 0 0-3 1.5 1.5 0 0 0 0 3Z">
#                  </path>
#                 </symbol>
#                </defs>
#                <use href="#icon-cart-20">
#                </use>
#               </svg>
#              </span>
#              <!--F/-->
#              <!--F#7-->
#              <!--F/-->
#             </a>
#             <button aria-controls="s0-1-4-9-12-1-0-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target-a11y-btn" tabindex="0">
#              Expand Basket
#             </button>
#             <!--F/-->
#             <div class="gh-flyout__dialog" id="s0-1-4-9-12-1-0-dialog">
#              <div class="gh-flyout__box">
#               <!--F#4-->
#               <div class="gh-cart__dialog">
#                <div class="gh-flyout-loading gh-cart__loading">
#                 <span aria-label="Loading..." class="progress-spinner progress-spinner--large gh-flyout-loading__spinner" role="img">
#                  <svg aria-hidden="true" class="icon icon--30" focusable="false">
#                   <defs>
#                    <symbol fill="none" id="icon-spinner-30" viewbox="0 0 24 24">
#                     <path clip-rule="evenodd" d="M12 2C10.0222 2 8.08879 2.58649 6.4443 3.6853C4.79981 4.78412 3.51809 6.3459 2.76121 8.17317C2.00433 10.0004 1.8063 12.0111 2.19215 13.9509C2.578 15.8907 3.53041 17.6725 4.92894 19.0711C6.32746 20.4696 8.10929 21.422 10.0491 21.8079C11.9889 22.1937 13.9996 21.9957 15.8268 21.2388C17.6541 20.4819 19.2159 19.2002 20.3147 17.5557C21.4135 15.9112 22 13.9778 22 12C22 11.4477 22.4477 11 23 11C23.5523 11 24 11.4477 24 12C24 14.3734 23.2962 16.6935 21.9776 18.6668C20.6591 20.6402 18.7849 22.1783 16.5922 23.0866C14.3995 23.9948 11.9867 24.2324 9.65892 23.7694C7.33115 23.3064 5.19295 22.1635 3.51472 20.4853C1.83649 18.8071 0.693605 16.6689 0.230582 14.3411C-0.232441 12.0133 0.00519943 9.60051 0.913451 7.4078C1.8217 5.21509 3.35977 3.34094 5.33316 2.02236C7.30655 0.703788 9.62663 0 12 0C12.5523 0 13 0.447715 13 1C13 1.55228 12.5523 2 12 2Z" fill="var(--color-spinner-icon-background, #3665F3)" fill-rule="evenodd">
#                     </path>
#                     <path clip-rule="evenodd" d="M14.1805 1.17194C14.3381 0.642616 14.895 0.341274 15.4243 0.498872C17.3476 1.07149 19.0965 2.11729 20.5111 3.54055C21.9257 4.96382 22.9609 6.71912 23.5217 8.64584C23.6761 9.17611 23.3714 9.73112 22.8411 9.88549C22.3108 10.0399 21.7558 9.73512 21.6015 9.20485C21.134 7.59925 20.2715 6.13651 19.0926 4.95045C17.9138 3.76439 16.4563 2.8929 14.8536 2.41572C14.3243 2.25812 14.0229 1.70126 14.1805 1.17194Z" fill="var(--color-spinner-icon-foreground, #E5E5E5)" fill-rule="evenodd">
#                     </path>
#                    </symbol>
#                   </defs>
#                   <use href="#icon-spinner-30">
#                   </use>
#                  </svg>
#                 </span>
#                 <span>
#                  Loading...
#                 </span>
#                </div>
#                <div data-marko-key="@dynamic s0-1-4-9-12-1" id="gh-minicart-hover-body">
#                </div>
#               </div>
#               <!--F/-->
#              </div>
#             </div>
#            </div>
#            <!--globalheaderweb/-->
#           </div>
#          </div>
#         </nav>
#         <section class="gh-header__main" data-marko-key="@gh-main s0-1-4">
#          <div class="gh-header__logo-cats-wrap">
#           <a _sp="m570.l2586" class="gh-logo" href="https://www.ebay.co.uk" tabindex="2">
#            <svg aria-labelledby="ebayLogoTitle" height="48" id="gh-logo" viewbox="0 0 122 48.592" width="117" xmlns="http://www.w3.org/2000/svg">
#             <title id="ebayLogoTitle">
#              eBay Home
#             </title>
#             <g>
#              <path d="M24.355 22.759c-.269-5.738-4.412-7.838-8.826-7.813-4.756.026-8.544 2.459-9.183 7.915zM6.234 26.93c.364 5.553 4.208 8.814 9.476 8.785 3.648-.021 6.885-1.524 7.952-4.763l6.306-.035c-1.187 6.568-8.151 8.834-14.145 8.866C4.911 39.844.043 33.865-.002 25.759c-.05-8.927 4.917-14.822 15.765-14.884 8.628-.048 14.978 4.433 15.033 14.291l.01 1.625z" fill="#F02D2D">
#              </path>
#              <path d="M46.544 35.429c5.688-.032 9.543-4.148 9.508-10.32s-3.947-10.246-9.622-10.214-9.543 4.148-9.509 10.32 3.974 10.245 9.623 10.214zM30.652.029l6.116-.034.085 15.369c2.978-3.588 7.1-4.65 11.167-4.674 6.817-.037 14.412 4.518 14.468 14.454.045 8.29-5.941 14.407-14.422 14.454-4.463.026-8.624-1.545-11.218-4.681a33.237 33.237 0 01-.19 3.731l-5.994.034c.09-1.915.185-4.364.174-6.322z" fill="#0968F6">
#              </path>
#              <path d="M77.282 25.724c-5.548.216-8.985 1.229-8.965 4.883.013 2.365 1.94 4.919 6.7 4.891 6.415-.035 9.826-3.556 9.794-9.289v-.637c-2.252.02-5.039.054-7.529.152zm13.683 7.506c.01 1.778.071 3.538.232 5.1l-5.688.032a33.381 33.381 0 01-.225-3.825c-3.052 3.8-6.708 4.909-11.783 4.938-7.532.042-11.585-3.915-11.611-8.518-.037-6.665 5.434-9.049 14.954-9.318 2.6-.072 5.529-.1 7.945-.116v-.637c-.026-4.463-2.9-6.285-7.854-6.257-3.68.021-6.368 1.561-6.653 4.2l-6.434.035c.645-6.566 7.53-8.269 13.595-8.3 7.263-.04 13.406 2.508 13.448 10.192z" fill="#FFBD14">
#              </path>
#              <path d="M91.939 19.852l-4.5-8.362 7.154-.04 10.589 20.922 10.328-21.02 6.486-.048-18.707 37.251-6.85.039 5.382-10.348-9.887-18.393" fill="#92C821">
#              </path>
#             </g>
#            </svg>
#           </a>
#           <!--globalheaderweb#s0-1-4-12-0-->
#           <div class="gh-categories">
#            <div class="gh-flyout is-left-aligned">
#             <!--F#2-->
#             <button aria-controls="s0-1-4-12-0-1-dialog" aria-expanded="false" aria-haspopup="true" class="gh-flyout__target" tabindex="3">
#              <!--F#10-->
#              <span class="gh-categories__title">
#               Shop by category
#              </span>
#              <!--F/-->
#              <!--F#11-->
#              <svg aria-hidden="true" class="gh-flyout__chevron icon icon--12" focusable="false" tabindex="-1">
#               <use href="#icon-chevron-down-12">
#               </use>
#              </svg>
#              <!--F/-->
#             </button>
#             <!--F/-->
#             <div class="gh-flyout__dialog" id="s0-1-4-12-0-1-dialog">
#              <div class="gh-flyout__box">
#               <!--F#4-->
#               <!--F/-->
#              </div>
#             </div>
#            </div>
#           </div>
#           <!--globalheaderweb/-->
#          </div>
#          <form action="https://www.ebay.co.uk/sch/i.html" class="gh-search" id="gh-f" method="get" target="_top">
#           <div class="gh-search-box__wrap" id="gh-search-box">
#            <div class="gh-search__wrap">
#             <!--globalheaderweb#s0-1-4-13-4-->
#             <div class="gh-search-input__wrap" id="gh-ac-wrap">
#              <input aria-autocomplete="list" aria-expanded="false" aria-haspopup="true" aria-label="Search for anything" autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-search-input gh-tb ui-autocomplete-input" data-marko='{"oninput":"handleTextUpdate s0-1-4-13-4 false","onfocusin":"handleMarkTimer s0-1-4-13-4 false","onkeydown":"handleMarkTimer s0-1-4-13-4 false"}' data-marko-key="@input s0-1-4-13-4" id="gh-ac" maxlength="300" name="_nkw" placeholder="Search for anything" role="combobox" size="50" spellcheck="false" tabindex="4" title="Search" type="text"/>
#              <!--globalheaderweb#s0-1-4-13-4-1-0-->
#              <svg aria-hidden="true" class="gh-search-input__icon icon icon--16" data-marko-key="@svg s0-1-4-13-4-1-0" focusable="false">
#               <defs data-marko-key="@defs s0-1-4-13-4-1-0">
#                <symbol id="icon-search-16" viewbox="0 0 16 16">
#                 <path d="M3 6.5a3.5 3.5 0 1 1 7 0 3.5 3.5 0 0 1-7 0Zm11.76 6.85-.021-.01-3.71-3.681-.025-.008A5.465 5.465 0 0 0 12 6.5 5.5 5.5 0 1 0 6.5 12a5.47 5.47 0 0 0 3.118-.972l3.732 3.732a1 1 0 0 0 1.41-1.41Z">
#                 </path>
#                </symbol>
#               </defs>
#               <use href="#icon-search-16">
#               </use>
#              </svg>
#              <!--globalheaderweb/-->
#              <!--globalheaderweb^s0-1-4-13-4-@clear s0-1-4-13-4 @clear-->
#              <button aria-label="Clear search" class="gh-search-input__clear-btn icon-btn icon-btn--transparent icon-btn--small" data-ebayui="" data-marko='{"onclick":"handleClick s0-1-4-13-4-@clear false","onkeydown":"handleKeydown s0-1-4-13-4-@clear false","onfocus":"handleFocus s0-1-4-13-4-@clear false","onblur":"handleBlur s0-1-4-13-4-@clear false"}' type="button">
#               <!--globalheaderweb#s0-1-4-13-4-@clear-1-2-0-->
#               <svg aria-hidden="true" class="gh-search-input__clear-icon icon icon--16" data-marko-key="@svg s0-1-4-13-4-@clear-1-2-0" focusable="false">
#                <defs data-marko-key="@defs s0-1-4-13-4-@clear-1-2-0">
#                 <symbol id="icon-clear-16" viewbox="0 0 16 16">
#                  <path d="M8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0Zm3.71 10.29a1 1 0 1 1-1.41 1.41L8 9.41l-2.29 2.3A1 1 0 0 1 4.3 10.3L6.59 8l-2.3-2.29a1.004 1.004 0 0 1 1.42-1.42L8 6.59l2.29-2.29a1 1 0 0 1 1.41 1.41L9.41 8l2.3 2.29Z">
#                  </path>
#                 </symbol>
#                </defs>
#                <use href="#icon-clear-16">
#                </use>
#               </svg>
#               <!--globalheaderweb/-->
#              </button>
#              <!--globalheaderweb/-->
#             </div>
#             <!--globalheaderweb/-->
#             <!--globalheaderweb#s0-1-4-13-5-->
#             <select aria-label="Select a category for search" class="gh-search-categories" data-marko='{"onchange":"handleCategorySelect s0-1-4-13-5 false"}' id="gh-cat" name="_sacat" size="1" tabindex="5">
#              <option value="0">
#               All Categories
#              </option>
#             </select>
#             <!--globalheaderweb/-->
#            </div>
#           </div>
#           <input name="_from" type="hidden" value="R40"/>
#           <input name="_trksid" type="hidden" value="m570.l1313"/>
#           <!--globalheaderweb#s0-1-4-13-8-->
#           <div class="gh-search-button__wrap">
#            <!--globalheaderweb^s0-1-4-13-8-@btn s0-1-4-13-8 @btn-->
#            <button class="gh-search-button btn btn--primary" data-ebayui="" data-marko='{"onclick":"handleClick s0-1-4-13-8-@btn false","onkeydown":"handleKeydown s0-1-4-13-8-@btn false","onfocus":"handleFocus s0-1-4-13-8-@btn false","onblur":"handleBlur s0-1-4-13-8-@btn false"}' id="gh-search-btn" role="button" tabindex="6" type="submit" value="Search">
#             <span class="gh-search-button__label">
#              Search
#             </span>
#             <!--globalheaderweb#s0-1-4-13-8-@btn-7-2-0-->
#             <svg aria-hidden="true" class="gh-search-button__icon icon icon--24" data-marko-key="@svg s0-1-4-13-8-@btn-7-2-0" focusable="false">
#              <defs data-marko-key="@defs s0-1-4-13-8-@btn-7-2-0">
#               <symbol id="icon-search-24" viewbox="0 0 24 24">
#                <path d="M3 10a7 7 0 1 1 14 0 7 7 0 0 1-14 0Zm19.703 11.29-5.67-5.67-.008-.003A8.954 8.954 0 0 0 19 10a9 9 0 0 0-9-9 9 9 0 0 0-9 9 9 9 0 0 0 9 9 8.958 8.958 0 0 0 5.66-2.007l5.663 5.717c.19.187.445.292.71.29a1 1 0 0 0 .67-1.71Z">
#                </path>
#               </symbol>
#              </defs>
#              <use href="#icon-search-24">
#              </use>
#             </svg>
#             <!--globalheaderweb/-->
#            </button>
#            <!--globalheaderweb/-->
#            <a _sp="m570.l2614" class="gh-search-button__advanced-link" href="https://www.ebay.co.uk/sch/ebayadvsearch" tabindex="7">
#             Advanced
#            </a>
#           </div>
#           <!--globalheaderweb/-->
#          </form>
#         </section>
#        </header>
#       </div>
#       <div class="widgets-placeholder" id="widgets-placeholder">
#       </div>
#       <!--globalheaderweb/-->
#       <div class="ghw" id="glbfooter" style="display:none">
#        <!--globalheaderweb#s0-1-5-1-->
#        <!--globalheaderweb/-->
#        <!--globalheaderweb#s0-1-5-2-0-->
#        <!--globalheaderweb/-->
#       </div>
#       <!-- ghw_reverted -->
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--vertlandweb^s0-1-0-33 s0-1-0 33-->
#   <div aria-modal="true" class="lightbox-dialog vl-iframe-modal lightbox-dialog--mask-fade" data-testid="vl-iframe-modal" hidden="" role="dialog">
#    <div class="lightbox-dialog__window lightbox-dialog__window--animate">
#     <!--F#9-->
#     <!--F/-->
#     <div class="lightbox-dialog__header">
#      <!--F#14-->
#      <button class="icon-btn lightbox-dialog__close" type="button">
#       <svg aria-hidden="true" class="icon icon--16" focusable="false">
#        <defs>
#         <symbol id="icon-close-16" viewbox="0 0 16 16">
#          <path d="M2.293 2.293a1 1 0 0 1 1.414 0L8 6.586l4.293-4.293a1 1 0 1 1 1.414 1.414L9.414 8l4.293 4.293a1 1 0 0 1-1.414 1.414L8 9.414l-4.293 4.293a1 1 0 0 1-1.414-1.414L6.586 8 2.293 3.707a1 1 0 0 1 0-1.414Z">
#          </path>
#         </symbol>
#        </defs>
#        <use href="#icon-close-16">
#        </use>
#       </svg>
#      </button>
#      <!--F/-->
#     </div>
#     <div class="lightbox-dialog__main">
#      <!--F#16-->
#      <!--F#1-->
#      <iframe class="vl-iframe-modal__iframe" title="VLP Iframe">
#      </iframe>
#      <!--F/-->
#      <!--F/-->
#     </div>
#    </div>
#   </div>
#   <!--vertlandweb/-->
#   <div hidden="">
#    <svg>
#     <symbol id="hp-icon-save-filled-16" viewbox="0 0 16 16">
#      <path d="M6.552 1.483c.48.244.96.588 1.448 1.053.489-.465.968-.81 1.448-1.053A4.409 4.409 0 0 1 11.5 1c1.55 0 2.709.634 3.461 1.554C15.688 3.443 16 4.55 16 5.5c0 .918-.348 1.711-.704 2.292a7.23 7.23 0 0 1-.978 1.237c-4.201 4.335-4.913 5.014-5.628 5.695l-.01.01a.997.997 0 0 1-1.36 0l-.01-.01c-.715-.681-1.426-1.36-5.628-5.695a7.228 7.228 0 0 1-.978-1.237C.348 7.212 0 6.418 0 5.5c0-.95.311-2.057 1.039-2.946C1.79 1.634 2.95 1 4.5 1c.625 0 1.311.107 2.052.483Z">
#      </path>
#     </symbol>
#     <symbol id="hp-icon-save-16" viewbox="0 0 16 16">
#      <path clip-rule="evenodd" d="M8 2.536a6.136 6.136 0 0 0-1.448-1.053A4.409 4.409 0 0 0 4.5 1c-1.55 0-2.709.634-3.461 1.554C.31 3.443 0 4.55 0 5.5c0 .918.348 1.711.704 2.292.36.586.77 1.023.978 1.237 4.193 4.327 4.91 5.011 5.624 5.691a.996.996 0 0 0 1.388 0c.714-.68 1.43-1.364 5.624-5.69a7.23 7.23 0 0 0 .978-1.238c.356-.58.704-1.374.704-2.292 0-.95-.312-2.057-1.039-2.946C14.21 1.634 13.05 1 11.5 1c-.625 0-1.311.107-2.052.483-.48.244-.96.588-1.448 1.053Zm-.778 2.093c-.635-.753-1.155-1.15-1.574-1.362A2.412 2.412 0 0 0 4.5 3c-.95 0-1.541.366-1.914.82A2.73 2.73 0 0 0 2 5.5c0 .415.161.842.409 1.246.245.398.535.711.71.891 2.97 3.065 4.183 4.289 4.881 4.974.698-.685 1.912-1.91 4.882-4.974.174-.18.464-.493.71-.891.247-.404.408-.83.408-1.246a2.73 2.73 0 0 0-.586-1.68C13.04 3.367 12.45 3 11.5 3c-.375 0-.739.06-1.148.267-.42.213-.94.609-1.574 1.362a.998.998 0 0 1-1.208.274.994.994 0 0 1-.348-.274Z" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="hp-icon-overflow-vertical-16" viewbox="0 0 16 16">
#      <path d="M8 4.5a1.5 1.5 0 1 0 0-3 1.5 1.5 0 0 0 0 3Zm0 10a1.5 1.5 0 1 0 0-3 1.5 1.5 0 0 0 0 3ZM9.5 8a1.5 1.5 0 1 1-3 0 1.5 1.5 0 0 1 3 0Z">
#      </path>
#     </symbol>
#     <symbol id="hp-icon-help-16" viewbox="0 0 16 16">
#      <path d="M9 14a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z">
#      </path>
#      <path clip-rule="evenodd" d="M6.872 3.178c-.384.154-.743.43-.902 1.065a1 1 0 1 1-1.94-.486c.342-1.366 1.232-2.089 2.099-2.435C6.934 1 7.716 1 7.987 1H8c.96 0 1.929.317 2.677.898C11.435 2.488 12 3.386 12 4.5c0 1.319-.523 2.206-1.273 2.872a7.984 7.984 0 0 1-1.097.79 44.72 44.72 0 0 1-.366.224L9 8.548V10a1 1 0 1 1-2 0V8a1 1 0 0 1 .446-.832c.274-.183.562-.359.82-.516l.307-.189c.342-.212.61-.394.825-.585C9.773 5.544 10 5.18 10 4.5c0-.386-.185-.738-.551-1.023A2.411 2.411 0 0 0 8 3c-.24 0-.696.006-1.128.178Z" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="hp-icon-help-24" viewbox="0 0 24 24">
#      <path d="M13 21a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z">
#      </path>
# ...
#     if(!ch) {document.getElementById("ghw-static-footer").removeAttribute("style");}})();
#       </script>
#       <!-- RcmdId Footer,RlogId t6diiebinbbacut%60ddlkr%3D9bjhadjofdbbqrce%60jhs.0%3F1%3Bgbc6%3Ce*w%60ut271*rqhmt-198c9472556-0x4 -->
#       <!-- SiteId: 0, Environment: production, AppName: globalheaderweb, PageId: 4479693 -->
#       <!-- ghw_reverted -->
#      </div>
#     </div>
#    </div>
#   </div>
#   <script crossorigin="" src="https://ir.ebaystatic.com/rs/c/globalheaderweb/runtime.6e0b9303.js" type="text/javascript">
#   </script>
#   <script crossorigin="" src="https://ir.ebaystatic.com/rs/c/globalheaderweb/index_lcNW.30e2b1df.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $mwp_globalheaderweb="https://ir.ebaystatic.com/rs/c/globalheaderweb/";$globalheaderweb_C=(window.$globalheaderweb_C||[]).concat({"o":{"g":{"gh_lang":"en-GB","gh_siteid":3,"gh_pageid":"4432023","gh_searchAutocomplete":{"acNoSuggestions":"No suggestions","acHideSuggestions":"Hide eBay suggestions","acShowSuggestions":"Show search suggestions","acPopularProducts":"Popular products","acSuggCategory":"{suggestion} <u>–\u003C/u> <i>{category}\u003C/i>","acCatalog":"<a href=\"https://www.ebay.co.uk/ctg/?_pid=#P#&amp;_trksid=\"/>","acAllCategories":"All categories","acViewAllSaved":"<a href=\"/mye/myebay/savedsearches\">View all saved<em>>\u003C/em>\u003C/a>","acSuggCategoryIn":"{suggestion} <u>–\u003C/u> <u>in\u003C/u> <i>{category}\u003C/i>","acSuggCategorySaved":"\"{suggestion} <u>in\u003C/u> <i>{category}\u003C/i><em>|\u003C/em> <span>Saved\u003C/span>","acSuggSaved":"{suggestion} <span>Saved\u003C/span>","acSuggCategoryRecent":"{suggestion} <u>in\u003C/u> <i>{category}\u003C/i><em>|\u003C/em> <span>Recent\u003C/span>","acSuggRecent":"{suggestion} <span>Recent\u003C/span>","acSuggStore":"{suggestion} <u>–\u003C/u> <u>in\u003C/u><i>eBay Shops\u003C/i>","acSuggCategoryInAria":"{suggestion}in {category}","acViewAllSavedAria":"View all saved","acHedSavedSearch":"Saved searches","acHedSavedSeller":"Saved sellers","acHedRecentSearch":"Recent searches","acHedPopularSearch":"Popular searches","acResultsAccessibility":"{count} results available; to navigate, use up and down arrow keys or swipe left and right on touch devices.","acNewnessIndicator":"new results available."},"gh_content":{"greetingSignedOutUnrecognized":"Hello. <a _sp=\"{signinSp}\" href=\"{signInLink}\">Sign in\u003C/a><span class=\"hide-at-md\"> or <a _sp=\"{registerSp}\" href=\"{registerLink}\">register\u003C/a>\u003C/span>","greetingSignedOutRecognized":"Hi! (<a _sp=\"{signinSp}\" href=\"{signInLink}\">Sign in\u003C/a>)","greetingUser":"Hi <span>{username}!\u003C/span>","greetingProfilePictureAltText":"Profile picture","greetingAccountSettingsLink":"Account settings","greetingSignOutLink":"Sign out","greetingSignIn":"<a _sp=\"{signinSp}\" href=\"{signInLink}\">Sign in\u003C/a> to see your user information.","signInMessage":"Please <a _sp=\"{signinSp}\" href=\"{signInLink}\">sign in\u003C/a> to view notifications.","notificationErrorMessage":"We ran into a problem and can't show your notifications right now.","flyoutGenericError":"There was an error. Please try again later.","watchlist":"Watch List","loading":"Loading...","cartEmpty":"Your shopping basket is empty","cartFull":"Your shopping basket contains {cartCount} items","AR":"Argentina","AU":"Australia","AT":"Austria","BY":"Belarus","BE":"Belgium","BO":"Bolivia","BR":"Brazil","CA":"Canada","CL":"Chile","CN":"China","CO":"Colombia","CR":"Costa Rica","DO":"Dominican Republic","EC":"Ecuador","SV":"El Salvador","FR":"France","DE":"Germany","GT":"Guatemala","HN":"Honduras","HK":"Hong Kong","IN":"India","IE":"Ireland","IL":"Israel","IT":"Italy","JP":"Japan","KZ":"Kazakhstan","KR":"Korea","MY":"Malaysia","MX":"Mexico","NL":"Netherlands","NZ":"New Zealand","NI":"Nicaragua","PA":"Panama","PY":"Paraguay","PE":"Peru","PH":"Philippines","PL":"Poland","PT":"Portugal","PR":"Puerto Rico","RU":"Russia","SG":"Singapore","ES":"Spain","CH":"Switzerland","TW":"Taiwan","TR":"Turkey","GB":"United Kingdom","UY":"Uruguay","US":"United States","VE":"Venezuela","star_1":"Yellow star for Feedback score from 10 to 49","star_2":"Blue star for Feedback score from 50 to 99","star_3":"Turquoise star for Feedback score from 100 to 499","star_4":"Purple star for Feedback score from 500 to 999","star_5":"Red star for Feedback score from 1,000 to 4,999","star_6":"Green star for Feedback score from 5,000 to 9,999","star_7":"Yellow shooting star for Feedback score from 10,000 to 24,999","star_8":"Turquoise shooting star for Feedback score from 25,000 to 49,999","star_9":"Purple shooting star for Feedback score from 50,000 to 99,999","star_10":"Red sh ...
#   </script>
#   <script>
#    /* ssgST: excluded from sampling */
#   </script>
#   <!--vertlandweb^s0-1-0-73 s0-1-0 73-->
#   <div class="vl-fsom-banner">
#   </div>
#   <!--vertlandweb/-->
#   <div id="afvertlandweb0" style="display:none">
#    <noscript id="afvertlandwebph2">
#    </noscript>
#   </div>
#   <div id="afvertlandweb1" style="display:none">
#    <script>
#     window._NUTS_CORR_ID_STORE = Object.assign(window._NUTS_CORR_ID_STORE||{},{"ads_platform_all_ads":"01K34NAVJ9KCBJC23HYP30K251"})
#    </script>
#    <noscript id="afvertlandwebph3">
#    </noscript>
#   </div>
#   <div id="afvertlandwebtracking" style="display:none">
#    <script type="text/javascript">
#     window.HL_PAGE_TRACKING = [{"eventFamily":"VERTLAND","eventAction":"VIEWDTLS","operationId":"4375194","flushImmediately":false,"eventProperty":{"parentrq":"c9556dfe1980ab1fbab669bdffe25072","audience":"general","pageci":"aca67c6f-7e0a-11f0-9239-6229b4efe979","vlpname":"vlp_homepage"}},{"eventFamily":"VERTLAND","eventAction":"CLIENT_PAGE_VIEW","operationId":"4375194","flushImmediately":false,"eventProperty":{"parentrq":"c9556dfe1980ab1fbab669bdffe25072","audience":"general","pageci":"aca67c6f-7e0a-11f0-9239-6229b4efe979","vlpname":"vlp_homepage"},"clientImpressionPageId":"4445145"},{"eventFamily":"VERTLAND","eventAction":"VIEWPORT","operationId":"4375194","flushImmediately":false,"eventProperty":{"parentrq":"c9556dfe1980ab1fbab669bdffe25072","audience":"general","pageci":"aca67c6f-7e0a-11f0-9239-6229b4efe979","vlpname":"vlp_homepage"},"clientImpressionPageId":"4445145"}];
#           window.vlServiceTime = 195;
#    </script>
#    <script crossorigin="" src="https://ir.ebaystatic.com/cr/v/c1/ebay-cookies/6.js">
#    </script>
#    <script type="text/javascript">
#     (function(scope) {var trackingInfo = {"X_EBAY_C_CORRELATION_SESSION":"si=c9556dff1980ab1fbab10926ff93e7f8,c=1,operationId=4375194,trk-gflgs=wA**"};scope.trkCorrelationSessionInfo={};scope.trkCorrelationSessionInfo.getTrackingInfo=function(){return trackingInfo;};scope.trkCorrelationSessionInfo.getTrackingCorrelationSessionInfo=function(){return trackingInfo.X_EBAY_C_CORRELATION_SESSION};})(window)
#    </script>
#    <script type="text/javascript">
#     if(typeof raptor !== "undefined" && raptor.require){var Uri=raptor.require("ebay/legacy/utils/Uri");$uri=function(href){return new Uri(href);};window.raptor.extend(window.raptor, require("ebay/legacy/adaptor-utils"));}
#    </script>
#    <script crossorigin="" id="taasHeaderRes" src="https://ir.ebaystatic.com/cr/v/c01/250687670C46D48A7E4E.js" type="text/javascript">
#    </script>
#    <script id="taasContent" type="text/javascript">
#     try {new window.TaaSTrackingCore({"psi":"AVW5OH40*","rover":{"imp":"/roverimp/0/0/9","clk":"/roverclk/0/0/9","uri":"https://rover.ebay.co.uk"},"pid":"p4375194"});
# var _plsubtInp={"eventFamily":"DFLT","samplingRate":100, "pageLoadTime": new Date().getTime(), "pageId":4375194, "app":"Testapp", "disableImp":true};var _plsUBTTQ=[];var TaaSIdMapTrackerObj = new TaaSIdMapTracker();TaaSIdMapTrackerObj.roverService("https://rover.ebay.co.uk/idmap/0?footer");} catch (err) { console && console.log && console.log(err); }
#    </script>
#    <script crossorigin="" id="taasFooterRes" src="https://ir.ebaystatic.com/cr/v/c01/250701JZ48C6XWVCKCN2.js" type="text/javascript">
#    </script>
#   </div>
#   <div id="afvertlandweb2" style="display:none">
#   </div>
#   <div id="afvertlandweb3" style="display:none">
#   </div>
#   <script>
#    function $afvertlandweb(d,a,e,l,g,h,k,b,f,c){c=$afvertlandweb;if(a&&!c[a])(c[a+="$"]||(c[a]=[])).push(d);else{e=document;l=e.getElementById("afvertlandweb"+d);g=e.getElementById("afvertlandwebph"+d);h=e.createDocumentFragment();k=l.childNodes;b=0;for(f=k.length;b<f;b++)h.appendChild(k.item(0));g&&g.parentNode.replaceChild(h,g);c[d]=1;if(a=c[d+"$"])for(b=0,f=a.length;b<f;b++)c(a[b])}};$afvertlandweb(0);$afvertlandweb(1);$afvertlandweb("tracking");$afvertlandweb(2);$afvertlandweb(3);$vertlandweb_C=(window.$vertlandweb_C||[]).concat({"o":{"l":1,"g":{"ENABLE_VLP_HP_WATCH_LIST_FAVORITE_UI":false,"watchlistInfo":{"localizedContent":{"loading":"Loading","error":"Something went wrong. Please try again."},"apiSettings":{"hostname":"www.ebay.co.uk","addToWatchCSRFToken":"01000a0000005055ffe9d8692c7ac28fe82824b779e10b6c900de6575488a5ea0f2839016feaa4018f7bba204ae3d9c25cc4014188c653ee48d08d494cc32d90c2f21a0ac2abed4fb4ff9f5a14b00511c8f701e1e55dcd","removeFromWatchCSRFToken":"01000a000000500b359fd7b94717c1af3007c5854754dc6d7a8beb03a95da851efa5b15d73e24a9c3658bae872b328d859d0cfaf49962ee9040176ded740b4101cf17e3f635d6067e02acaf9d90376f5a46df12ff3d4ae"}},"ENABLE_EVO_CAROUSEL":true,"ENABLE_PAGE_GRID":true,"carouselDefaultA11yContent":{"play":"Play slideshow","pause":"Pause slideshow","previous":"Go to previous slide","next":"Go to next slide"},"VIDEO_CAROUSEL_CONFIG":{},"corrRequestId":"c9556dfe1980ab1fbab669bdffe25072","IMAGE_HOVER_ANIMATION":false,"ENABLE_BANNER_TEXT_ANIMATION":false,"FILL_ITEM_IMAGE":true,"imgResolutions":{"MIN_RES":"500","MAX_RES":"500"},"QV_OPTIONS":{"ENABLE_ITEM_QUICK_VIEW":false,"itemQuickViewEndpoint":null,"itemQuickViewCacheEnabled":false,"itemQuickViewRecsEnabled":false},"ENABLE_DIC_SLOT_3_GROUP":true,"signInPageUrl":"https://signin.ebay.co.uk/ws/eBayISAPI.dll?SignIn&UsingSSL=1&siteid=3&co_partnerId=2&pageType=4432023&ru=https%3A%2F%2Fvertlandweb60.vip.ebay.co.uk%2F","text":{"loggedOutNotice":"You've signed out. See you again soon.","loggedOutFeedbackWithLink":"How was your experience? <a href=\"https://qu.ebay.co.uk/survey?srvName=mobileweb%20(mobileweb-UK)\">Leave Feedback\u003C/a>","signInAgainLink":"<a href=\"https://signin.ebay.co.uk/ws/eBayISAPI.dll?SignIn&amp;srcAppId=3564&amp;ru=https%3A%2F%2Fwww.ebay.co.uk\">Sign in again\u003C/a>","open":"Open","close":"Close","registerLiveEventError":"We had trouble setting an alert. Please try again later.","recentlyViewedTitle":"Recently viewed","dealsTitle":"Today's deals","watchedItemsTitle":"Watched items","piyiTitle":"Picks for you","setReminderText":"Set reminder for event","removeReminderText":"Remove reminder for event"},"isIos":false,"openInNewTab":true,"siteId":3,"consumerId":"urn:ebay-marketplace-consumerid:22bf24f0-c570-4811-9ee1-9983d07c0a8b","manifestId":"vertlandweb-21.6.1_2025081922511294","thirdPartyAdsPlacementIds":["100712","100713","100716","100765","102200"],"isMobileLayout":false,"displayWidth":-1,"isHomepage":true},"w":[["s0-1-0-26-10",0,{"model":{"_type":"BANNER","containers":[{"_type":"CardContainer","cards":[{"_type":"ThirdPartyAd","placementId":"100713"}]}],"trackingInfo":{"moduleInstance":"mi:4816|iid:1","parentrq":"c9556dfe1980ab1fbab669bdffe25072","trackViews":"true","trackPerf":"true"},"meta":{"name":"THIRD_PARTY_NATIVE_PUSHDOWN","trackingList":[{"eventFamily":"VERTLAND","eventAction":"VIEW","operationId":"4375194","flushImmediately":false,"eventProperty":{"parentrq":"c9556dfe1980ab1fbab669bdffe25072","pageci":"aca67c6f-7e0a-11f0-9239-6229b4efe979","moduledtl":"mi:4816|c:1|iid:1|luid:1","vlpname":"vlp_homepage"}}]},"__uxComponentName":"THIRD_PARTY_NATIVE_PUSHDOWN"},"openText":"Open","closeText":"Close"},{"f":1}],["s0-1-0-53-1-2-4-18[0[0]]",1,{"model":{"modules":[null,{"_type":"MadronaGenericModule","cards":[{"_type":"COLOR_BLOCK_BANNER","placementid":"100000","campaignId":"5899321622003802311","campaignName":"UK_Live_Fashion_2025|Q3_UK_25_TotalFashion_PollySayer_W34_Aug2|5899321622003802311","messageId":"5899321622003802311","creatives":[{"c ...
#   </script>
#  </body>
# </html>
# <!--vertlandweb/-->
# <!-- RcmdId vertlandweb_homepage,RlogId t6u%60tsodhct%60d13fiiw%3F%3Cqfwrkbkbpfg07%60jhs.3%3Fde3%602%3Afb*w%60ut261*60woe-198c9556e07-0x202 -->
# <!-- SiteId: 3, Environment: production, AppName: vertlandweb, PageId: 4432023 -->

# %% [markdown]
# ### Turning a webpage into data using BeautifulSoup: getting the text

# %% [markdown]
# In this exercise, you'll figure out how to extract the text from the BDFL's webpage, along with printing the webpage's title.

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
url = 'https://www.ebay.co.uk'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extract the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Get the title of eBay's webpage: ebay_title
ebay_title = soup.title

# Print the title of eBay's webpage to the shell
print(ebay_title)

# Get eBay's text: ebay_text
ebay_text = soup.get_text()

# Print eBay's text to the shell
print(ebay_text)
# Out:
# <title>eBay UK | Electronics, Cars, Fashion, Collectibles &amp; More</title>
# eBay UK | Electronics, Cars, Fashion, Collectibles & MoreOpenExpand SvgSkip to main contentHi !Hello. Sign in or registerLocalDaily DealsFashionHelp & ContactSellWatch ListExpand watch listMy eBayExpand My eBaySummaryRecently ViewedBids/OffersWatch ListPurchase HistorySellingSaved feedSaved SearchesSaved SellersMy GarageSizesMessagesExpand NotificationsPlease sign in to view notifications.Expand BasketLoading...eBay HomeShop by categoryAll CategoriesSearchAdvancedSavedHomeExpand: HomeTop CategoriesCook & dineBeddingRugs & carpetsHome decorLightingFurnitureSofas, armchairs & couchesBeds & mattressesMore CategoriesBedroomLiving roomKitchenDining roomBetter than new homewarePet suppliesGroceryToysGarden & DIYExpand: Garden & DIYDIYHome decoratingPower toolsBathroom & showersHand toolsKitchen units & setsHeating, cooling & airBuilding & hardwareCentral heating & radiatorsGardenGarden & patioLawn mowersGarden power toolsGarden hand toolsGarden furniturePlant care & soilPlants, seeds & bulbsLandscaping & garden materialsElectronicsExpand: ElectronicsTop CategoriesAppliancesMobile phones & communicationComputing, tablets & networkingSound & visionVideo games & consolesHeating, cooling & airCameras & photographyHome entertainmentMore CategoriesLaptops & netbooksTVsTablets & eBook readersDesktops & all-in-onesPortable audio & headphonesHome audio & HiFi seperatesSmart home & surveillanceSmartwatchesRefurbishedExpand: RefurbishedTop CategoriesComputingMobile phonesHaircareAppliancesAir qualityAudioFurnitureTVsShop by conditionCertifiedExcellentVery GoodGoodLearn about RefurbishedFashionExpand: FashionTop CategoriesWomen's fashionMen's fashionKids' and baby fashionSneakersLuxury handbagsShop A-Z brandsWhat is Authenticity Guarantee?What is the Pre-loved Partner Programme?Shop by brandSeasaltRiver IslandDorothy PerkinsPumaJordan sneakersadidas sneakersGucci handbagsLouis Vuitton handbagsJewellery & watchesExpand: Jewellery & watchesTop CategoriesLuxury watchesFine jewelleryFashion jewelleryWhat is Authenticity Guarantee?Shop by brandRolexOMEGATAG HeuerCartierTiffany & Co.ChopardErnest JonesMotorsExpand: MotorsTop CategoriesMy GarageVehicle parts & accessoriesMotoring deals & offersCertified Recycled partsTyre fittingeBay Assured FitParts & AccessoriesCar parts & accessoriesCar wheels, tyres & partsMotorcycle parts & accessoriesVehicle clothing, protection & merchandiseGarage equipment & toolsOils, fluids & lubricantsCaravan, campervan & motorhome partsCollectablesExpand: CollectablesTop CategoriesArtCoins & bullionCollectable card gamesComicsSports memorabiliaSports trading cardsStampsToys & gamesMore CategoriesModel trainsAntique furnitureAntique solid silverDiecast vehiclesLEGO®RC model vehiclesRole-playing gamesToy models & kitsSports & LeisureExpand: Sports & LeisureTop CategoriesSporting goodsFitness, running & yogaCyclingFishingGolfCamping & hikingEquestrianMusical instrumentsMore CategoriesSkiing & snowboardingRugbyFootballBoxingCanoeing & kayakingGuitarsPercussionPro-Audio EquipmentHealth & BeautyExpand: Health & BeautyHealthHealth careVitamins & dietary supplementsIndependent livingOral careNatural & alternative remediesVision careOther health & beautySports supplementsBeautyHair care & stylingMake-upNail care, manicure & pedicureFragrancesFacial skin careShaving & hair removalBath & bodySun care & tanningeBay LiveSmall BusinessesMore Expand: MoreHomeGarden & DIYElectronicsRefurbishedFashionJewellery & watchesMotorsCollectablesSports & LeisureHealth & BeautyeBay LiveSmall BusinessesStream eBay Live with Polly SayerBag Rat & Boa, Miu Miu, RIXO and more in the live auction.Don't miss out Don't miss out Up to 60% off laptops? You bet.Save big on brands you love with Refurbished on eBay.Shop now Shop now *vs RRP*vs RRPAppleLenovoDellAppleLenovoDellRotate your 'fits over (and over)Discover a world of fresh, stylish pieces for your wardrobe.Shop fashion Shop fashion Women'sMen'sKids'Women'sMen'sKids'Back to routine, back to savingsFrom ...
#
#
#
#
# Copyright © 1995-2025 eBay Inc. All Rights Reserved. User Agreement, Privacy, Payments Terms of Use, Cookies and AdChoice

# %% [markdown]
# ### Turning a webpage into data using BeautifulSoup: getting the hyperlinks

# %% [markdown]
# In this exercise, you'll figure out how to extract the URLs of the hyperlinks from the BDFL's webpage. In the process, you'll become close friends with the soup method find_all()

# %%
# import packages
import requests 
from bs4 import BeautifulSoup

#specify url
url = 'https://www.ebay.co.uk'

#package the request and catch the response r
r = requests.get(url)

# Extracts the response as html: html_doc
html_doc = r.text

# create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Print the title of eBay's webpage
print(soup.title)

# Find all 'a' tags (which define hyperlinks): a_tags
a_tags = soup.find_all('a')

# Print the URLs to the shell
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# <title>eBay UK | Electronics, Cars, Fashion, Collectibles &amp; More</title>
# #mainContent
# https://signin.ebay.co.uk/ws/eBayISAPI.dll?SignIn&sgfl=gh
# https://signup.ebay.co.uk/pa/crte
# https://www.ebay.co.uk/vlp/local
# https://www.ebay.co.uk/deals
# https://www.ebay.co.uk/b/bn_7000259675
# https://www.ebay.co.uk/help/home
# https://www.ebay.co.uk/sl/sell
# https://www.ebay.co.uk/mye/myebay/watchlist
# https://www.ebay.co.uk/mys/home?source=GBH
# https://www.ebay.co.uk/mye/myebay/summary
# https://www.ebay.co.uk/mye/myebay/rvi
# https://www.ebay.co.uk/mye/myebay/bidsoffers
# https://www.ebay.co.uk/mye/myebay/watchlist
# https://www.ebay.co.uk/mye/myebay/purchase
# https://www.ebay.co.uk/mys/home?CurrentPage=MyeBayAllSelling&ssPageName=STRK:ME:LNLK:MESX&source=GBH
# https://www.ebay.co.uk/mye/myebay/saved
# https://www.ebay.co.uk/mye/myebay/savedsearches
# https://www.ebay.co.uk/mye/myebay/savedsellers
# https://www.ebay.co.uk/g/mygarage
# https://www.ebay.co.uk/mysize/hub
# https://mesg.ebay.co.uk/mesgweb/ViewMessages/0
# https://signin.ebay.co.uk/ws/eBayISAPI.dll?SignIn&sgfl=nf&ru=
# https://cart.ebay.co.uk
# https://www.ebay.co.uk
# https://www.ebay.co.uk/sch/ebayadvsearch
# /mye/myebay/saved
# https://www.ebay.co.uk/b/bn_7000259670
# https://www.ebay.co.uk/b/bn_1842060
# https://www.ebay.co.uk/b/bn_1841055
# https://www.ebay.co.uk/b/bn_1632681
# https://www.ebay.co.uk/b/bn_1839832
# https://www.ebay.co.uk/b/bn_818588
# https://www.ebay.co.uk/b/bn_1633685
# https://www.ebay.co.uk/b/bn_1633911
# https://www.ebay.co.uk/b/bn_1632812
# https://www.ebay.co.uk/b/bn_7000259858
# https://www.ebay.co.uk/b/bn_7000259933
# https://www.ebay.co.uk/b/bn_7000259854
# https://www.ebay.co.uk/b/bn_7001217378
# https://www.ebay.co.uk/b/bn_7120889698
# https://www.ebay.co.uk/b/bn_1841771
# https://www.ebay.co.uk/b/bn_7115284177
# https://www.ebay.co.uk/b/bn_1841704
# https://www.ebay.co.uk/b/bn_1841446
# https://www.ebay.co.uk/b/bn_1838574
# https://www.ebay.co.uk/b/bn_2316369
# https://www.ebay.co.uk/b/bn_821820
# https://www.ebay.co.uk/b/bn_2316368
# https://www.ebay.co.uk/b/bn_1842006
# https://www.ebay.co.uk/b/bn_1839695
# https://www.ebay.co.uk/b/bn_1842092
# https://www.ebay.co.uk/b/bn_7117204214
# https://www.ebay.co.uk/b/bn_1841446
# https://www.ebay.co.uk/b/bn_1841782
# https://www.ebay.co.uk/b/bn_1841113
# https://www.ebay.co.uk/b/bn_7204986
# https://www.ebay.co.uk/b/bn_1838227
# https://www.ebay.co.uk/b/bn_7204983
# https://www.ebay.co.uk/b/bn_7204886
# https://www.ebay.co.uk/b/bn_7204994
# https://www.ebay.co.uk/b/bn_7000259660
# https://www.ebay.co.uk/b/bn_1841467
# https://www.ebay.co.uk/b/bn_1841703
# https://www.ebay.co.uk/b/bn_1838792
# https://www.ebay.co.uk/b/bn_1838178
# https://www.ebay.co.uk/b/bn_1841995
# https://www.ebay.co.uk/b/bn_1839695
# https://www.ebay.co.uk/b/bn_1839566
# https://www.ebay.co.uk/b/bn_7000259852
# https://www.ebay.co.uk/b/bn_1631140
# https://www.ebay.co.uk/b/bn_1839641
# https://www.ebay.co.uk/b/bn_450775
# https://www.ebay.co.uk/b/bn_1635224
# https://www.ebay.co.uk/b/bn_7025962239
# https://www.ebay.co.uk/b/bn_1838773
# https://www.ebay.co.uk/b/Smart-Home-Surveillance-Electronics/185066/bn_7025955880
# https://www.ebay.co.uk/b/bn_7117653182
# https://www.ebay.co.uk/b/bn_7117653182
# https://www.ebay.co.uk/e/special-events/roe-computing
# https://www.ebay.co.uk/e/_electronics/roe-mobile-smart-phones-2
# https://www.ebay.co.uk/e/_electronics/roe-haircare
# https://www.ebay.co.uk/e/special-events/roe-appliances
# https://www.ebay.co.uk/e/special-events/roe-air-quality
# https://www.ebay.co.uk/e/special-events/roe-audio
# https://www.ebay.co.uk/e/special-events/roe-furniture
# https://www.ebay.co.uk/e/special-events/roe-tvs
# https://www.ebay.co.uk/e/special-events/roe-certified
# https://www.ebay.co.uk/e/special-events/roe-excellent
# https://www.ebay.co.uk/e/special-events/roe-very-good
# https://www.ebay.co.uk/e/special-events/roe-good
# https://pages.ebay.co.uk/refurbished-hub/
# https://www.ebay.co.uk/vlp/fashion
# https://www.ebay.co.uk/vlp/womens-fashion
# https://www.ebay.co.uk/vlp/mens-fashion
# https://www.ebay.co.uk/b/bn_1632761
# https://www.ebay.co.uk/vlp/sneakers
# https://www.ebay.co.uk/vlp/handbags
# https://pages.ebay.co.uk/a-z-brand-directory/
# https://pages.ebay.co.uk/authenticity-guarantee/
# https://pages.ebay.co.uk/pre-loved-partner/
# https://www.ebay.co.uk/str/seasaltcornwallofficialoutlet
# https://www.ebay.co.uk/b/bn_21834140
# https://www.ebay.co.uk/e/fashion/dorothy-perkins-trusted-sellers
# https://www.ebay.co.uk/str/pumauk
# https://www.ebay.co.uk/e/special-events/jordan-spotlight-sneakers
# https://www.ebay.co.uk/e/special-events/adidas-spotlight-sneakers
# https://www.ebay.co.uk/e/fashion/gucci-handbags-ag
# https://www.ebay.co.uk/e/fashion/louis-vuitton-handbags-ag
# https://www.ebay.co.uk/b/bn_1838540
# https://www.ebay.co.uk/vlp/watches
# https://www.ebay.co.uk/b/bn_1841461
# https://www.ebay.co.uk/b/bn_1841104
#
# https://pages.ebay.co.uk/authenticity-guarantee/
# https://www.ebay.co.uk/e/special-events/ag-rolex
# https://www.ebay.co.uk/e/special-events/ag-omega
# https://www.ebay.co.uk/e/special-events/ag-tag-heuer
# https://www.ebay.co.uk/e/special-events/shop-fine-cartier
# https://www.ebay.co.uk/e/special-events/shop-fine-tiffany-co
# https://www.ebay.co.uk/e/special-events/shop-fine-chopard
# https://www.ebay.co.uk/str/ernestjonesofficial
# https://www.ebay.co.uk/vlp/motors
# https://www.ebay.co.uk/g/mygarage
# https://www.ebay.co.uk/b/bn_1838652
# https://www.ebay.co.uk/deals/automotive
# https://www.ebay.co.uk/b/bn_7118694781
# https://www.ebay.co.uk/b/bn_7121209158
# https://pages.ebay.co.uk/2023/ebay-assured-fit
# https://www.ebay.co.uk/b/bn_1528081
# https://www.ebay.co.uk/b/bn_875475
# https://www.ebay.co.uk/b/bn_1838394
# https://www.ebay.co.uk/b/bn_2315509
# https://www.ebay.co.uk/b/bn_1624265
# https://www.ebay.co.uk/b/bn_1635761
# https://www.ebay.co.uk/b/bn_2314597
# https://www.ebay.co.uk/b/bn_7000259665
# https://www.ebay.co.uk/b/bn_1839171
# https://www.ebay.co.uk/b/bn_1839238
# https://www.ebay.co.uk/b/bn_2316999
# https://www.ebay.co.uk/b/bn_1841088
# https://www.ebay.co.uk/b/bn_1838743
# https://www.ebay.co.uk/b/bn_55159883
# https://www.ebay.co.uk/b/bn_1841094
# https://www.ebay.co.uk/b/bn_1841704
# https://www.ebay.co.uk/b/bn_1635521
# https://www.ebay.co.uk/b/bn_1841457
# https://www.ebay.co.uk/b/bn_2316101
# https://www.ebay.co.uk/b/bn_1676972
# https://www.ebay.co.uk/b/bn_21829136
# https://www.ebay.co.uk/b/bn_1841711
# https://www.ebay.co.uk/b/bn_1842051
# https://www.ebay.co.uk/b/bn_1842061
# https://www.ebay.co.uk/b/bn_7000259669
# https://www.ebay.co.uk/b/bn_1838666
# https://www.ebay.co.uk/b/bn_1841074
# https://www.ebay.co.uk/b/bn_1669642
# https://www.ebay.co.uk/b/bn_1838600
# https://www.ebay.co.uk/b/bn_1839270
# https://www.ebay.co.uk/b/bn_1841706
# https://www.ebay.co.uk/b/bn_1841777
# https://www.ebay.co.uk/b/bn_1841127
# https://www.ebay.co.uk/b/bn_1841501
# https://www.ebay.co.uk/b/bn_1842032
# https://www.ebay.co.uk/b/bn_1842001
# https://www.ebay.co.uk/b/bn_1841469
# https://www.ebay.co.uk/b/bn_1841498
# https://www.ebay.co.uk/b/bn_1842014
# https://www.ebay.co.uk/b/bn_1841029
# https://www.ebay.co.uk/b/bn_1841031
# https://www.ebay.co.uk/b/bn_1840059
# https://www.ebay.co.uk/b/bn_1838772
# https://www.ebay.co.uk/b/bn_7204993
# https://www.ebay.co.uk/b/bn_7114087302
# https://www.ebay.co.uk/b/bn_776932
# https://www.ebay.co.uk/b/bn_1839770
# https://www.ebay.co.uk/b/bn_1838397
# https://www.ebay.co.uk/b/bn_1841062
# https://www.ebay.co.uk/b/bn_2317955
# https://www.ebay.co.uk/b/bn_1838735
# https://www.ebay.co.uk/b/bn_1841505
# https://www.ebay.co.uk/b/bn_552182
# https://www.ebay.co.uk/b/bn_1841451
# https://www.ebay.co.uk/b/bn_1841793
# https://www.ebay.co.uk/b/bn_1635788
# https://www.ebay.co.uk/b/bn_1841513
# https://www.ebay.co.uk/b/bn_1839164
# https://www.ebay.co.uk/ebaylive
# https://www.ebay.co.uk/b/bn_7117571158
# https://www.ebay.co.uk/b/bn_7000259670
# https://www.ebay.co.uk/b/bn_1841446
# https://www.ebay.co.uk/b/bn_7000259660
# https://www.ebay.co.uk/b/bn_7117653182
# https://www.ebay.co.uk/vlp/fashion
# https://www.ebay.co.uk/b/bn_1838540
# https://www.ebay.co.uk/vlp/motors
# https://www.ebay.co.uk/b/bn_7000259665
# https://www.ebay.co.uk/b/bn_7000259669
# https://www.ebay.co.uk/b/bn_1840059
# https://www.ebay.co.uk/ebaylive
# https://www.ebay.co.uk/b/bn_7117571158
# https://www.ebay.co.uk/ebaylive/events/3HqxwzUQ5cnglNdl?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A2%7Cvlpname%3Avlp_homepage%7Cii%3A7543af3b-7a20-4318-b14e-3f090441af17
# https://www.ebay.co.uk/ebaylive/events/3HqxwzUQ5cnglNdl?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A2%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/_electronics/up-to-50-off-refurbished-laptops?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-apple/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-apple/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-lenovo/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-lenovo/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-dell/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-dell/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-apple/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-lenovo/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/roe-dell/laptops-netbooks/175672?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A3%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/vlp/fashion?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/vlp/womens-fashion?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/vlp/womens-fashion?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/vlp/mens-fashion?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/vlp/mens-fashion?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/b/kids-fashion/bn_1632761?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/b/kids-fashion/bn_1632761?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/vlp/womens-fashion?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/vlp/mens-fashion?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/b/kids-fashion/bn_1632761?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A4%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/b/bn_7114608164?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A5%7Cvlpname%3Avlp_homepage%7Cii%3A9d19fe54-8d11-440c-a787-5fac0bb91391
# https://www.ebay.co.uk/b/bn_7114608164?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A5%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/sgall?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/sgall?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/sgall?_dlg=tc
# https://www.ebay.co.uk/itm/356930867786?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D356930867786%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/356570962688?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D356570962688%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/404838485257?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D404838485257%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/314897557953?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D314897557953%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/314906357631?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D314906357631%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/126776967238?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D126776967238%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/126775028374?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D126775028374%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/405222856722?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D405222856722%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/sgall?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/sgall?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/special-events/sgall?_dlg=tc
# https://www.ebay.co.uk/itm/356930867786?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D356930867786%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/356570962688?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D356570962688%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/404838485257?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D404838485257%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/314897557953?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D314897557953%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/314906357631?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D314906357631%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/126776967238?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D126776967238%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/126775028374?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D126775028374%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/405222856722?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240312102548%26meid%3Def7ba63105c4415fa4873ca2bf963d66%26pid%3D102037%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D405222856722%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DPersonalizedEventsV2&_trksid=p4375194.c102037.m45444&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/127318614905?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D127318614905%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3Dadidas&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/396972419430?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D396972419430%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3DJordan&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/286770683092?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D286770683092%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3Dadidas&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/157227319172?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D157227319172%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3Dadidas&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/286766882574?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D286766882574%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3DJordan&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/136339464725?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D136339464725%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3Dadidas&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/357489606961?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D357489606961%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3Dadidas&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/357474127220?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D357474127220%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3DJordan&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/286773821362?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D286773821362%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3Dadidas&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/136325786604?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603120050%26meid%3D19487f5c757744adaebd0c5ff29d2319%26pid%3D102175%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D136325786604%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostSearched%26brand%3DJordan&_trksid=p4375194.c102175.m166538&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/b/Sales-Events/bn_7115216712?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cmi%3A4776%7Cli%3A9803
# https://www.ebay.co.uk/b/Sales-Events/bn_7115216712?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cmi%3A4776%7Cli%3A8342
# https://www.ebay.co.uk/b/bn_7114608164
# https://www.ebay.co.uk/e/home-garden/up-to-50-off-refurbished-bank-holiday-diy
# https://www.ebay.co.uk/e/_electronics/up-to-50-off-computing-2305
# https://www.ebay.co.uk/sl/sell
# https://www.ebay.co.uk/e/motors/vehicle-oils-fluids-lubricants-deals
# https://www.ebay.co.uk/str/ernestjonesofficial
# https://www.ebay.co.uk/vlp/local
# https://www.ebay.co.uk/itm/306451328650?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D306451328650%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DOMEGA&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/406137928806?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D406137928806%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DCartier&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/286764683576?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D286764683576%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DRolex&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/157249319871?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D157249319871%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DRolex&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/127312465825?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D127312465825%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DChristopher%2BWard&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/396963842014?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D396963842014%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DOMEGA&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/267369176092?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D267369176092%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DOMEGA&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/205673791589?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D205673791589%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DOMEGA&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/136326670914?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D136326670914%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DRolex&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/277327428111?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121338%26meid%3Dbb1ce53d66c94e8087f8dd402d539345%26pid%3D102176%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D277327428111%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DBreitling&_trksid=p4375194.c102176.m166539&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/8y7WVsdpFwGgGbAv?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/fdkqMrctbvQFQoUa?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/cSsBo3UXwRcbzHTa?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/2xdZLmxujjh7InzV?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/8DXVg34uSEI4P0zq?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/yTxHWpHYagoSNqCr?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/0VTOCzrbpwgygCxi?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/eMqgjqU8P2vOixgJ?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/PqNIpIwzAt5A5LMl?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/sHM6bnjT19s5gj6l?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/Dm7KpZfpFQliXY7B?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/3HqxwzUQ5cnglNdl?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/pGnxNkz1EHQQjvEp?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/LS3UHcVJqNd5s54M?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/ebaylive/events/2DF13a4NgGE2tqWO?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/deals?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/deals?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/135554282415?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D135554282415%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/267341397865?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D267341397865%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/131707248576?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D131707248576%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/404773233851?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D404773233851%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/186681016619?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D186681016619%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/316597482886?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D316597482886%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/124987833305?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D124987833305%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/235792338979?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D235792338979%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/deals?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/deals?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/135554282415?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D135554282415%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/267341397865?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D267341397865%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/131707248576?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D131707248576%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/404773233851?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D404773233851%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/186681016619?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D186681016619%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/316597482886?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D316597482886%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/124987833305?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D124987833305%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/235792338979?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20231108131718%26meid%3D7f30d48aaa9f4daa979de07366ba3f68%26pid%3D101910%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D235792338979%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DFeaturedDealsV2&_trksid=p4375194.c101910.m150506&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/256861084347?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D256861084347%26pmt%3D1%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/386413370211?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D386413370211%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DVytronix&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/127073057621?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D127073057621%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DNinja&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/126681744842?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D126681744842%26pmt%3D1%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DNinja&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/127261390642?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D127261390642%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DNinja&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/196757484000?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D196757484000%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DDJI&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/235822029483?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D235822029483%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DMajority&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/186681052267?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D186681052267%26pmt%3D1%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DShark&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/386413365056?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D386413365056%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DHoover&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/itm/276648955608?_trkparms=amclksrc%3DITM%26aid%3D777008%26algo%3DPERSONAL.TOPIC%26ao%3D1%26asc%3D20240603121456%26meid%3Db64ee517c84a449aa4f11c8a54b2ca24%26pid%3D102177%26rk%3D1%26rkt%3D1%26b%3D1%26itm%3D276648955608%26pmt%3D0%26noa%3D1%26pg%3D4375194%26algv%3DNoSignalMostWatched%26brand%3DK%25E4rcher&_trksid=p4375194.c102177.m166540&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/b/Sales-Events/bn_7115216712?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A2%7Cmi%3A4776%7Cli%3A9803
# https://www.ebay.co.uk/b/Sales-Events/bn_7115216712?_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Ciid%3A2%7Cmi%3A4776%7Cli%3A8342
# https://www.ebay.co.uk/e/fashion/up-to-25-off-marks-and-spencer
# https://www.ebay.co.uk/e/home-garden/up-to-50-off-beds-mattresses
# https://www.ebay.co.uk/e/home-garden/save-20-on-energy-essentials
# https://www.ebay.co.uk/e/fashion/10-off-luxury-goods
# https://www.ebay.co.uk/e/motors/3325-10-off-tyres
# https://www.ebay.co.uk/e/fashion/25-off-vintage-clothing
# https://www.ebay.co.uk/e/_electronics/up-to-50-off-macbooks-ipads
# https://www.ebay.co.uk/sl/sell?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A1
# https://www.ebay.co.uk/sl/sell?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A1
# https://www.ebay.co.uk/e/coupon-offers/pa-coupon?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A6%7Cvlpname%3Avlp_homepage%7Cii%3A989c8c8d-fc51-49ca-85f7-f048140197cf
# https://pages.ebay.co.uk/coupons/2025/d1e0pes/?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A6%7Cvlpname%3Avlp_homepage
# https://pages.ebay.co.uk/coupons/2025/d1e0pes/?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A6%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/e/coupon-offers/pa-coupon?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A6%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/b/bn_7117653182?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A1%7Cvlpname%3Avlp_homepage%7Cii%3Aa412934a-219c-462f-bdc6-fafdad6064ed
# https://www.ebay.co.uk/b/bn_7117653182?_trkparms=pageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cparentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Ciid%3A1%7Cvlpname%3Avlp_homepage
# https://www.ebay.co.uk/deals?itmprp=enc%3AAQAKAAAAUGJc42PbZezye6cyuxOuth2SfcoxzclMvl9ybHAs3HM5LHYyaaOO90LcBl8zx%2FxrnyL4B6rAv7vhclmhPqr7%2FN3hpnwvmR%2FK1Pjn6gpwlSDr%7Ctkp%3AEElOVEVSTkFMktOrlZlm&_trkparms=parentrq%3Ac955745c1980a2c629c3b1f3ffe49ada%7Cpageci%3Aad9d5fe2-7e0a-11f0-8538-267b25d16864%7Cc%3A1%7Ciid%3A1%7Cmi%3A4818%7Cli%3A8991
# https://www.ebay.co.uk/help/policies/member-behaviour-policies/user-agreement?id=4259
# https://www.ebay.co.uk/help/policies/member-behaviour-policies/user-privacy-notice-privacy-policy?id=4260
# https://pages.ebay.co.uk/payment/2.0/terms.html
# https://www.ebay.co.uk/help/policies/member-behaviour-policies/ebay-cookie-notice?id=4267
# https://www.ebay.co.uk/adchoice

# %% [markdown]
# ## 2. Introduction to API and JSON

# %% [markdown]
# API = application programming interfaces
#
# Its a set of protocols and routines for building and interacting with software aplications
#
# A standard form for transfering data through API's is the JSON file format
#
# JSON - JavaScript Object Notation
#
# File format that arose out of a growing need for real-time server to browser communication that woulnd't necessarily rely on Flash or Java
#
# They are human readible

# %% [markdown]
# ### Loading and exploring a JSON

# %% [markdown]
# you'll load the JSON 'a_movie.json' into the variable json_data, which will be a dictionary. You'll then explore the JSON contents by printing the key-value pairs of json_data to the shell

# %%
#import package json
import json

# Load JSON: json_data
with open("a_movie.json") as json_file:
    json_data = json.load(json_file)

# Print each key-value pair in json_data
for k in json_data.keys(): #access the keys from the json_data dictionary using the keys() method
    print(k + ': ', json_data[k]) #where json_data is the value in dictionary i.e. 2010 is value of key year
# Out:
# Title:  The Social Network
# Year:  2010
# Rated:  PG-13
# Released:  01 Oct 2010
# Runtime:  120 min
# Genre:  Biography, Drama
# Director:  David Fincher
# Writer:  Aaron Sorkin (screenplay), Ben Mezrich (book)
# Actors:  Jesse Eisenberg, Rooney Mara, Bryan Barter, Dustin Fitzsimons
# Plot:  Harvard student Mark Zuckerberg creates the social networking site. That would become known as Facebook but is later sued by two brothers who claimed he stole their idea, and the co-founder who was later squeezed out of the business.
# Language:  English, French
# Country:  USA
# Awards:  Won 3 Oscars. Another 165 wins & 168 nominations.
# Poster:  https://m.media-amazon.com/images/M/MV5BOGUyZDUxZjEtMmIzMC00MzlmLTg4MGItZWJmMzBhZjE0Mjc1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg
# Ratings:  [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}, {'Source': 'Rotten Tomatoes', 'Value': '95%'}, {'Source': 'Metacritic', 'Value': '95/100'}]
# Metascore:  95
# imdbRating:  7.7
# imdbVotes:  571,335
# imdbID:  tt1285016
# Type:  movie
# DVD:  11 Jan 2011
# BoxOffice:  $96,400,000
# Production:  Columbia Pictures
# Website:  http://www.thesocialnetwork-movie.com/
# Response:  True

# %% [markdown]
# much of the data you get from API's are packaged as JSONs
#
# API's can be thought of as a bunch of code that allows 2 software programmes to communicate with each other
#
# For instance, if you wanted to stream twitter data by writing python code, you would use the twitter API or if you want to automate pulling and processing information from wikipedia you would use the wikipedia API
#
# Process:
#
#     HTTP - Signals that we're making a HTTP request
#
#     www.ombdapi.com - quering the OMBD API
#
#     ?t=hackers - query strings which are part of urls but don't fit into the conventional hieracal part structure - query we are making is t=hackers so that we ask the API to return the data for a movie with title (t) 'hackers
#
#     We knew that this was how to perform such a query from the documentation on the OMBD homepage uder 'usage'

# %% [markdown]
# ### API requests

# %% [markdown]
# Now it's your turn to pull some movie data down from the Open Movie Database (OMDB) using their API. The movie you'll query the API about is The Social Network. Recall that, in the video, to query the API about the movie Hackers

# %%
#import requests package
import requests

#assign url to variable: url
url = ('http://www.omdbapi.com/?apikey=72bc447a&t=the+social+network') #Put together the URL of interest, the string '/?' and the arguments apikey=72bc447a and t=the+social+network into one string: 'http://www.omdbapi.com/?apikey=72bc447a&t=the+social+network'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Print the text of the response
print(r.text)
# Out:
# {"Title":"The Social Network","Year":"2010","Rated":"PG-13","Released":"01 Oct 2010","Runtime":"120 min","Genre":"Biography, Drama","Director":"David Fincher","Writer":"Aaron Sorkin, Ben Mezrich","Actors":"Jesse Eisenberg, Andrew Garfield, Justin Timberlake","Plot":"As Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, he is sued by the twins who claimed he stole their idea and by the co-founder who was later squeezed out of the business.","Language":"English, French","Country":"United States","Awards":"Won 3 Oscars. 174 wins & 188 nominations total","Poster":"https://m.media-amazon.com/images/M/MV5BMjlkNTE5ZTUtNGEwNy00MGVhLThmZjMtZjU1NDE5Zjk1NDZkXkEyXkFqcGc@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"7.8/10"},{"Source":"Rotten Tomatoes","Value":"96%"},{"Source":"Metacritic","Value":"95/100"}],"Metascore":"95","imdbRating":"7.8","imdbVotes":"795,943","imdbID":"tt1285016","Type":"movie","DVD":"N/A","BoxOffice":"$96,962,694","Production":"N/A","Website":"N/A","Response":"True"}

# %% [markdown]
# ### JSON–from the web to Python

# %% [markdown]
# You've just queried your first API programmatically in Python and printed the text of the response to the shell. However, as you know, your response is actually a JSON, so you can do one step better and decode the JSON. You can then print the key-value pairs of the resulting dictionary. That's what you're going to do now!

# %%
# import package
import requests

# assign url to variable: url
url = 'http://www.omdbapi.com/?apikey=72bc447a&t=social+network'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# Print each key-value pair in json_data
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Title:  The Social Network
# Year:  2010
# Rated:  PG-13
# Released:  01 Oct 2010
# Runtime:  120 min
# Genre:  Biography, Drama
# Director:  David Fincher
# Writer:  Aaron Sorkin, Ben Mezrich
# Actors:  Jesse Eisenberg, Andrew Garfield, Justin Timberlake
# Plot:  As Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, he is sued by the twins who claimed he stole their idea and by the co-founder who was later squeezed out of the business.
# Language:  English, French
# Country:  United States
# Awards:  Won 3 Oscars. 174 wins & 188 nominations total
# Poster:  https://m.media-amazon.com/images/M/MV5BMjlkNTE5ZTUtNGEwNy00MGVhLThmZjMtZjU1NDE5Zjk1NDZkXkEyXkFqcGc@._V1_SX300.jpg
# Ratings:  [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '96%'}, {'Source': 'Metacritic', 'Value': '95/100'}]
# Metascore:  95
# imdbRating:  7.8
# imdbVotes:  795,943
# imdbID:  tt1285016
# Type:  movie
# DVD:  N/A
# BoxOffice:  $96,962,694
# Production:  N/A
# Website:  N/A
# Response:  True

# %% [markdown]
# ### Checking out the Wikipedia API

# %% [markdown]
# You'll figure out how to find and extract information from the Wikipedia page for Pizza. What gets a bit wild here is that your query will return nested JSONs, that is, JSONs with JSONs, but Python can handle that because it will translate them into dictionaries within dictionaries.

# %%
#import packages
import requests

#assign url to variable: url
url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=pizza'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# Print the Wikipedia page extract
pizza_extract = json_data['query']['pages']['24768']['extract']
print(pizza_extract)
# Out:
# <p class="mw-empty-elt">
#
#
# </p>
#
#
# <p><b>Pizza</b> is an Italian, specifically Neapolitan, dish typically consisting of a flat base of leavened wheat-based dough topped with tomato, cheese, and other ingredients, baked at a high temperature, traditionally in a wood-fired oven.
# </p><p>The term <i>pizza</i> was first recorded in 997<span> </span>AD, in a Latin manuscript from the southern Italian town of Gaeta, in Lazio, on the border with Campania. Raffaele Esposito is often credited for creating the modern pizza in Naples. In 2009, Neapolitan pizza was registered with the European Union as a traditional speciality guaranteed (TSG) dish. In 2017, the art of making Neapolitan pizza was included on UNESCO's list of intangible cultural heritage.
# </p><p>Pizza and its variants are among the most popular foods in the world. Pizza is sold at a variety of restaurants, including pizzerias (pizza specialty restaurants), Mediterranean restaurants, via delivery, and as street food. In Italy, pizza served in a restaurant is presented unsliced, and is eaten with the use of a knife and fork. In casual settings, however, it is typically cut into slices to be eaten while held in the hand. Pizza is also sold in grocery stores in a variety of forms, including frozen or as kits for self-assembly. Store-bought pizzas are then cooked using a home oven.
# </p><p>In 2017, the world pizza market was US$128 billion; in the US, it was $44 billion spread over 76,000 pizzerias. Overall, 13% of the US population aged two years and over consumed pizza on any given day.
# </p>

# %% [markdown]
# ## 3. The Twitter API and Authentication

# %% [markdown]
# ### Streaming tweets

# %% [markdown]
# Using the twitter API - you must have a twitter account in order to access your keys and access token to allow you to access the twitter API from Python

# %% [markdown]
# ### Load and explore your Twitter data

# %% [markdown]
# Now that you've got your Twitter data sitting locally in a text file, it's time to explore it! This is what you'll do in the next few interactive exercises. In this exercise, you'll read the Twitter data into a list: tweets_data

# %%
import json
import pandas as pd

# load the tweets file
tweets_data_path = "tweets3.txt"
tweets_data = []

with open(tweets_data_path, "r") as f:
    for line in f:
        try:
            tweet = json.loads(line)
            tweets_data.append(tweet)
        except:
            continue

# create DataFrame
tweets = pd.DataFrame(tweets_data)

# show available columns
print(tweets.columns)
# Out:
# Index(['in_reply_to_user_id', 'created_at', 'filter_level', 'truncated',
#        'possibly_sensitive', 'timestamp_ms', 'user', 'text',
#        'extended_entities', 'in_reply_to_status_id', 'entities', 'favorited',
#        'retweeted', 'is_quote_status', 'id', 'favorite_count',
#        'retweeted_status', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id_str', 'id_str', 'in_reply_to_screen_name',
#        'coordinates', 'lang', 'place', 'contributors', 'geo', 'retweet_count',
#        'source', 'quoted_status', 'quoted_status_id', 'quoted_status_id_str'],
#       dtype='object')

# %% [markdown]
# ### Twitter data to DataFrame

# %% [markdown]
# Now you have the Twitter data in a list of dictionaries, tweets_data, where each dictionary corresponds to a single tweet. Next, you're going to extract the text and language of each tweet. The text in a tweet, t1, is stored as the value t1['text']; similarly, the language is stored in t1['lang']. Your task is to build a DataFrame in which each row is a tweet and the columns are 'text' and 'lang'.

# %%
# Import package
import pandas as pd

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(tweets_data, 
                  columns = ['text', 'lang']) 

# Print head of DataFrame
print(df.head())
# Out:
#                                                 text lang
# 0  RT @bpolitics: .@krollbondrating's Christopher...   en
# 1  RT @HeidiAlpine: @dmartosko Cruz video found.....   en
# 2  Njihuni me Zonjën Trump !!! | Ekskluzive https...   et
# 3  Your an idiot she shouldn't have tried to grab...   en
# 4  RT @AlanLohner: The anti-American D.C. elites ...   en

# %% [markdown]
# ### A little bit of Twitter text analysis

# %% [markdown]
# Now that you have your DataFrame of tweets set up, you're going to do a bit of text analysis to count how many tweets contain the words 'clinton', 'trump', 'sanders' and 'cruz'. In the pre-exercise code, we have defined the following function word_in_text(), which will tell you whether the first argument (a word) occurs within the 2nd argument (a tweet).
#
# You're going to iterate over the rows of the DataFrame and calculate how many tweets contain each of our keywords! The list of objects for each candidate has been initialized to 0.

# %%
import re

# define word in text
def word_in_text(word, text):
    if text is None:
        return False
    word = word.lower()
    text = text.lower()
    return bool(re.search(r'\b' + re.escape(word) + r'\b', text))

# %%
# apply above to our tweets
tweets['clinton'] = tweets['text'].apply(lambda x: word_in_text('clinton', x))
tweets['trump']   = tweets['text'].apply(lambda x: word_in_text('trump', x))
tweets['sanders'] = tweets['text'].apply(lambda x: word_in_text('sanders', x))
tweets['cruz']    = tweets['text'].apply(lambda x: word_in_text('cruz', x))

print(tweets[['text','clinton','trump','sanders','cruz']].head())
# Out:
#                                                 text  clinton  trump  sanders  \
# 0  RT @bpolitics: .@krollbondrating's Christopher...     True  False    False
# 1  RT @HeidiAlpine: @dmartosko Cruz video found.....    False  False    False
# 2  Njihuni me Zonjën Trump !!! | Ekskluzive https...    False   True    False
# 3  Your an idiot she shouldn't have tried to grab...    False   True    False
# 4  RT @AlanLohner: The anti-American D.C. elites ...    False   True    False
#
#     cruz
# 0  False
# 1   True
# 2  False
# 3  False
# 4  False

# %% [markdown]
# ### Plotting your Twitter data

# %%
# Count how many tweets mention each candidate
counts = {
    'clinton': tweets['clinton'].sum(),
    'trump': tweets['trump'].sum(),
    'sanders': tweets['sanders'].sum(),
    'cruz': tweets['cruz'].sum()
}

print(counts)
# Out:
# {'clinton': np.int64(5), 'trump': np.int64(69), 'sanders': np.int64(4), 'cruz': np.int64(12)}

# %%
counts_df = pd.DataFrame(list(counts.items()), columns=['candidate', 'mentions'])
print(counts_df)
# Out:
#   candidate  mentions
# 0   clinton         5
# 1     trump        69
# 2   sanders         4
# 3      cruz        12

# %%
import seaborn as sns

# Create a bar plot
plt.figure(figsize=(8,5))
sns.barplot(data=counts_df, x='candidate', y='mentions', palette="pastel")

plt.title("Mentions of Candidates in Tweets", fontsize=14)
plt.ylabel("Number of Mentions", fontsize=12)
plt.xlabel("Candidate", fontsize=12)
plt.show()
# Out:
# /var/folders/h1/63qltpj12zq4ms95z852hkg40000gn/T/ipykernel_26011/712493392.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=counts_df, x='candidate', y='mentions', palette="pastel")
