# %% [markdown]
# # Web Scraping with Python - Collecting More Data from the Modern Web -
# https://edu.anarcho-copy.org/Programming%20Languages/Python/Web%20Scraping%20with%20Python,%202nd%20Edition.pdf

# %% [markdown]
# # Chapter 1: Your First Web Scraper

# %%
from urllib.request import urlopen
html = urlopen('http://pythonscraping.com/pages/page1.html')
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %% [markdown]
# ## install & run beautiful soup

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\jorda\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jorda\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('http://www.pythonscraping.com/pages/page1.html')
bs = BeautifulSoup(html.read(), 'html.parser') #get HTML content of the page - transformed into a BeautifulSoup Object which is nested: html > body > h1
print(bs.h1) #we are running the h1 tag found on the page
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
#           Beautiful soup object has the following structure
#         html <html><head>...</head><body>...</body></html>
#              head → <head><title>A Useful Page<title></head>
#                  title → <title>A Useful Page</title>
#              body → <body><h1>An Int...</h1><div>Lorem ip...</div></body>
#                  h1 → <h1>An Interesting Title</h1>
#                  div → <div>Lorem Ipsum dolor...</div>

# %%
bs.html.body.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bs.body.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bs.html.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bs.h1
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
# #### another popular parser whihch has the benefit of parsing messy or malformed HTML code

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\jorda\anaconda3\lib\site-packages (4.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
bs = BeautifulSoup(html.read(), 'lxml')

# %% [markdown]
# #### Another popular HTML parser is html5lib. Like lxml, html5lib is an extremely forgiving parser that takes even more initiative correcting broken HTML

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\jorda\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\jorda\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jorda\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
bs = BeautifulSoup(html.read(), 'html5lib')

# %%
bs.html.h1

# %% [markdown]
# ### Connecting Reliability and Handling Expectations

# %% [markdown]
# The web is messy. Data is poorly formatted, websites go down, and closing tags go
# missing. One of the most frustrating experiences in web scraping is to go to sleep
# with a scraper running, dreaming of all the data you’ll have in your database the next
# day—only to find that the scraper hit an error on some unexpected data format and
# stopped execution shortly after you stopped looking at the screen.

# %%
html = urlopen('http://www.pythonscraping.com/pages/page1.html')

# %% [markdown]
# page not found / error retrieving it = HTTP error return i.e. 404 page not found or 500 internal server error for mserver is not found

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
try:
     html = urlopen('http://www.pythonscraping.com/pages/page1.html')
except HTTPError as e:
 print(e)
 # return null, break, or do some other "Plan B"
else:
# program continues. Note: If you return or break in the
# exception catch, you do not need to use the "else" statement
# Out:
#   Input In [16]
#     # exception catch, you do not need to use the "else" statement
#                                                                   ^
# IndentationError: expected an indented block

# %% [markdown]
# If an HTTP error code is returned, the program now prints the error, and does not
# execute the rest of the program under the else statement.
#
# If the server is not found at all (if, say, http://www.pythonscraping.com is down, or the
# URL is mistyped), urlopen will throw an URLError
#
# You can add a check to see whether this is the case:

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError
try:
 html = urlopen('https://pythonscrapingthisurldoesnotexist.com')
except HTTPError as e:
 print(e)
except URLError as e:
 print('The server could not be found!')
else:
 print('It Worked!')
# Out:
# The server could not be found!

# %% [markdown]
# Of course, if the page is retrieved successfully from the server, there is still the issue of
# the content on the page not quite being what you expected. Every time you access a
# tag in a BeautifulSoup object, it’s smart to add a check to make sure the tag actually
# exists.

# %%
print(bs.nonExistentTag) #The line (where nonExistentTag is a made-up tag, not the name of a realBeautifulSoup function)
# Out:
# None

# %%
print(bs.nonExistentTag.someTag)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 print(bs.nonExistentTag.someTag)
#
# AttributeError: 'NoneType' object has no attribute 'someTag'

# %%
try:
 badContent = bs.nonExistingTag.anotherTag
except AttributeError as e:
 print('Tag was not found')
else:
 if badContent == None:
     print ('Tag was not found')
 else:
     print(badContent)
# Out:
# Tag was not found

# %% [markdown]
# This checking and handling of every error does seem laborious at first, but it’s easy to
# add a little reorganization to this code to make it less difficult to write. This code, for example, is our same scraper
# written in a slightly different way:

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
def getTitle(url): #create function called getTitle that retruns the title of the page or none if can;t retrieve 
 try:
     html = urlopen(url)
 except HTTPError as e:
     return None
 try:
     bs = BeautifulSoup(html.read(), 'html.parser')
     title = bs.body.h1 
 except AttributeError as e:
     return None
 return title
title = getTitle('http://www.pythonscraping.com/pages/page1.html')
if title == None:
     print('Title could not be found')
else:
     print(title)
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
# In this example, you’re creating a function getTitle, which returns either the title of
# the page, or a None object if there was a problem retrieving it. Inside getTitle, you
# check for an HTTPError, as in the previous example, and encapsulate two of the Beau‐
# tifulSoup lines inside one try statement

# %% [markdown]
# # Chapter 2: Advanced HTML Parsing

# %% [markdown]
# Let’s say you have some target content. Maybe it’s a name, statistic, or block of text.
# Maybe it’s buried 20 tags deep in an HTML mush with no helpful tags or HTML
# attributes to be found.

# %% [markdown]
# 1. Look for a “Print This Page” link, or perhaps a mobile version of the site that has
# better-formatted HTML
# 2. Look for the information hidden in a JavaScript file. Remember, you might need
# to examine the imported JavaScript files in order to do this.
# 3. This is more common for page titles, but the information might be available in
# the URL of the page itself.
# 4. If the information you are looking for is unique to this website for some reason,
# you’re out of luck. If not, try to think of other sources you could get this informa‐
# tion from. Is there another website with the same data? Is this website displaying
# data that it scraped or aggregated from another website?

# %% [markdown]
# CSS
# relies on the differentiation of HTML elements that might otherwise have the exact
# same markup in order to style them differently. Some tags might look like this:

# %%
<span class="green"></span>
<span class="red"></span>
# Out:
#   Input In [23]
#     <span class="green"></span>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Web scrapers can easily separate these two tags based on their class; for example, they
# might use BeautifulSoup to grab all the red text but none of the green text. Because
# CSS relies on these identifying attributes to style sites appropriately, you are almost
# guaranteed that these class and ID attributes will be plentiful on most modern web‐
# sites

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen(' http://www.pythonscraping.com/pages/warandpeace.html')
bs = BeautifulSoup(html.read(), 'html.parser')

# %%
print(bs.html.h1)
# Out:
# <h1>War and Peace</h1>

# %%
nameList = bs.findAll('span', {'class':'green'})
for name in nameList:
    print(name.get_text())  # returns all the green text in the order they appear in war and peace
                            # this can be checked by typing in the url on the web
# Out:
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %% [markdown]
# BeautifulSoup’s find() and find_all() are the two functions you will likely use the
# most. With them, you can easily filter HTML pages to find lists of desired tags, or a
# single tag, based on their various attributes

# %% [markdown]
# find_all(tag, attributes, recursive, text, limit, keywords)
#
# find(tag, attributes, recursive, text, keywords)
#
# In all likelihood, 95% of the time you will need to use only the first two arguments:
# tag and attributes. However, let’s take a look at all the arguments in greater detail.

# %%
bs.find_all(['h1','h2','h3','h4','h5','h6']) #lists all headers in the doc
# Out:
# [<h1>War and Peace</h1>, <h2>Chapter 1</h2>]

# %%
bs.find_all('span', {'class':{'green', 'red'}}) #returns green and red span tags in html doc
# Out:
# [<span class="red">Well, Prince, so Genoa and Lucca are now just family estates of the
#  Buonapartes. But I warn you, if you don't tell me that this means war,
#  if you still try to defend the infamies and horrors perpetrated by
#  that Antichrist- I really believe he is Antichrist- I will have
#  nothing more to do with you and you are no longer my friend, no longer
#  my 'faithful slave,' as you call yourself! But how do you do? I see
#  I have frightened you- sit down and tell me all the news.</span>,
#  <span class="green">Anna
#  Pavlovna Scherer</span>,
#  <span class="green">Empress Marya
#  Fedorovna</span>,
#  <span class="green">Prince Vasili Kuragin</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="green">St. Petersburg</span>,
#  <span class="red">If you have nothing better to do, Count [or Prince], and if the
#  prospect of spending an evening with a poor invalid is not too
#  terrible, I shall be very charmed to see you tonight between 7 and 10-
#  Annette Scherer.</span>,
#  <span class="red">Heavens! what a virulent attack!</span>,
#  <span class="green">the prince</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="red">First of all, dear friend, tell me how you are. Set your friend's
#  mind at rest,</span>,
#  <span class="red">Can one be well while suffering morally? Can one be calm in times
#  like these if one has any feeling?</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="red">You are
#  staying the whole evening, I hope?</span>,
#  <span class="red">And the fete at the English ambassador's? Today is Wednesday. I
#  must put in an appearance there,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">My daughter is
#  coming for me to take me there.</span>,
#  <span class="red">I thought today's fete had been canceled. I confess all these
#  festivities and fireworks are becoming wearisome.</span>,
#  <span class="red">If they had known that you wished it, the entertainment would
#  have been put off,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">Don't tease! Well, and what has been decided about Novosiltsev's
#  dispatch? You know everything.</span>,
#  <span class="red">What can one say about it?</span>,
#  <span class="green">the prince</span>,
#  <span class="red">What has been decided? They have decided that
#  Buonaparte has burnt his boats, and I believe that we are ready to
#  burn ours.</span>,
#  <span class="green">Prince Vasili</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="red">Oh, don't speak to me of Austria. Perhaps I don't understand
#  things, but Austria never has wished, and does not wish, for war.
#  She is betraying us! Russia alone must save Europe. Our gracious
#  sovereign recognizes his high vocation and will be true to it. That is
#  the one thing I have faith in! Our good and wonderful sovereign has to
#  perform the noblest role on earth, and he is so virtuous and noble
#  that God will not forsake him. He will fulfill his vocation and
#  crush the hydra of revolution, which has become more terrible than
#  ever in the person of this murderer and villain! We alone must
#  avenge the blood of the just one.... Whom, I ask you, can we rely
#  on?... England with her commercial spirit will not and cannot
#  understand the Emperor Alexander's loftiness of soul. She has
#  refused to evacuate Malta. She wanted to find, and still seeks, some
#  secret motive in our actions. What answer did Novosiltsev get? None.
#  The English have not understood and cannot understand the
#  self-abnegation of our Emperor who wants nothing for himself, but only
#  desires the good of mankind. And what have they promised? Nothing! And
#  what little they have promised they will not perform! Prussia has
#  always declared that Buonaparte is invincible, and that all Europe
#  is powerless before him.... And I don't believe a word that Hardenburg
#  says, or Haugwitz either. This famous Prussian neutrality is just a
#  trap. I have faith only in God and the lofty destiny of our adored
#  monarch. He will save Europe!</span>,
#  <span class="red">I think,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">that if you had been
#  sent instead of our dear <span class="green">Wintzingerode</span> you would have captured the
#  <span class="green">King of Prussia</span>'s consent by assault. You are so eloquent. Will you
#  give me a cup of tea?</span>,
#  <span class="green">Wintzingerode</span>,
#  <span class="green">King of Prussia</span>,
#  <span class="red">In a moment. A propos,</span>,
#  <span class="red">I am
#  expecting two very interesting men tonight, <span class="green">le Vicomte de Mortemart</span>,
#  who is connected with the <span class="green">Montmorencys</span> through the <span class="green">Rohans</span>, one of
#  the best French families. He is one of the genuine emigres, the good
#  ones. And also the <span class="green">Abbe Morio</span>. Do you know that profound thinker? He
#  has been received by <span class="green">the Emperor</span>. Had you heard?</span>,
#  <span class="green">le Vicomte de Mortemart</span>,
#  <span class="green">Montmorencys</span>,
#  <span class="green">Rohans</span>,
#  <span class="green">Abbe Morio</span>,
#  <span class="green">the Emperor</span>,
#  <span class="red">I shall be delighted to meet them,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">But tell me,</span>,
#  <span class="red">is it true that the Dowager Empress wants Baron Funke
#  to be appointed first secretary at Vienna? The baron by all accounts
#  is a poor creature.</span>,
#  <span class="green">Prince Vasili</span>,
#  <span class="green">Dowager Empress Marya Fedorovna</span>,
#  <span class="green">the baron</span>,
#  <span class="green">Anna Pavlovna</span>,
#  <span class="green">the Empress</span>,
#  <span class="red">Baron Funke has been recommended to the Dowager Empress by her
#  sister,</span>,
#  <span class="green">the Empress</span>,
#  <span class="green">Anna Pavlovna's</span>,
#  <span class="green">Her Majesty</span>,
#  <span class="green">Baron
#  Funke</span>,
#  <span class="green">The prince</span>,
#  <span class="green">Anna
#  Pavlovna</span>,
#  <span class="green">the Empress</span>,
#  <span class="red">Now about your family. Do you know that since your daughter came
#  out everyone has been enraptured by her? They say she is amazingly
#  beautiful.</span>,
#  <span class="green">The prince</span>,
#  <span class="red">I often think,</span>,
#  <span class="red">I often think how unfairly sometimes the
#  joys of life are distributed. Why has fate given you two such splendid
#  children? I don't speak of <span class="green">Anatole</span>, your youngest. I don't like
#  him,</span>,
#  <span class="green">Anatole</span>,
#  <span class="red">Two such charming children. And really you appreciate
#  them less than anyone, and so you don't deserve to have them.</span>,
#  <span class="red">I can't help it,</span>,
#  <span class="green">the prince</span>,
#  <span class="red">Lavater would have said I
#  lack the bump of paternity.</span>,
#  <span class="red">Don't joke; I mean to have a serious talk with you. Do you know I
#  am dissatisfied with your younger son? Between ourselves</span>,
#  <span class="red">he was mentioned at Her
#  Majesty's and you were pitied....</span>,
#  <span class="green">The prince</span>,
#  <span class="red">What would you have me do?</span>,
#  <span class="red">You know I did all
#  a father could for their education, and they have both turned out
#  fools. Hippolyte is at least a quiet fool, but Anatole is an active
#  one. That is the only difference between them.</span>,
#  <span class="red">And why are children born to such men as you? If you were not a
#  father there would be nothing I could reproach you with,</span>,
#  <span class="green">Anna
#  Pavlovna</span>,
#  <span class="red">I am your faithful slave and to you alone I can confess that my
#  children are the bane of my life. It is the cross I have to bear. That
#  is how I explain it to myself. It can't be helped!</span>,
#  <span class="green">Anna Pavlovna</span>]

# %% [markdown]
# find_all works recursively (recur
# sive is set to True); it’s generally a good idea to leave this as is, unless you really know
# what you need to do and performance is an issue. function looks into children, and children’s children, for tags that match your parameters. If it is False, it will look only at
# the top-level tags in your document.

# %%
# if you want to find the number of times “the prince” is surrounded by tags on the example page
nameList = bs.find_all(text='the prince')
print(len(nameList))
# Out:
# 7

# %%
# The keyword argument allows you to select tags that contain a particular attribute or set of attributes. For example:
title = bs.find_all(id='title', class_='text')

# %% [markdown]
# #### recap
#
# BeautifulSoup objects = Instances seen in previous code examples as the variable bs
#
# Tag objects = Retrieved in lists, or retrieved individually by calling find and find_all on a BeautifulSoup object, or drilling down, as follows: = bs.div.h1
#
# However, there are two more objects in the library that, although less commonly used, are still important to know about:
# NavigableString objects = Used to represent text within tags, rather than the tags themselves (some functions operate on and produce NavigableStrings, rather than tag objects).
#
# Comment object = Used to find HTML comments in comment tags, <!--like this one-->.
#
# These four objects are the only objects you will ever encounter in the BeautifulSoup

# %% [markdown]
# ### dealing with children and other decendents

# %% [markdown]
# http://www.pythonscraping.com/pages/page3.html ---- shopping example
#
# which has a tree like HTML structure:
#
#     — body
# — div.wrapper
# — h1
# — div.content
# — table#giftList
# — tr
# — th
# — th
# — th
# — th
# — tr.gift#gift1
# — td
# — td
# — span.excitingNote
# — td
# — td
# — img
# — ...table rows continue...
# — div.footer
#
# In the BeautifulSoup library, as well as many other libraries, there is a distinction
# drawn between children and descendants: much like in a human family tree, children
# are always exactly one tag below a parent, whereas descendants can be at any level in
# the tree below a parent. For example, the tr tags are children of the table tag,
# whereas tr, th, td, img, and span are all descendants of the table tag (at least in our
# example page). All children are descendants, but not all descendants are children

# %%
#If you want to find only descendants that are children, you can use the .children tag:
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')
for child in bs.find('table',{'id':'giftList'}).children:
    print(child)

#This code prints the list of product rows in the giftList table, including the initial
row of column labels. If you were to write it using the descendants() function
instead of the children() function, about two dozen tags would be found within the
table and printed, including img tags, span tags, and individual td tags.
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>

# %% [markdown]
# ### dealing with siblings

# %%
#The BeautifulSoup next_siblings() function makes it trivial to collect data from tables, especially ones with title rows:
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')
for sibling in bs.find('table', {'id':'giftList'}).tr.next_siblings:
    print(sibling)

#The output of this code is to print all rows of products from the product table, except
#for the first title row. Why does the title row get skipped? Objects cannot be siblings
#with themselves. Anytime you get siblings of an object, the object itself will not be
#included in the list. As the name of the function implies, it calls next siblings only
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>

# %% [markdown]
# ### dealing with parents

# %% [markdown]
# When scraping pages, you will likely discover that you need to find parents of tags less frequently than you need to find their children or siblings.
#
# Typically, when you look at HTML pages with the goal of crawling them, you start by looking at the top layer of tags, and then figure out how to drill your way down into the exact piece of data that you want.
#
# Occasionally, however, you can find yourself in odd situations that require BeautifulSoup’s parent-finding functions, .parent and .parents. For example:

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('img',{'src':'../img/gifts/img1.jpg'}).parent.previous_sibling.get_text())

#prev sibling of the td tag is the td tag that contains the dollar value of the product
# Out:
# $15.00

# %% [markdown]
# ### Regular expressions and beutiful soup
#
# https://www.pythonscraping.com/pages/page3.html

# %% [markdown]
# notice that the site has many product images which takes the following form:>>>"../img/gifts/img3.jpg">
#
# If you wanted to grab URLs to all of the product images, it might seem fairly straight‐forward at first: just grab all the image tags by using.find_all("img"), right?
#
# But here’s a problem. In addition to the obvious “extra” images (e.g., logos), modern web‐sites often have hidden images, blank images used for spacing and aligning elements, ad other random image tags you might not be aware of. Certainly, you can’t count n the only images on the page being product images.
#
# Let’s also assume that the layout of the page might change, or that, for whatever reason, you don’t want to depend on the position of the image in the page in order to ind the correct tag.
#
# The solution is to look for something identifying about the tag itself. In this case, you
# can look at the file path of the product images:

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img',{'src':re.compile('\.\.\/img\/gifts/img.*\.jpg')})
for image in images:
    print(image['src'])
    
#prints relative image paths that start with /img/giftd/img and end in jpg
# Out:
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %% [markdown]
# ### accessing attributes
#
# With tag objects, a Python list of attributes can be automatically accessed by calling this:
#
# myTag.attrs
#
# The source location for animage, for example, can be found using the following line:
#
# myImgTag.attrs['src']

# %% [markdown]
# ### Lambda Expressions
#
# Is a function that is passed into another function as a variable; instead of defining a function as f(x, y), you may define a function as f(g(x),y) or even f(g(x), h(x)).
#
# BeautifulSoup allows you to pass certain types of functions as parameters into the find_all function.

# %% [markdown]
# The only restriction is that these functions must take a tag object as an argument and return a boolean.
#
# Every tag object that BeautifulSoup encounters is evaluated in this function, and tags that evaluate to True are returned, while the rest are discarded.
#
# For example, the following retrieves all tags that have exactly two attributes:

# %%
bs.find_all(lambda tag: len(tag.attrs) == 2)

#Here, the function that you are passing as the argument is len(tag.attrs) == 2.
#Where this is True, the find_all function will return the tag. That is, it will find tags
# with two attributes, such as the following:
# <div class="body" id="content"></div>
# <span style="color:red" class="title"></span>
# Out:
# [<img src="../img/gifts/logo.jpg" style="float:left;"/>,
#  <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
#  </td><td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift4"><td>
#  Dead Parrot
#  </td><td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td><td>
#  $0.50
#  </td><td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift5"><td>
#  Mystery Box
#  </td><td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td><td>
#  $1.50
#  </td><td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td></tr>]

# %%
#Lambda functions are so useful you can even use them to replace existing Beauti‐
#fulSoup functions:    
bs.find_all(lambda tag: tag.get_text() == 'Or maybe he\'s only resting?')
# Out:
# [<span class="excitingNote">Or maybe he's only resting?</span>]

# %%
#This can also be accomplished without a lambda function:
bs.find_all('', text='Or maybe he\'s only resting?')
# Out:
# ["Or maybe he's only resting?"]

# %% [markdown]
# ### Regular Expressions

# %% [markdown]
# Problem:
# 1. Write the letter a at least once.
# 2. Append to this the letter b exactly five times.
# 3. Append to this the letter c any even number of times.
# 4. Write either the letter d or e at the end.

# %%
#soluction = aa*bbbbb(cc)*(d|e)

# aa* = any number of as a inc 0 of them (written at least once)
# bbbbb = 5 b's in a row
# (cc)* = any even number or things that can be grouped into pairs
# (d/e) = d or e

# %% [markdown]
# ### for testing regular expressions
#
# https://www.regexpal.com/

# %%
# * = matches preceding char 0 or more times i.e. a*b* = aaaaaaaaa,aaabbbbbbbb, bbbbbb
# + = matches the preceding character 1 or more times i.e a+b+ = aaaaab, aaabbbbb, abbbbb
# [] = matches any character wihtin the brackets i..e. [A-Z]* = APPLE, CAPITALS, QUERY
# () = grouped sub expression i.e. (a*b)* = aaabaaab, abaaab, ababaaab
# (m,n) = matches the preceding character between m and n inclusive i.e. a(2,3)b(2,3) = aabbb, aaabbb, aabb
# [^] = matches any single character that is not in the brackets i.e. [^A-Z]* = apple, lowercase, qwerty
# | = matches any character/string seperated by | i.e. b(a|i|e|d) = bad, bid, bed
# . = matches any single char at beggining of string i.e. b.d = bad, bzd, b$d, b d
# ^ = indicates that a character occurs at begginng of string i.e. ^a = aple, asdf, a 
# \ = escape character allows special char as literal meanings i.e. \.\|\\ = .|\
# $ = often used at end of regular expression match this up to end of string i.e. [A-Z]*[a-z]*$ = ABCabc, zzzyx, Bob
# ?! = does not contain i.e. ^((?![A-Z]).)*$ = co-caps-here, $ymb0ls a4e f!ne

# %%
# EMAIL ADDRESS EXAMPLE

 # [A-Za-z0-9\._+]+@[A-Za-z]+\.(com|org|edu|net)
    
 # first part contains at least 1 upper/lower case letters, numbers 0-9, periods(.), plus signs (+), or underscores (_)
 # next contains @
 # then contians at least 1 upper/lower case letter
 # followed by period (.)
 #  followed by .com/edu/net etc

# %% [markdown]
# # Chapter 3: Writing Web Crawlers

# %% [markdown]
# Web crawlers are called such because they crawl across the web. At their core is an element of recursion. They must retrieve page contents for a URL, examine that page for another URL, and retrieve that page, ad infinitum.
#
# With web crawlers, you must be extremely conscientious of how much bandwidth you are using and make every effort to determine whether there’s a way to make the target server’s load easier.

# %% [markdown]
# ### Traversing a single Domain

# %% [markdown]
# In this section, you’ll begin a project that will become a Six Degrees of Wikipedia solution finder: You’ll be able to take the Eric Idle page and find the fewest number of link clicks that will take you to the Kevin Bacon page.
#
# https://en.wikipedia.org/wiki/Kevin_Bacon

# %%
# You should already know how to write a Python script that retrieves an arbitrary
# Wikipedia page and produces a list of links on that page:

from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Wikipedia:Citation_needed
# http://baconbros.com/
# #cite_note-2
# #cite_note-actor-3
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/X-Men:_First_Class
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-6
# /wiki/EE_Limited
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_High_School
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-6
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-7
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-18
# /wiki/Tremors_(1990_film)
# #cite_note-19
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-20
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-21
# /wiki/A_Few_Good_Men_(film)
# #cite_note-22
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-23
# /wiki/Sleepers_(film)
# #cite_note-24
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-25
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-26
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-27
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-28
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-29
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-30
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-31
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-32
# #cite_note-33
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-34
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-35
# #cite_note-36
# /wiki/The_Following
# #cite_note-37
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-38
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-39
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# #cite_note-40
# #cite_note-41
# #cite_note-42
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-43
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-44
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-45
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-46
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-47
# /wiki/Tracy_Pollan
# #cite_note-48
# #cite_note-49
# #cite_note-50
# /wiki/The_Times
# #cite_note-51
# #cite_note-52
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-53
# #cite_note-54
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-55
# #cite_note-56
# #cite_note-57
# #cite_note-58
# /wiki/Apollo_13_(film)
# #cite_note-59
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-60
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-61
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-62
# /wiki/Denver_Film_Festival
# #cite_note-63
# /wiki/Phoenix_Film_Festival
# #cite_note-64
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-65
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-66
# /wiki/Seattle_International_Film_Festival
# #cite_note-67
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_6-0
# #cite_ref-walk_6-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.sixdegrees.org/
# #cite_ref-44
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-45
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-46
# http://baconbros.com/
# #cite_ref-47
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-48
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-49
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-50
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-51
# #cite_ref-52
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_53-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-54
# #cite_ref-55
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-56
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-57
# http://www.drawtheline.org/sign-now/
# #cite_ref-58
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-59
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-60
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-61
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-62
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-63
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-64
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-65
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-66
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-67
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# https://en.wikipedia.org/w/index.php?title=Template:Golden_Globe_Best_Actor_TV_Miniseries_Film&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# /wiki/ISNI_(identifier)
# https://isni.org/isni/0000000121291300
# /wiki/VIAF_(identifier)
# https://viaf.org/viaf/39570812
# https://www.worldcat.org/identities/lccn-n88034930/
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://d-nb.info/gnd/124109659
# http://uli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://id.loc.gov/authorities/names/n88034930
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an36021861
# https://librarian.nl.go.kr/LI/contents/L20101000000.do?id=KAC2020K8226
# http://data.bibliotheken.nl/id/thes/p147880998
# http://mak.bn.org.pl/cgi-bin/KHW/makwww.exe?BM=1&NU=1&IM=4&WI=9810630778405606
# http://id.worldcat.org/fast/242183/
# /wiki/MBA_(identifier)
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/RERO_(identifier)
# http://data.rero.ch/02-A016294166
# https://snaccooperative.org/ark:/99166/w6w67gw2
# /wiki/SUDOC_(identifier)
# https://www.idref.fr/084292652
# https://www.idref.fr/067287832
# /wiki/Trove_(identifier)
# https://trove.nla.gov.au/people/1189569
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1091807363
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_October_2021
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Articles_with_ISNI_identifiers
# /wiki/Category:Articles_with_VIAF_identifiers
# /wiki/Category:Articles_with_WORLDCATID_identifiers
# /wiki/Category:Articles_with_BIBSYS_identifiers
# /wiki/Category:Articles_with_BNE_identifiers
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_LNB_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_with_NLA_identifiers
# /wiki/Category:Articles_with_NLK_identifiers
# /wiki/Category:Articles_with_NTA_identifiers
# /wiki/Category:Articles_with_PLWABN_identifiers
# /wiki/Category:Articles_with_FAST_identifiers
# /wiki/Category:Articles_with_MusicBrainz_identifiers
# /wiki/Category:Articles_with_RERO_identifiers
# /wiki/Category:Articles_with_SNAC-ID_identifiers
# /wiki/Category:Articles_with_SUDOC_identifiers
# /wiki/Category:Articles_with_Trove_identifiers
# /wiki/Category:Articles_with_multiple_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1091807363
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1091807363&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# Recently a friend of mine, while working on a similar Wikipedia-scraping project, mentioned he had written a large filtering function, with more than 100 lines of code, in order to determine whether an internal Wikipedia link was an article page.
#
# Unfortunately, he had not spent much time upfront trying to find patterns between “article links” and “other links,”

# %% [markdown]
# If you examine the links that point to article pages (as opposed to other internal pages), you’ll see that they all have three things in common:
#
# • They reside within the div with the id set to bodyContent.
# • The URLs do not contain colons.
# • The URLs begin with /wiki/.

# %%
#You can use these rules to revise the code slightly to retrieve only the desired article
#links by using the regular expression ^(/wiki/)((?!:).)*$"

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])

#output is a list of URL's
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/EE_Limited
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Julia_R._Masterman_High_School
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/EE_(telecommunications_company)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/The_Times
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/ISNI_(identifier)
# /wiki/VIAF_(identifier)
# /wiki/MBA_(identifier)
# /wiki/RERO_(identifier)
# /wiki/SUDOC_(identifier)
# /wiki/Trove_(identifier)

# %%
# single function, getLinks, that takes in a Wikipedia article URL of the
# form /wiki/<Article_Name> and returns a list of all linked article URLs in the
# same form.

# A main function that calls getLinks with a starting article, chooses a random
# article link from the returned list, and calls getLinks again, until you stop the
# program or until no article links are found on the new page.

from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a',
        href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Screen_Actors_Guild_Award
# /wiki/Matthew_McConaughey
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Leading_Role
# /wiki/Morgan_Freeman
# /wiki/Courtland_Milloy
# /wiki/Precious_(film)
# /wiki/Mahalia_Jackson
# /wiki/Civil_rights_movement
# /wiki/Joseph_Lowery
# /wiki/Jesse_Owens
# /wiki/Bouncy_Moore
# /wiki/Track_and_field
# /wiki/Women%27s_Amateur_Athletic_Association
# /wiki/Commonwealth_Games
# /wiki/Basketball_at_the_Commonwealth_Games
# /wiki/Lawn_bowls_at_the_2018_Commonwealth_Games
# /wiki/Malaysia_at_the_2018_Commonwealth_Games
# /wiki/Malaysia_at_the_1998_Commonwealth_Games
# /wiki/New_Zealand_national_badminton_team
# /wiki/Wayback_Machine
# /wiki/Institut_de_l%27information_scientifique_et_technique
# /wiki/France
# /wiki/Climate_change_in_France
# /wiki/French_Fourth_Republic
# /wiki/Ancient_history
# /wiki/West_Africa
# /wiki/Emigrant
# /wiki/ISBN_(identifier)
# /wiki/ISO_base_media_file_format
# /wiki/Au_file_format
# /wiki/Modified_Huffman_coding
# /wiki/Lempel%E2%80%93Ziv%E2%80%93Oberhumer
# /wiki/Rate%E2%80%93distortion_theory
# /wiki/Variance
# /wiki/Reliability_engineering
# /wiki/Print_design
# /wiki/Design_quality_indicator
# /wiki/Property_designer
# /wiki/Universal_design
# /wiki/Ecological_design
# /wiki/Extended_producer_responsibility
# /wiki/Recycling_rates_by_country
# /wiki/Hungary
# /wiki/Portugal
# /wiki/PMID_(identifier)
# /wiki/List_of_university_presses
# /wiki/Northwestern_University_Press
# /wiki/Hurston-Wright_Legacy_Award
# /wiki/Gerald_Horne
# /wiki/Ferdinand_Smith
# /wiki/Frank_Marshall_Davis
# /wiki/Wayback_Machine
# /wiki/DMCA_request
# /wiki/Fourth_Estate_Public_Benefit_Corp._v._Wall-Street.com
# /wiki/Gibbons_v._Ogden
# /wiki/United_States_Reports
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_528
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_336
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_428
# /wiki/List_of_United_States_Supreme_Court_cases,_volume_143
# /wiki/2021_term_opinions_of_the_Supreme_Court_of_the_United_States
# /wiki/Vega_v._Tekoh
# /wiki/Title_42_of_the_United_States_Code
# /wiki/Title_18_of_the_United_States_Code
# /wiki/Trap_and_trace_device
# /wiki/Telephony
# /wiki/History_of_radio
# /wiki/FM_radio
# /wiki/Amplitude_modulation
# /wiki/Subsidiary_communications_authority
# /wiki/High_frequency
# /wiki/Radio_frequency
# /wiki/History_of_broadcasting
# /wiki/Node_(networking)
# /wiki/Optical_fiber
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_8859-7
# /wiki/Code_page_853
# /wiki/Code_page_773
# /wiki/Extended_Unix_Code
# /wiki/Tamil_All_Character_Encoding
# /wiki/Code_page_1124
# /wiki/Mac_OS_Armenian
# /wiki/Code_page_1008
# /wiki/ISO/IEC_8859-16
# /wiki/NEC_APC_character_set
# /wiki/DEC_Hebrew
# /wiki/Digital_UNIX
# /wiki/Windows_Subsystem_for_Linux
# /wiki/Windows_Insider
# /wiki/Local_Security_Authority_Subsystem_Service
# /wiki/DirectX_Diagnostic_Tool
# /wiki/InkBall
# /wiki/Shadow_Copy
# /wiki/Microsoft_ScanDisk
# /wiki/PATH_(variable)
# /wiki/Environment_variable
# /wiki/DR_DOS_3.40
# /wiki/MS-DOS
# /wiki/Microsoft
# /wiki/Microsoft_HoloLens
# /wiki/Applications_of_virtual_reality
# /wiki/Haptic_technology
# /wiki/DualShock
# /wiki/Gun_Metal_(video_game)
# /wiki/Gunmetal_(video_game)
# /wiki/PC_Accelerator
# /wiki/Cyclingnews.com
# /wiki/Broadcasting_%26_Cable
# /wiki/GamesMaster_(magazine)
# /wiki/Amstrad_Action
# /wiki/MacLife
# /wiki/Official_Nintendo_Magazine
# /wiki/Purch_Group
# /wiki/Cycling_Weekly
# /wiki/Edmund_Dangerfield
# /wiki/Doi_(identifier)
# /wiki/Legal_Entity_Identifier
# /wiki/ISO_5427
# /wiki/Stanford_Extended_ASCII
# /wiki/Cork_encoding
# /wiki/Number_sign
# /wiki/Bookkeeping
# /wiki/Generally_accepted_auditing_standards
# /wiki/Accounting_research
# /wiki/Positive_accounting
# /wiki/Academia
# /wiki/Residential_college
# /wiki/Harvard_College
# /wiki/President_and_Fellows_of_Harvard_College
# /wiki/List_of_Harvard_University_non-graduate_alumni
# /wiki/Colonel
# /wiki/Chilean_Army
# /wiki/Concert_band
# /wiki/Clarinet
# /wiki/Museum_musicum_theoreticalo_practicum
# /wiki/Schw%C3%A4bisch_Hall
# /wiki/Swabian_Circle
# /wiki/Irsee_Abbey
# /wiki/Abbey_of_Saint_Gall
# /wiki/Marchtal_Abbey
# /wiki/Margraviate_of_Baden
# /wiki/Schelklingen
# /wiki/Westerheim,_Baden-W%C3%BCrttemberg
# /wiki/%C3%96llingen
# /wiki/Swabian_Jura
# /wiki/Kapellenberg_(Vogtland)
# /wiki/Kasseler_Kuppe
# /wiki/Anterior_Bavarian_Forest
# /wiki/ISBN_(identifier)
# /wiki/ISO_10628
# /wiki/Vicat_softening_point
# /wiki/ISO_898
# /wiki/Screws
# /wiki/Cold_forming
# /wiki/Near_net_shape
# /wiki/Lanxide_process
# /wiki/Lotus_Elise
# /wiki/Supercharger
# /wiki/Lancia_Delta_S4
# /wiki/Rally_Argentina
# /wiki/Petter_Solberg
# /wiki/Tommi_M%C3%A4kinen
# /wiki/List_of_World_Rally_Championship_Drivers%27_champions
# /wiki/Spain
# /wiki/Sexenio_Democr%C3%A1tico
# /wiki/History_of_Spain
# /wiki/History_of_the_European_Union
# /wiki/Decolonization
# /wiki/Declaration_on_the_Granting_of_Independence_to_Colonial_Countries_and_Peoples
# /wiki/Bel%C3%A9m_do_Par%C3%A1_Convention
# /wiki/International_human_rights_law
# /wiki/National_human_rights_institution
# /wiki/World_Federation_of_Engineering_Organizations
# /wiki/World_Intellectual_Property_Organization
# /wiki/List_of_specialized_agencies_of_the_United_Nations
# /wiki/List_of_United_Nations_Security_Council_resolutions_concerning_Yemen
# /wiki/United_Nations_Security_Council_Resolution_188
# /wiki/Soviet_Union
# /wiki/Nabat#Decline
# /wiki/Expropriative_anarchism
# /wiki/Carnival_Against_Capital
# /wiki/Situationist_International
# /wiki/Public_discourse
# /wiki/Politics_and_technology#The_digital_public_sphere
# /wiki/Democracy
# /wiki/Isaac_Newton
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_15288
# /wiki/ISO_2788
# /wiki/OCR-A
# /wiki/Fat_face
# /wiki/Paragraph
# /wiki/Color_printing
# /wiki/Blue
# /wiki/Glass
# /wiki/Borosilicate_glass
# /wiki/Zwiesel_Kristallglas
# /wiki/Wood%27s_glass
# /wiki/Nickel_oxide
# /wiki/Nickel(III)_oxide
# /wiki/Cerium
# /wiki/Cerium(III)_methanesulfonate
# /wiki/Ammonium_cerium(IV)_sulfate
# /wiki/Ammonium_lauryl_sulfate
# /wiki/Triammonium_citrate
# /wiki/Generally_recognized_as_safe
# /wiki/Grandfather_clause
# /wiki/Multiple_non-transferable_vote
# /wiki/Limited_voting
# /wiki/Sequential_proportional_approval_voting
# /wiki/Unified_primary
# /wiki/STAR_voting
# /wiki/Independence_of_Smith-dominated_alternatives
# /wiki/Additional_member_system
# /wiki/Forward_Wales
# /wiki/Independent_(Politician)
# /wiki/Blaenau_Gwent_(UK_Parliament_constituency)
# /wiki/Labour_Party_(UK)
# /wiki/2005_United_Kingdom_general_election
# /wiki/Blaenau_Gwent_(UK_Parliament_constituency)
# /wiki/Electoral_Calculus
# /wiki/Michael_White_(journalist)
# /wiki/BBC
# /wiki/Oxford_University_Press
# /wiki/Oxford_University_Lightweight_Rowing_Club
# /wiki/St_Hilda%27s_College_Boat_Club
# /wiki/Lancaster_University_Boat_Club
# /wiki/Linacre_College_Boat_Club
# /wiki/List_of_fictional_Oxford_colleges
# /wiki/Faculty_of_History,_University_of_Oxford
# /wiki/Oxford_University_Ice_Hockey_Club
# /wiki/Coach_of_the_Year_Trophy_(IHJUK)
# /wiki/Coach_(ice_hockey)
# /wiki/Self-esteem
# /wiki/Seven_virtues
# /wiki/Ren%C3%A9_Descartes
# /wiki/Jean_Buridan
# /wiki/Heloise_(student_of_Abelard)
# /wiki/Wayback_Machine
# /wiki/Prior_art
# /wiki/European_Patent_Convention
# /wiki/ISBN_(identifier)
# /wiki/RM-ODP
# /wiki/Distributed_systems
# /wiki/PSPACE-complete
# /wiki/NL-complete
# /wiki/2-satisfiability
# /wiki/Doi_(identifier)
# /wiki/ISO_9564
# /wiki/ISO_31-7
# /wiki/ISO/TR_11941
# /wiki/Manufacturing_Message_Specification
# /wiki/Common_Criteria
# /wiki/Bundesamt_f%C3%BCr_Sicherheit_in_der_Informationstechnik
# /wiki/Certification
# /wiki/Certified_(disambiguation)
# /wiki/Certificate_(disambiguation)
# /wiki/Technical_and_further_education#Qualifications_awarded_by_TAFE_colleges
# /wiki/Australian_Qualifications_Framework
# /wiki/Tertiary_education_in_Australia
# /wiki/RMIT_University
# /wiki/Elizabeth_Street,_Melbourne
# /wiki/Degraves_Street
# /wiki/History_of_Melbourne
# /wiki/Western_Port
# /wiki/Tooradin,_Victoria
# /wiki/Boon_wurrung
# /wiki/McPhee_Gribble
# /wiki/Carlton,_Victoria
# /wiki/Carlton_Football_Club
# /wiki/Hyundai_Group
# /wiki/Hyundai_Electronics
# /wiki/LG_Uplus
# /wiki/Telecommunications_link
# /wiki/Virtual_circuit
# /wiki/S2CID_(identifier)
# /wiki/Electronic_publishing
# /wiki/Retraction_in_academic_publishing
# /wiki/The_Lancet
# /wiki/LCCN_(identifier)
# /wiki/Library_of_Congress
# /wiki/Joint_resolution
# /wiki/House_Democratic_Caucus
# /wiki/John_C._Calhoun
# /wiki/Idaho_Democratic_Party
# /wiki/Henry_G._Davis
# /wiki/William_Windom
# /wiki/Bob_Menendez
# /wiki/United_States_Senate_Special_Committee_on_Aging
# /wiki/List_of_United_States_congressional_joint_committees
# /wiki/Joint_Committees_of_the_United_States_Congress
# /wiki/United_States_Senate_Committee_on_Indian_Affairs
# /wiki/Henry_L._Dawes
# /wiki/Joe_Kennedy_III
# /wiki/Massachusetts
# /wiki/French_language
# /wiki/Homelessness_in_France
# /wiki/Homelessness_in_the_United_States_by_state
# /wiki/Gardendale,_Alabama
# /wiki/Warrior,_Alabama
# /wiki/Jefferson_County,_Alabama
# /wiki/Morris,_Alabama
# /wiki/2020_United_States_census
# /wiki/1950_United_States_census
# /wiki/Missouri
# /wiki/Acadians
# /wiki/French_people
# /wiki/ArXiv_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_8859-4
# /wiki/Cork_encoding
# /wiki/Code_page_1052
# /wiki/National_Replacement_Character_Set
# /wiki/%C3%89
# /wiki/MacOS
# /wiki/Mavericks,_California
# /wiki/OS_X_Mavericks
# /wiki/User_Interface
# /wiki/Video_production
# /wiki/QuickTime
# /wiki/List_of_old_Macintosh_software
# /wiki/FullPaint
# /wiki/MacPaint
# /wiki/ICloud
# /wiki/Mega_(service)
# /wiki/Comparison_of_file_hosting_services
# /wiki/Amazon_S3
# /wiki/Amazon_Astro
# /wiki/Amazon_Luna
# /wiki/Early_access
# /wiki/PCGamesN
# /wiki/Destructoid
# /wiki/OutsideXbox
# /wiki/New_York_Comic_Con
# /wiki/Kevin_Smith
# /wiki/The_New_York_Times
# /wiki/Henry_Kissinger
# /wiki/A_World_Restored
# /wiki/Napoleonic_Wars
# /wiki/Mikhail_Kutuzov
# /wiki/Miguel_Ricardo_de_%C3%81lava
# /wiki/Battle_of_Cabez%C3%B3n
# /wiki/Battle_of_Tolentino
# /wiki/Battle_of_Sankt_Michael
# /wiki/Third_siege_of_Girona
# /wiki/Battle_of_Bar-sur-Aube
# /wiki/Austrian_Empire
# /wiki/Austrian_literature
# /wiki/Adalbert_Stifter
# /wiki/Irmgard_Keun
# /wiki/Kingdom_of_Prussia
# /wiki/Saxe-Weimar-Eisenach
# /wiki/German_colonial_empire
# /wiki/Miscegenation
# /wiki/ISBN_(identifier)
# /wiki/National_Library_of_Brazil
# /wiki/Geographic_coordinate_system
# /wiki/North_American_Datum#North_American_Datum_of_1983
# /wiki/U.S._National_Geodetic_Survey
# /wiki/Orthometric_height
# /wiki/NAVD88
# /wiki/ED50
# /wiki/Ireland
# /wiki/Penal_Laws_(Ireland)
# /wiki/Battle_of_Glenmama
# /wiki/Cenn%C3%A9tig_mac_Lorc%C3%A1in
# /wiki/King_of_Munster
# /wiki/Kingdom_of_Ormond
# /wiki/School_of_Ross
# /wiki/O%27Leary
# /wiki/Daniel_Florencio_O%27Leary
# /wiki/Society_for_Irish_Latin_American_Studies
# /wiki/Area_studies
# /wiki/Food_studies
# /wiki/Public_health
# /wiki/Infection_control
# /wiki/Theory_of_planned_behavior
# /wiki/Carl_Rogers_Darnall
# /wiki/Statistical_hypothesis_testing
# /wiki/Bachelor_of_Science_in_Public_Health
# /wiki/Health_belief_model
# /wiki/Food_engineering
# /wiki/Saccharin
# /wiki/Operation_Weak_Meat
# /wiki/Trichinosis
# /wiki/Third_World
# /wiki/Developing_country
# /wiki/ArXiv_(identifier)
# /wiki/Comstock_Hall_(Ithaca,_New_York)
# /wiki/Journal_of_Empirical_Legal_Studies
# /wiki/Andrew_Dickson_White_House
# /wiki/National_Register_of_Historic_Places_listings_in_Putnam_County,_New_York
# /wiki/Old_Southeast_Town_Hall
# /wiki/National_Register_of_Historic_Places_listings_in_Oneida_County,_New_York
# /wiki/Five_Lock_Combine_and_Locks_37_and_38,_Black_River_Canal
# /wiki/National_Register_of_Historic_Places_listings_in_Ontario_County,_New_York
# /wiki/National_Register_of_Historic_Places_listings_in_Otsego_County,_New_York
# /wiki/National_Register_of_Historic_Places_listings_in_Cayuga_County,_New_York
# /wiki/Aurora_Village-Wells_College_Historic_District
# /wiki/National_Register_of_Historic_Places_listings_in_Manhattan_above_110th_Street
# /wiki/National_Register_of_Historic_Places_listings_in_Schenectady_County,_New_York
# /wiki/General_Electric_Realty_Plot
# /wiki/Mazda_(light_bulb)
# /wiki/General_Comprehensive_Operating_System
# /wiki/Mebibyte
# /wiki/Request_for_Comments
# /wiki/Best_Current_Practice
# /wiki/Internet_Engineering_Steering_Group
# /wiki/International_Telecommunication_Union
# /wiki/Telecommunications
# /wiki/Lille
# /wiki/Fort-de-France
# /wiki/Le_Marin
# /wiki/Sainte-Anne,_Martinique
# /wiki/Le_Lorrain
# /wiki/Le_Marigot
# /wiki/Le_Fran%C3%A7ois
# /wiki/Martinique
# /wiki/Plazas_de_soberan%C3%ADa
# /wiki/Spain_in_the_Middle_Ages
# /wiki/Hisham_II
# /wiki/Taifa_of_Seville
# /wiki/Al_Mualla
# /wiki/List_of_rulers_of_individual_Emirates_of_the_United_Arab_Emirates
# /wiki/History_of_the_United_Arab_Emirates
# /wiki/Hengqin
# /wiki/Jinshazhou
# /wiki/Haixinsha_Island_(Haizhu_District)
# /wiki/Pratas_Islands
# /wiki/Newsweek
# /wiki/HuffPost
# /wiki/Jenna_Busch
# /wiki/Entertainment_reporter
# /wiki/Weather_forecasting
# /wiki/Megha-Tropiques
# /wiki/Semi-major_axis
# /wiki/Transfer_orbit
# /wiki/Lyapunov_stability
# /wiki/Sofya_Kovalevskaya
# /wiki/Humboldt_Foundation
# /wiki/Werner_Heisenberg
# /wiki/ISBN_(identifier)
# /wiki/Currency
# /wiki/Harold_Hotelling
# /wiki/Confounding
# /wiki/Causal_inference
# /wiki/Doi_(identifier)
# /wiki/C_Sharp_(programming_language)
# /wiki/A_Sharp_(.NET)
# /wiki/Operating_system
# /wiki/S2CID_(identifier)
# /wiki/Machine_learning
# /wiki/False_negative_rate
# /wiki/Specificity_(tests)
# /wiki/False_positive_rate
# /wiki/Alternative_hypothesis
# /wiki/Multiple_comparisons
# /wiki/PMID_(identifier)
# /wiki/Review_article
# /wiki/Bias
# /wiki/Insider_trading#Legal_differences_among_jurisdictions
# /wiki/Portfolio_manager
# /wiki/ISSN_(identifier)
# /wiki/ISO_metric_screw_thread
# /wiki/ISO_1745
# /wiki/IS-IS
# /wiki/ISO/IEC_27006
# /wiki/Trusted_Platform_Module
# /wiki/OpeniBoot
# /wiki/Wake-on-LAN
# /wiki/ROM_image
# /wiki/CP_System_II
# /wiki/Capcom
# /wiki/GameSpot
# /wiki/Webby_Awards
# /wiki/Hollywood_Roosevelt_Hotel
# /wiki/Ambassador_Hotel_(Los_Angeles)
# /wiki/Max_Kennedy_Jr.
# /wiki/Democratic_Party_(United_States)
# /wiki/Modern_liberalism_in_the_United_States
# /wiki/Jack_Reed_(Rhode_Island_politician)
# /wiki/Jerry_Moran
# /wiki/Kansas_House_of_Representatives
# /wiki/Kansas_Historical_Quarterly
# /wiki/ISO_4
# /wiki/ISO_6385
# /wiki/Meta-Object_Facility
# /wiki/ISO/TR_11941
# /wiki/OCR-A
# /wiki/ISO_16750
# /wiki/ISO/IEC_20000
# /wiki/MPEG-7
# /wiki/Pixlet
# /wiki/High-Efficiency_Advanced_Audio_Coding
# /wiki/Comparison_of_audio_coding_formats
# /wiki/Ffdshow
# /wiki/Software_license
# /wiki/BSD_license
# /wiki/Timeline_of_free_and_open-source_software
# /wiki/GNU_Project
# /wiki/BSD_licenses
# /wiki/Berkeley_Software_Design
# /wiki/Mike_Karels
# /wiki/ISBN_(identifier)
# /wiki/Nielsen_Holdings
# /wiki/AsiaSat
# /wiki/International_Launch_Services
# /wiki/Proton_(rocket)
# /wiki/Circumlunar
# /wiki/Apollo_Lunar_Module
# /wiki/List_of_Hubble_anniversary_images
# /wiki/GALEX
# /wiki/AMC-9
# /wiki/Coordinated_Universal_Time
# /wiki/A_series_and_B_series
# /wiki/Tense%E2%80%93aspect%E2%80%93mood
# /wiki/Quantificational_variability_effect
# /wiki/Denotation
# /wiki/Ludwig_Wittgenstein
# /wiki/John_Searle
# /wiki/William_Lane_Craig
# /wiki/Jean-Luc_Marion
# /wiki/ISBN_(identifier)
# /wiki/PDF/A
# /wiki/ISO_31-10
# /wiki/ISO_13406-2
# /wiki/PDF/X
# /wiki/ISO_9660
# /wiki/ISO/IEC_7064
# /wiki/ISO/IEC_9797-1
# /wiki/ISO_11170
# /wiki/SDMX
# /wiki/ISO_31-3
# /wiki/Open_Document_Architecture
# /wiki/ISO/IEC_29119
# /wiki/Common_Language_Infrastructure
# /wiki/ISO/IEC_11801
# /wiki/Simple_Features
# /wiki/ISO_31-0
# /wiki/JPEG_XR
# /wiki/DOC_(computing)
# /wiki/Ebook
# /wiki/Andries_van_Dam
# /wiki/James_D._Meindl
# /wiki/Thomas_Kailath
# /wiki/Franz_Ollendorff
# /wiki/William_Gould_Dow
# /wiki/Franz_Ollendorff
# /wiki/Yasuharu_Suematsu
# /wiki/Athanasios_Papoulis
# /wiki/Joseph_Bordogna
# /wiki/Philadelphia
# /wiki/William_Penn
# /wiki/James_Nayler
# /wiki/Central_Yearly_Meeting_of_Friends
# /wiki/Anne_Conway_(philosopher)
# /wiki/Aristotle
# /wiki/Samuel_von_Pufendorf
# /wiki/Georg_Wilhelm_Friedrich_Hegel
# /wiki/Encyclopedia_of_the_Philosophical_Sciences
# /wiki/Theodor_W._Adorno
# /wiki/Han_Fei
# /wiki/Taoist_philosophy
# /wiki/Taoist_meditation
# /wiki/Mudra
# /wiki/Natya_Shastra
# /wiki/Devi
# /wiki/Shashthi
# /wiki/Tetanus
# /wiki/Ureaplasma_infection
# /wiki/Streptococcus_mitis
# /wiki/PMID_(identifier)
# /wiki/Google_Scholar
# /wiki/Global_IP_Solutions
# /wiki/Google_Swiffy
# /wiki/Google_Search_Console
# /wiki/Google_Forms
# /wiki/Google_Browser_Sync
# /wiki/Global_IP_Solutions
# /wiki/MyTracks
# /wiki/Realme
# /wiki/Chief_marketing_officer
# /wiki/Chief_solutions_officer
# /wiki/Chief_audit_executive
# /wiki/Chief_revenue_officer
# /wiki/Chief_commercial_officer
# /wiki/Chief_visionary_officer
# /wiki/Chief_privacy_officer
# /wiki/Health_Insurance_Portability_and_Accountability_Act#Security_Rule
# /wiki/Title_29_of_the_United_States_Code
# /wiki/United_States_Government_Printing_Office
# /wiki/U.S._senator_bibliography_(congressional_memoirs)
# /wiki/Elizabeth_Dole
# /wiki/Second-wave_feminism
# /wiki/Powers_of_the_president_of_the_United_States
# /wiki/Plum_Book
# /wiki/Barry_M._Goldwater_Scholarship
# /wiki/Brown_University
# /wiki/Times_Higher_Education
# /wiki/Walter_v_Lane
# /wiki/John_Witherow
# /wiki/Iran%E2%80%93Iraq_War
# /wiki/Financial_Times
# /wiki/Dominic_Lawson
# /wiki/Charles_Moore_(journalist)
# /wiki/Lord_Snooty
# /wiki/The_Beano_timeline
# /wiki/Jim_Petrie
# /wiki/David_Law_(cartoonist)
# /wiki/Ken_H._Harrison
# /wiki/Cracker_(comic)
# /wiki/The_Snookums
# /wiki/The_Wizard_(DC_Thomson)
# /wiki/Twinkle_(comics)
# /wiki/Judy_(comic)
# /wiki/Commando_(comics)
# /wiki/Evening_Telegraph_(Dundee)
# /wiki/Scotland_on_Sunday
# /wiki/Centre-right_politics
# /wiki/Leadership_election
# /wiki/2011_Israeli_Labor_Party_leadership_election
# /wiki/Golda_Meir
# /wiki/Carol_Mutter
# /wiki/Platoon
# /wiki/Industrial_warfare
# /wiki/Air_combat_manoeuvring
# /wiki/Immelmann_turn#Historical_combat_maneuver
# /wiki/German_Empire
# /wiki/Province_of_Hanover
# /wiki/Landkreis_Northeim
# /wiki/G%C3%B6ttingen_(district)
# /wiki/Germany
# /wiki/North_Sea
# /wiki/Seine
# /wiki/%C3%8Ele_aux_Juifs
# /wiki/Paul_Lacroix
# /wiki/Ren%C3%A9-Charles_Guilbert_de_Pix%C3%A9r%C3%A9court
# /wiki/Nancy,_France
# /wiki/Morfontaine
# /wiki/Gondrexon
# /wiki/Arnaville
# /wiki/Doncourt-l%C3%A8s-Conflans
# /wiki/Bagneux,_Meurthe-et-Moselle
# /wiki/Daylight_saving_time
# /wiki/Tz_database
# /wiki/Erlang_(programming_language)
# /wiki/Light-weight_process
# /wiki/Futures_and_promises
# /wiki/Actor_model
# /wiki/Kyoto_University
# /wiki/Hosei_University
# /wiki/Prudential_Tower_(Tokyo)
# /wiki/Kokyo_Gaien_National_Garden
# /wiki/National_Museum_of_Modern_Art,_Tokyo
# /wiki/Routledge
# /wiki/Wayback_Machine
# /wiki/List_of_Web_archiving_initiatives
# /wiki/Heritrix
# /wiki/Bingbot
# /wiki/FAST_Crawler
# /wiki/HTML
# /wiki/HTML5
# /wiki/GreenBrowser
# /wiki/Yandex_Browser
# /wiki/Yandex.Checkout
# /wiki/Yandex.Drive
# /wiki/Enterprise_Rent-a-Truck
# /wiki/Jucy_Group_Limited
# /wiki/EvCard
# /wiki/TR_Group
# /wiki/Payless_Car_Rental
# /wiki/Jucy_Group_Limited
# /wiki/Carsharing
# /wiki/Connect_by_Hertz
# /wiki/List_of_S%26P_400_companies
# /wiki/Coraopolis,_Pennsylvania
# /wiki/Third_Party_(United_States)
# /wiki/Western_United_States
# /wiki/Indian_Ocean
# /wiki/Body_of_water#Waterbody_types
# /wiki/Whitewater_canoeing
# /wiki/International_Canoe
# /wiki/Nacra_17
# /wiki/Finn_(dinghy)
# /wiki/Tornado_(sailboat)
# /wiki/United_Kingdom
# /wiki/London
# /wiki/London_General
# /wiki/London_Buses_route_57
# /wiki/London_Buses_route_X140
# /wiki/Brent_Cross_bus_station
# /wiki/Hyde_Park,_London
# /wiki/ISBN_(identifier)
# /wiki/List_of_IEC_standards
# /wiki/Video_tape_recorder
# /wiki/JVC
# /wiki/Sega
# /wiki/Kotaku
# /wiki/WYEL
# /wiki/WWJE-DT
# /wiki/KAMA-FM
# /wiki/KZNX
# /wiki/KAMX
# /wiki/KJKK
# /wiki/K273CS
# /wiki/K273CS
# /wiki/KDGE
# /wiki/KKLF
# /wiki/WBAP_(AM)
# /wiki/WJEZ
# /wiki/KZRK-FM
# /wiki/KAVO_(FM)
# /wiki/De_Queen,_Arkansas
# /wiki/Melbourne,_Arkansas
# /wiki/Pine_Bluff,_Arkansas
# /wiki/The_Arkansas_Historical_Quarterly
# /wiki/LCCN_(identifier)
# /wiki/Virtual_International_Authority_File
# /wiki/Italian_language
# /wiki/Volcanism_of_Italy
# /wiki/Military_history_of_Italy
# /wiki/Foreign_involvement_in_the_Spanish_Civil_War
# /wiki/Bolivia
# /wiki/Apolo,_La_Paz
# /wiki/Combaya
# /wiki/Aucapata
# /wiki/Ayo_Ayo_Municipality
# /wiki/Licoma
# /wiki/Chacaltaya
# /wiki/Andes
# /wiki/Andean_Geology
# /wiki/Editor-in-chief
# /wiki/Staff_writer
# /wiki/Editor-in-chief
# /wiki/Journalist
# /wiki/Columnist
# /wiki/Infotainment
# /wiki/Influence_of_mass_media
# /wiki/Post-Fordism
# /wiki/Ash_Amin
# /wiki/Commander_of_the_Order_of_the_British_Empire
# /wiki/Distinguished_Service_Medal_(United_Kingdom)
# /wiki/King%27s_Police_Medal
# /wiki/The_London_Gazette
# /wiki/United_Kingdom
# /wiki/Monarchy_in_the_Cook_Islands
# /wiki/Kingdom_of_Cyprus
# /wiki/Hugh_II_of_Cyprus
# /wiki/Nicosia
# /wiki/Minsk
# /wiki/Independence_Avenue_(Minsk)
# /wiki/Yakub_Kolas_Square
# /wiki/Vera_Khoruzhaya
# /wiki/Zoya_Kosmodemyanskaya
# /wiki/Wayback_Machine
# /wiki/Copyright_infringement
# /wiki/Criminal
# /wiki/Right_to_silence
# /wiki/Legal_abuse
# /wiki/Legal_malpractice
# /wiki/Ex_turpi_causa_non_oritur_actio
# /wiki/Trover
# /wiki/Fraud
# /wiki/Common_purpose
# /wiki/Jurisdiction_(area)
# /wiki/Political_division
# /wiki/Burgh
# /wiki/Fraserburgh
# /wiki/Insch
# /wiki/Crimond
# /wiki/Lonmay
# /wiki/Stonehaven
# /wiki/William_Wallace
# /wiki/Wallace_(surname)
# /wiki/Bill_Wallace_(American_football)
# /wiki/Jac_Weller
# /wiki/The_Hun_School
# /wiki/Boston_Red_Sox
# /wiki/Ray_Collins_(baseball)
# /wiki/Hugh_Bedient
# /wiki/Duffy_Lewis
# /wiki/Heinie_Wagner
# /wiki/Boston_Red_Sox
# /wiki/Commissioner_of_Baseball
# /wiki/Fenway_Park
# /wiki/2005_Boston_Red_Sox_season
# /wiki/Eastern_League_(1938%E2%80%932020)
# /wiki/New_Britain_Rock_Cats
# /wiki/Jorge_Polanco
# /wiki/Pablo_L%C3%B3pez_(baseball)
# /wiki/Pitcher
# /wiki/Setup_pitcher
# /wiki/Closer_(baseball)
# /wiki/Pat_Gillick
# /wiki/General_manager_(baseball)
# /wiki/Charlie_Gehringer
# /wiki/Pie_Traynor
# /wiki/1925_Pittsburgh_Pirates_season
# /wiki/Red_Oldham
# /wiki/Al_Stump
# /wiki/Colorado_Springs,_Colorado
# /wiki/United_States_Olympic_%26_Paralympic_Committee
# /wiki/USA_Football
# /wiki/Raymond_T._Odierno
# /wiki/United_States_Military_Academy
# /wiki/Economic_diversity
# /wiki/Wealth
# /wiki/Productivity
# /wiki/Robert_Solow
# /wiki/Yakir_Aharonov
# /wiki/Weak_value
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Indecs_Content_Model
# /wiki/Product_life_cycle_management
# /wiki/Product_management
# /wiki/Change_management
# /wiki/Executive_sponsor
# /wiki/Washwood_Heath#Project_Champion
# /wiki/List_of_law_enforcement_agencies_in_the_United_Kingdom,_Crown_Dependencies_and_British_Overseas_Territories
# /wiki/Havering_Parks_Constabulary
# /wiki/Manchester_Airport_Police
# /wiki/List_of_law_enforcement_agencies_in_the_United_Kingdom,_Crown_Dependencies_and_British_Overseas_Territories#Ports_police
# /wiki/Derbyshire_Constabulary
# /wiki/Chesterfield,_Derbyshire
# /wiki/Arnold_Laver
# /wiki/BOC_(company)
# /wiki/Dal%C3%A9n_light
# /wiki/Lists_of_lighthouses#Oceania
# /wiki/Sector_light
# /wiki/Pharology
# /wiki/F._Ross_Holland
# /wiki/United_States_Navy
# /wiki/Central_Security_Service
# /wiki/Joint_Worldwide_Intelligence_Communications_System
# /wiki/Wayback_Machine
# /wiki/United_States_patent_office
# /wiki/Criticism_of_the_United_States_government#Criticism_of_agencies
# /wiki/United_States%E2%80%93Venezuela_relations
# /wiki/Abkhazia%E2%80%93Venezuela_relations
# /wiki/India%E2%80%93Venezuela_relations
# /wiki/India%E2%80%93Soviet_Union_relations
# /wiki/Indian_Technical_and_Economic_Cooperation_Programme
# /wiki/Hamid_Karzai
# /wiki/2009_Afghan_presidential_election
# /wiki/Hedayat_Arsala
# /wiki/Frontline_(U.S._TV_series)
# /wiki/The_Victory_Garden_(TV_program)
# /wiki/IMDb_(identifier)
# /wiki/Amazon_Air
# /wiki/Amapedia
# /wiki/Statistically_improbable_phrase
# /wiki/Amazon_Lightsail
# /wiki/VentureBeat
# /wiki/The_Mercury_News
# /wiki/San_Mateo_County,_California
# /wiki/Bay_Point,_California
# /wiki/Petaluma_River
# /wiki/Save_the_Bay
# /wiki/Oakland,_California
# /wiki/Fox_Oakland_Theater
# /wiki/Atoms_For_Peace
# /wiki/Excise_Tax_Reduction_Act_of_1954
# /wiki/Operation_40
# /wiki/Nixon_Doctrine
# /wiki/People_Power_Revolution
# /wiki/Arthur_M._Schlesinger_Jr.
# /wiki/Dhofar_Rebellion
# /wiki/Guatemalan_Civil_War
# /wiki/Economy_of_Guatemala
# /wiki/Economy_of_India
# /wiki/Hyderabad
# /wiki/Formula_E
# /wiki/Artistic_Billiards_World_Championship
# /wiki/FINA_World_Swimming_Championships_(25_m)
# /wiki/Major_achievements_in_swimming_by_nation
# /wiki/United_States
# /wiki/Economic_Policy_Institute
# /wiki/AFSCME
# /wiki/Waste_collector
# /wiki/Biological_hazard
# /wiki/Occupational_Safety_and_Health_Administration
# /wiki/Tennessee
# /wiki/Memphis_International_Airport
# /wiki/Viracopos_International_Airport
# /wiki/Bras%C3%ADlia_International_Airport
# /wiki/Bras%C3%ADlia_Air_Force_Base
# /wiki/Agriculture_in_Brazil
# /wiki/Agriculture_in_Chile
# /wiki/Phylloxera
# /wiki/Powdery_mildew
# /wiki/Blumeria_graminis
# /wiki/PMID_(identifier)
# /wiki/University_at_Buffalo
# /wiki/Jamestown_Community_College
# /wiki/SUNY-ESF_Ranger_School
# /wiki/Rural_area
# /wiki/Street_market
# /wiki/Wet_market
# /wiki/Supermarket
# /wiki/Heron_Foods
# /wiki/Lincoln_Green
# /wiki/West_Yorkshire
# /wiki/Real_ale
# /wiki/American_pale_ale
# /wiki/Fritz_Maytag
# /wiki/Maytag_Blue_cheese
# /wiki/ISBN_(identifier)
# /wiki/ISO_6385
# /wiki/ISO_15926
# /wiki/ISO/IEC_8859
# /wiki/%C4%BB
# /wiki/French_language
# /wiki/Luxembourg
# /wiki/Cayman_Islands
# /wiki/Caricom
# /wiki/Great_power
# /wiki/David_Lloyd_George
# /wiki/Centre-left_politics
# /wiki/Revolutionary
# /wiki/Journals_of_the_Continental_Congress
# /wiki/John_Dickinson
# /wiki/Second_Amendment_to_the_United_States_Constitution
# /wiki/William_Blackstone
# /wiki/Natural_law
# /wiki/The_Macmillan_Company
# /wiki/ISSN_(identifier)
# /wiki/Location_(geography)
# /wiki/Human_settlement
# /wiki/Building
# /wiki/Attic
# /wiki/Loft
# /wiki/Parlour
# /wiki/Secret_passage
# /wiki/C%E1%BB%A7_Chi_tunnels
# /wiki/1960_South_Vietnamese_coup_attempt
# /wiki/Double_Seven_Day_scuffle
# /wiki/Buddhist_crisis
# /wiki/Ng%C3%B4_%C4%90%C3%ACnh_Di%E1%BB%87m
# /wiki/Dalat_University
# /wiki/Business_Administration
# /wiki/Office_administration
# /wiki/Receptionist
# /wiki/Tour_guide
# /wiki/Yoga_tourism
# /wiki/List_of_archaeoastronomical_sites_by_country#India
# /wiki/Amap%C3%A1
# /wiki/Territory
# /wiki/China
# /wiki/United_Nations
# /wiki/International_Red_Cross_and_Red_Crescent_Movement
# /wiki/Cyprus_Red_Cross
# /wiki/List_of_Red_Cross_and_Red_Crescent_Societies
# /wiki/Slovenia
# /wiki/Samo
# /wiki/Old_German
# /wiki/Mohawk_Dutch
# /wiki/Southeast_Limburgish_dialect
# /wiki/Siegen
# /wiki/Karlsruhe
# /wiki/Dandy_horse
# /wiki/Paddleboarding
# /wiki/Adirondack_Canoe_Classic
# /wiki/Umiak
# /wiki/Inughuit
# /wiki/Inuit_Tapiriit_Kanatami
# /wiki/Nunatsiavut
# /wiki/List_of_census_agglomerations_in_Newfoundland_and_Labrador
# /wiki/Corner_Brook
# /wiki/Precipitation
# /wiki/Atmospheric_chemistry
# /wiki/Acid_rain
# /wiki/Doi_(identifier)
# /wiki/POSIX
# /wiki/Nucleus_RTOS
# /wiki/I%C2%B2C
# /wiki/Front-side_bus
# /wiki/VME_eXtensions_for_Instrumentation
# /wiki/RS-423
# /wiki/Profibus
# /wiki/De_facto_standard
# /wiki/Phone_connector_(audio)
# /wiki/Ziff-Davis_Press
# /wiki/ZDNet
# /wiki/News_website
# /wiki/Doi_(identifier)
# /wiki/Renard_series
# /wiki/Common_Criteria
# /wiki/ISO_14031
# /wiki/ISO_17100
# /wiki/ISO/IEC_7810
# /wiki/JPEG_XR
# /wiki/ISO_11170
# /wiki/ISO_18245
# /wiki/A440_(pitch_standard)
# /wiki/CHILL
# /wiki/ISO_26000
# /wiki/ISO/IEC_2022
# /wiki/ISO_11992
# /wiki/RM-ODP
# /wiki/Enterprise_architecture_framework
# /wiki/DoDAF
# /wiki/CADM
# /wiki/NASA
# /wiki/Ranger_Program
# /wiki/Gross_Domestic_Product_deflator
# /wiki/Market_basket
# /wiki/GDP_deflator
# /wiki/Consumer_price_index
# /wiki/Quantitative_tightening
# /wiki/The_New_York_Times
# /wiki/Montgomery_Advertiser
# /wiki/Ku_Klux_Klan
# /wiki/Andrew_Goodman_(activist)
# /wiki/NAACP
# /wiki/Dorothy_Tillman
# /wiki/Memphis_sanitation_strike
# /wiki/Eyes_on_the_Prize
# /wiki/Sanford_R._Leigh
# /wiki/Civil_rights_movement
# /wiki/Supreme_Court_of_the_United_States
# /wiki/Calvin_Coolidge_Supreme_Court_candidates
# /wiki/Federal_Radio_Commission
# /wiki/Immigration_Act_of_1924
# /wiki/Netherlands
# /wiki/Denmark
# /wiki/List_of_World_Heritage_Sites_in_North_America
# /wiki/Precambrian
# /wiki/Evolution_of_fungi
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_17025
# /wiki/IEC_62196
# /wiki/IEC_61851
# /wiki/SAE_J3105
# /wiki/SAE_J306
# /wiki/AS9100
# /wiki/F%C3%A9d%C3%A9ration_Internationale_des_Soci%C3%A9t%C3%A9s_d%27Ing%C3%A9nieurs_des_Techniques_de_l%27Automobile
# /wiki/SAE_Aerodesign
# /wiki/440C
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_11404
# /wiki/ISO/IEC_9529
# /wiki/SDMX
# /wiki/MPEG-4
# /wiki/MPEG_transport_stream
# /wiki/Time-division_multiplexing
# /wiki/Whistled_language
# /wiki/PMC_(identifier)
# /wiki/Citation_index
# /wiki/PubMed
# /wiki/Abstract_(summary)
# /wiki/IMRAD
# /wiki/Matt_Vassar
# /wiki/Oncology
# /wiki/Tumor_suppressor_gene
# /wiki/Oncogenes
# /wiki/Signal_transduction
# /wiki/ISBN_(identifier)
# /wiki/ISO_657
# /wiki/ISO/IEC_7813
# /wiki/Integrated_circuit
# /wiki/Model_of_computation
# /wiki/Random-access_machine
# /wiki/Universal_Turing_machine
# /wiki/Lynn_Steen
# /wiki/Northfield,_Minnesota
# /wiki/Mendota_Heights,_Minnesota
# /wiki/Eden_Prairie,_Minnesota
# /wiki/Watonwan_County,_Minnesota
# /wiki/Saint_Paul,_Minnesota
# /wiki/Light_rail
# /wiki/High-speed_rail
# /wiki/High-speed_rail_in_Norway
# /wiki/Rauma_Line
# /wiki/Gj%C3%B8vik_Line
# /wiki/Bleiken_Station
# /wiki/Jaren_Station
# /wiki/Bane_NOR
# /wiki/Infrabel
# /wiki/Russian_Railways
# /wiki/Belarusian_Railway
# /wiki/DSB_(railway_company)
# /wiki/List_of_DSB_locomotives_and_multiple_units
# /wiki/Bo-Bo
# /wiki/Grovers_bogie
# /wiki/Tram
# /wiki/Dalian
# /wiki/Gaomi
# /wiki/Weifang
# /wiki/Wayback_Machine
# /wiki/PepsiCo
# /wiki/Vending_machines
# /wiki/Photo_booth
# /wiki/1996_in_video_games
# /wiki/Sony_Computer_Entertainment
# /wiki/Patapon
# /wiki/Robert_Langdon_(franchise)
# /wiki/Box_Office_Mojo
# /wiki/Amazon.com,_Inc._v._Barnesandnoble.com,_Inc.
# /wiki/AWS_Elastic_Beanstalk
# /wiki/Sellaband
# /wiki/BlackBerry_World
# /wiki/BlackBerry_Z10
# /wiki/Telus_Mobility
# /wiki/Inukshuk_Wireless
# /wiki/TV_Rogers
# /wiki/Shaw_Communications
# /wiki/Cable_television
# /wiki/History_of_television
# /wiki/Casting_director
# /wiki/30_Rock
# /wiki/College_(30_Rock)
# /wiki/Hogcock!
# /wiki/The_Break-Up_(30_Rock)
# /wiki/The_Rural_Juror
# /wiki/30_Rock
# /wiki/Desperate_Housewives_(season_1)
# /wiki/Wayback_Machine
# /wiki/Time_capsule
# /wiki/Era_(geology)
# /wiki/Latin
# /wiki/Roman_cursive
# /wiki/Getty-Dubay_Italic
# /wiki/Visigothic_script
# /wiki/Kawi_script
# /wiki/Buhid_script
# /wiki/William_Bell_Wait
# /wiki/Luxembourgish_Braille
# /wiki/Optical_braille_recognition
# /wiki/Gardner%E2%80%93Salinas_braille_codes
# /wiki/Decapoint
# /wiki/Gujarati_Braille
# /wiki/Tamil_Braille
# /wiki/Navajo_Braille
# /wiki/Ghanaian_braille
# /wiki/Perkins_Brailler
# /wiki/Portuguese_Braille
# /wiki/%C3%81
# /wiki/IJ_(digraph)
# /wiki/T-rules
# /wiki/Subjunctive
# /wiki/Relative_pronoun
# /wiki/Nominalized_adjective
# /wiki/Ditransitive_verb
# /wiki/Pronoun
# /wiki/Demonstrative_pronoun
# /wiki/Proper_and_common_nouns
# /wiki/German_name
# /wiki/Diminutive
# /wiki/Mongolian_name
# /wiki/Democratic_Republic_of_the_Congo_naming_customs
# /wiki/Eastern_Slavic_naming_customs
# /wiki/Akan_names
# /wiki/Anansi
# /wiki/Rabbit_Ears_Productions_media_and_release_information
# /wiki/Max_von_Sydow
# /wiki/Robert_Gustafsson
# /wiki/Stellan_Skarsg%C3%A5rd
# /wiki/Bj%C3%B6rn_Ulvaeus
# /wiki/Sweden_in_the_Eurovision_Song_Contest_1974
# /wiki/Brighton
# /wiki/Brighton_and_Hove
# /wiki/Derby
# /wiki/Cardiff
# /wiki/Bath,_Somerset
# /wiki/Trunk_road
# /wiki/Main_Street
# /wiki/United_States_of_America
# /wiki/Great_Recession
# /wiki/General_glut
# /wiki/Great_Depression_in_the_United_States
# /wiki/Adrian_Wooldridge
# /wiki/Warren_T._Brookes
# /wiki/Floyd_Norris
# /wiki/Holman_W._Jenkins_Jr.
# /wiki/Asian_Wall_Street_Journal
# /wiki/S%26P_Dow_Jones_Indices
# /wiki/Hong_Kong
# /wiki/Bauhinia_%C3%97_blakeana
# /wiki/March_of_the_Volunteers
# /wiki/Gambling_in_Macau#Gaming_law
# /wiki/Gambling_in_Italy
# /wiki/Revolutions_of_1830#In_Italy
# /wiki/Constitution_of_Belgium
# /wiki/Police_tribunal_(Belgium)
# /wiki/Halle,_Belgium
# /wiki/Braine-le-Ch%C3%A2teau
# /wiki/Halle,_Belgium
# /wiki/Philip_IV_of_Spain
# /wiki/House_of_Lorraine
# /wiki/Adalbert,_Duke_of_Lorraine
# /wiki/William_I,_Count_of_Burgundy
# /wiki/Urraca_of_Le%C3%B3n_and_Castile
# /wiki/Muniadona_of_Castile
# /wiki/Justo_P%C3%A9rez_de_Urbel
# /wiki/Cortes_Generales#Cortes_Generales_under_Franco_regime_(1939–1978)
# /wiki/C%C3%A1ndido_Conde-Pumpido
# /wiki/Central_Intelligence_Agency
# /wiki/Islamism
# /wiki/Salafi_movement
# /wiki/Islamic_revival
# /wiki/Ayman_al-Zawahiri
# /wiki/United_States_Intelligence_Community
# /wiki/List_of_earthquakes_in_the_United_States
# /wiki/List_of_historical_tsunamis
# /wiki/Nankai_earthquake
# /wiki/Nankai_megathrust
# /wiki/Gas_hydrates
# /wiki/Bibcode_(identifier)
# /wiki/Astronomy
# /wiki/CRC_Press
# /wiki/Fan_Expo_Chicago
# /wiki/Farm_Progress
# /wiki/Agrochemical
# /wiki/Monsanto
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_8859
# /wiki/%E0%B8%98
# /wiki/Pyu_script
# /wiki/Todhri_script
# /wiki/Johann_Georg_von_Hahn
# /wiki/South_Morava
# /wiki/Government_of_Kosovo
# /wiki/Neolithic_sites_in_Kosovo
# /wiki/First_Balkan_War
# /wiki/Battle_of_Livno
# /wiki/Croatian%E2%80%93Bulgarian_battle_of_854
# /wiki/French_Revolutionary_Wars
# /wiki/Siege_of_Toulon_(1793)
# /wiki/Hulk_(ship_type)
# /wiki/Great_Britain
# /wiki/Southeast_Asia
# /wiki/Gilgit-Baltistan
# /wiki/Azad_Jammu_and_Kashmir
# /wiki/1941_Census_of_Jammu_and_Kashmir
# /wiki/Narsinghgarh_State
# /wiki/Barwani_State
# /wiki/Mudhol_State
# /wiki/Ajaigarh_State
# /wiki/Sailana_State
# /wiki/Patna_State
# /wiki/Kishangarh_State
# /wiki/India
# /wiki/ISBN_(identifier)
# /wiki/List_of_group-0_ISBN_publisher_codes
# /wiki/Chatto_%26_Windus
# /wiki/Richard_Aldington
# /wiki/JSTOR_(identifier)
# /wiki/Ann_Arbor,_Michigan
# /wiki/Eastlawn,_Michigan
# /wiki/Willow_Run,_Michigan
# /wiki/Sharon,_Michigan
# /wiki/Lima_Township,_Michigan
# /wiki/Civil_township
# /wiki/Provinces_of_Finland
# /wiki/Judicial_system_of_Finland#General_Courts
# /wiki/Warrant_officer
# /wiki/Junior_officer
# /wiki/Aircraftman
# /wiki/Trooper_(rank)
# /wiki/Flag_officer
# /wiki/Royal_Navy_other_rank_insignia
# /wiki/Ranks_and_insignia_of_the_Confederate_States
# /wiki/Rank_insignia_of_the_Iranian_military
# /wiki/Military_ranks_of_the_Ottoman_Empire
# /wiki/Ranks_and_insignia_of_the_Imperial_Russian_Armed_Forces
# /wiki/Cyprus_military_ranks
# /wiki/Comparative_air_force_enlisted_ranks_of_Asia
# /wiki/Yefreytor
# /wiki/Swiss_army_ranks
# /wiki/Comparative_army_officer_ranks_of_Lusophone_countries
# /wiki/Comparative_air_force_officer_ranks_of_Oceania
# /wiki/Comparison_of_United_Kingdom_and_United_States_military_ranks
# /wiki/Royal_Engineers
# /wiki/Chatham,_Kent
# /wiki/Chatham_Dockyard
# /wiki/Spinning_(textiles)
# /wiki/Myanmar
# /wiki/Amnesty_International
# /wiki/Prisoners_of_conscience
# /wiki/Incarceration_in_the_United_States#Privatization
# /wiki/Northern_Ireland_Prison_Service
# /wiki/Irish_Republican_Army
# /wiki/Irish_Civil_War
# /wiki/Irish_rebellion_of_1803
# /wiki/Saor_%C3%89ire
# /wiki/Northern_Ireland
# /wiki/Royal_assent
# /wiki/Serjeant-at-arms#Canada
# /wiki/United_States_Congress
# /wiki/United_States_congressional_conference_committee
# /wiki/United_States_nationality_law
# /wiki/William_French_Smith
# /wiki/Office_of_the_United_States_Trade_Representative
# /wiki/Office_of_Federal_Financial_Management
# /wiki/White_House_Chief_Floral_Designer
# /wiki/Truman_Balcony
# /wiki/Statue_of_the_Marquis_de_Lafayette_(Washington,_D.C.)
# /wiki/National_Register_of_Historic_Places
# /wiki/Grants-in-aid
# /wiki/Public_funding
# /wiki/ISBN_(identifier)
# /wiki/Modular_arithmetic
# /wiki/List_of_recreational_number_theory_topics
# /wiki/Powerful_number
# /wiki/Primitive_abundant_number
# /wiki/Evil_number
# /wiki/Pancake_sorting
# /wiki/Introsort
# /wiki/Tournament_sort
# /wiki/Transdichotomous_model
# /wiki/Analysis_of_algorithms
# /wiki/Video_game
# /wiki/Nonviolent_video_game
# /wiki/Video_game_genre
# /wiki/Action-adventure_game
# /wiki/Online_gambling
# /wiki/Variability_hypothesis
# /wiki/Anne_Fernald
# /wiki/PMC_(identifier)
# /wiki/Open-notebook_science
# /wiki/Sci-Mate
# /wiki/Cell_lines
# /wiki/Henrietta_Lacks
# /wiki/Baltimore_County,_Maryland
# /wiki/Joseph_Bartenfelder
# /wiki/Jeff_Witte
# /wiki/Mike_Freiberg
# /wiki/Minnesota_Secretary_of_State
# /wiki/Murray_County,_Minnesota
# /wiki/Wirock,_Minnesota
# /wiki/Chandler,_Minnesota
# /wiki/Turbine
# /wiki/Water_turbine
# /wiki/Algorithm
# /wiki/Computer_science
# /wiki/Glossary_of_aerospace_engineering
# /wiki/Planet
# /wiki/Oberon_(moon)
# /wiki/William_Lassell
# /wiki/University_of_Cambridge
# /wiki/Royal_Holloway,_University_of_London
# /wiki/Strode%27s_College
# /wiki/South_Farnham_School
# /wiki/Pierrepont_School,_Frensham
# /wiki/Farnham_College
# /wiki/Notre_Dame_School,_Surrey
# /wiki/City_of_London_Freemen%27s_School
# /wiki/Red_Riding
# /wiki/Riding_(country_subdivision)
# /wiki/Leges_Edwardi_Confessoris
# /wiki/Henry_de_Bracton
# /wiki/Shire
# /wiki/James_City_Shire
# /wiki/Newport_News,_Virginia
# /wiki/Alleghany_County,_Virginia
# /wiki/Race_(United_States_Census)
# /wiki/American_ancestry
# /wiki/Know_Nothing#Underlying_issues
# /wiki/United_States_Secretary_of_War
# /wiki/Joseph_Doe
# /wiki/Wisconsin_National_Guard
# /wiki/Warrant_officer_(United_States)
# /wiki/Flag_of_the_United_States_Army
# /wiki/United_States_Senate_Committee_on_Armed_Services
# /wiki/Semper_Supra_(march)
# /wiki/Battle_Cry_of_Freedom
# /wiki/The_U.S._Air_Force_(song)
# /wiki/List_of_United_States_Air_Force_personnel
# /wiki/Forbes_400
# /wiki/New_York_(state)
# /wiki/Syracuse,_New_York
# /wiki/State_University_of_New_York_College_of_Environmental_Science_and_Forestry
# /wiki/Ecological_Society_of_America
# /wiki/American_Association_for_the_Advancement_of_Science
# /wiki/Science_(journal)
# /wiki/ISSN_(identifier)
# /wiki/MPEG-4
# /wiki/IEC_60601
# /wiki/Canada
# /wiki/Canadian_beer
# /wiki/Maple_syrup
# /wiki/Flue
# /wiki/Radiant_heating
# /wiki/ISSN_(identifier)
# /wiki/ISO_10303-21
# /wiki/ISO_5964
# /wiki/Film_speed
# /wiki/ISO_31-6
# /wiki/ISO/IEC_7816
# /wiki/Vicinity_card
# /wiki/ISO/IEC_80000
# /wiki/ISO/IEC_11179
# /wiki/ISO/IEC_17025
# /wiki/ISO_10006
# /wiki/ISO_20400
# /wiki/ISO_7200
# /wiki/STEP-NC
# /wiki/ISO_2
# /wiki/ISO_22300
# /wiki/ISO/IEC_9126
# /wiki/ISO_31-5
# /wiki/ISO_2047
# /wiki/Software_maintenance
# /wiki/Software_project_management
# /wiki/Software_developers
# /wiki/Great_Recession
# /wiki/Member_states_of_the_Commonwealth_of_Nations
# /wiki/United_Nations_geoscheme_for_Africa
# /wiki/The_Gambia
# /wiki/United_Party_(Gambia)
# /wiki/United_Democratic_Party_(The_Gambia)
# /wiki/Politics_of_Gambia
# /wiki/Politics_of_Madeira
# /wiki/Funchal
# /wiki/Algeria
# /wiki/Doi_(identifier)
# /wiki/ISO_843
# /wiki/ISO_3103
# /wiki/STEP-NC
# /wiki/ISO_639-5
# /wiki/ISO_704
# /wiki/JPEG_XS
# /wiki/RTVideo
# /wiki/Line_spectral_pairs
# /wiki/Psychoacoustics
# /wiki/Music
# /wiki/ISBN_(identifier)
# /wiki/ISO_15189
# /wiki/ISO_8583
# /wiki/PDF/E
# /wiki/Ada_Semantic_Interface_Specification
# /wiki/IEC_60320
# /wiki/Mains_supply
# /wiki/BC_Hydro
# /wiki/The_Globe_and_Mail
# /wiki/The_Globe_(Toronto_newspaper)
# /wiki/Reform_movement_(pre-Confederation_Canada)
# /wiki/Orange_Order
# /wiki/Ulster_Defence_Association
# /wiki/John_McMichael
# /wiki/Ned_McCreery
# /wiki/Sam_McCrory_(loyalist)
# /wiki/Francisco_Notarantonio
# /wiki/Tommy_English_(loyalist)
# /wiki/Charlemont_pub_attacks
# /wiki/1970_Crossmaglen_bombing
# /wiki/Crossmaglen
# /wiki/Newry,_Mourne_and_Down
# /wiki/Derry_City_and_Strabane_District_Council
# /wiki/Newry,_Mourne_and_Down_District_Council
# /wiki/Sinn_F%C3%A9in
# /wiki/The_Irish_Times
# /wiki/Dublin
# /wiki/Hungary_in_the_Eurovision_Song_Contest
# /wiki/Festivali_i_K%C3%ABng%C3%ABs
# /wiki/Va%C3%A7e_Zela
# /wiki/Dardan_discography
# /wiki/Elita_5
# /wiki/2008_G%C3%ABrdec_explosions
# /wiki/2008_Chelopechene_explosions
# /wiki/Taxiway
# /wiki/Taxiing
# /wiki/Lockheed_C-130_Hercules
# /wiki/Lockheed_LC-130
# /wiki/Lockheed_XP-49
# /wiki/Lockheed_YF-22
# /wiki/Sukhoi_Su-57
# /wiki/Langkawi_International_Maritime_and_Aerospace_Exhibition
# /wiki/AgustaWestland_AW189
# /wiki/Agusta_A.115
# /wiki/Bell_47
# /wiki/Bell_Model_47
# /wiki/Savoia-Marchetti_S.55
# /wiki/Umberto_Nobile
# /wiki/Southern_Cross_Expedition
# /wiki/Ivan_Fyodorov_(navigator)
# /wiki/Georgy_Sedov
# /wiki/Georgy_Ushakov
# /wiki/Erik_the_Red
# /wiki/Arctic_Circle
# /wiki/95th_meridian_west
# /wiki/Minnesota
# /wiki/Broomball
# /wiki/Ice_skates
# /wiki/Steel-toe_boot
# /wiki/Chopine
# /wiki/Turnshoes
# /wiki/Shoe_last
# /wiki/Linguistic_reconstruction
# /wiki/Sorin_Paliga
# /wiki/Alexis_Manaster_Ramer
# /wiki/Georgiy_Starostin
# /wiki/Internal_reconstruction
# /wiki/Alexis_Manaster_Ramer
# /wiki/Macrofamily
# /wiki/Linguistic_reconstruction
# /wiki/Allan_R._Bomhard
# /wiki/John_Bengtson
# /wiki/Association_for_the_Study_of_Language_in_Prehistory
# /wiki/Sorin_Paliga
# /wiki/Austric_languages
# /wiki/Pacoh_language
# /wiki/Laotian_sign_languages
# /wiki/Taiwanese_Sign_Language
# /wiki/Tibetan_Sign_Language
# /wiki/Henniker_Sign_Language
# /wiki/Gambian_Sign_Language
# /wiki/Tactile_signing
# /wiki/Nicaraguan_Sign_Language
# /wiki/Old_Costa_Rican_Sign_Language
# /wiki/Deaf-community_sign_language
# /wiki/Yol%C5%8Bu_Sign_Language
# /wiki/Mehek_Sign_Language
# /wiki/Plateau_Sign_Language
# /wiki/Chinook_Jargon
# /wiki/Tolowa_language
# /wiki/National_Geographic_Society
# /wiki/BioNTech
# /wiki/Cambridge,_Massachusetts
# /wiki/Dedham,_Massachusetts
# /wiki/Alien_and_Sedition_Acts
# /wiki/The_Adams_Chronicles
# /wiki/John_Quincy_Adams#Notes
# /wiki/Cordell_Hull
# /wiki/Nobel_Peace_Prize
# /wiki/1968_Nobel_Peace_Prize
# /wiki/Michael_Landmann
# /wiki/Kiel
# /wiki/M%C3%BCnster
# /wiki/Fernmeldeturm_M%C3%BCnster
# /wiki/M%C3%BCnster
# /wiki/Time_in_Germany
# /wiki/Time_in_Latvia
# /wiki/Western_European_Summer_Time
# /wiki/Western_European_Time
# /wiki/Irish_Standard_Time
# /wiki/European_Union
# /wiki/ISBN_(identifier)
# /wiki/Renard_series
# /wiki/ISO_31-12
# /wiki/Power_take-off
# /wiki/Balancing_machine
# /wiki/Propeller
# /wiki/James_Watt
# /wiki/Bo%27ness
# /wiki/Clock
# /wiki/Tense%E2%80%93aspect%E2%80%93mood
# /wiki/Exhaustivity
# /wiki/Speech_act
# /wiki/De_se
# /wiki/Existential_closure
# /wiki/Distributional_semantics
# /wiki/Automatic_summarization
# /wiki/Text_mining
# /wiki/S2CID_(identifier)
# /wiki/Academic_journal
# /wiki/Research
# /wiki/Institutional_review_board
# /wiki/Project_MKULTRA
# /wiki/Wormwood_(miniseries)
# /wiki/The_Curious_Creations_of_Christine_McConnell
# /wiki/Earth_to_Ned
# /wiki/Doogie_Kame%C4%81loha,_M.D.
# /wiki/Intertwined_(TV_series)
# /wiki/Cars_on_the_Road
# /wiki/Mater_(Cars)
# /wiki/Radiator_Springs
# /wiki/Cars_Land
# /wiki/Disney_Infinity_(video_game)
# /wiki/Monsters_at_Work
# /wiki/Pixar_Pal-A-Round
# /wiki/Pixar_Short_Films_Collection,_Volume_2
# /wiki/Cars_on_the_Road
# /wiki/Jake_Monaco
# /wiki/IMDb_(identifier)
# /wiki/Amazon_Pharmacy
# /wiki/Amazon_Prime
# /wiki/Amazon_Prime_Pantry
# /wiki/Twitch_(service)
# /wiki/Amazon_Dash#Barcode_scanner
# /wiki/Werner_Vogels
# /wiki/Amazon_Clinic
# /wiki/Amazon_Pay
# /wiki/EServGlobal
# /wiki/Softcard
# /wiki/Google_Ngram_Viewer
# /wiki/2020_Korean_YouTube_backdoor_advertising_controversy
# /wiki/YouTube_Shorts
# /wiki/Tez_(software)
# /wiki/Interbank_network
# /wiki/Diners_Club_International
# /wiki/Interbank_network
# /wiki/Grace_period
# /wiki/Charge_card
# /wiki/Diners_Club
# /wiki/PIN_(debit_card)
# /wiki/Chipknip
# /wiki/EquensWorldline
# /wiki/BeaNet
# /wiki/Van_Lanschot_Kempen
# /wiki/BMO_Capital_Markets
# /wiki/Haitong_Securities
# /wiki/Wells_Fargo
# /wiki/Eric_Schneiderman
# /wiki/Tanya_Selvaratnam
# /wiki/Colombo
# /wiki/ISBN_(identifier)
# /wiki/ISO_10160
# /wiki/ISO_45001
# /wiki/ISO_31-8
# /wiki/ISO_13399
# /wiki/STEP-File
# /wiki/ISO_843
# /wiki/ISO_7001
# /wiki/International_Standard_Identifier_for_Libraries_and_Related_Organizations
# /wiki/PDF/VT
# /wiki/ECMAScript
# /wiki/VXA
# /wiki/Helical_scan
# /wiki/MicroP2
# /wiki/Cartrivision
# /wiki/D-VHS
# /wiki/Hard_drive
# /wiki/Clustered_file_system
# /wiki/Filesystem-level_encryption
# /wiki/Files-11
# /wiki/SquashFS
# /wiki/Bcachefs
# /wiki/ExFAT
# /wiki/Windows_Ink
# /wiki/Microsoft_Windows_library_files
# /wiki/ISBN_(identifier)
# /wiki/ISO_3307
# /wiki/RELAX_NG
# /wiki/ISO_2848
# /wiki/STEP-NC
# /wiki/ISO/IEC_27006
# /wiki/ISO/IEC_18014
# /wiki/MPEG-4
# /wiki/ISO_5426
# /wiki/Shift_out
# /wiki/Box-drawing_characters
# /wiki/%F0%9F%AC%9C
# /wiki/Unicode_block
# /wiki/Lontara_script
# /wiki/Ulu_scripts
# /wiki/Javanese_script
# /wiki/Bamum_script
# /wiki/Diacritic
# /wiki/%C4%B0
# /wiki/I
# /wiki/N
# /wiki/Unified_English_Braille
# /wiki/Nemeth_Braille
# /wiki/Arabic_Braille
# /wiki/Yodh#Arabic_yāʾ
# /wiki/Teth
# /wiki/Quranic_Arabic_Corpus
# /wiki/Arabic_keyboard
# /wiki/Islamic_calligraphy
# /wiki/Jama%27at_Khana
# /wiki/Taqiyah_(cap)
# /wiki/Jamawar
# /wiki/Pathin
# /wiki/Khalat
# /wiki/Dumdyam
# /wiki/Kho_(costume)
# /wiki/Apron
# /wiki/Trousers
# /wiki/Persians
# /wiki/Ibn_Battuta
# /wiki/JSTOR_(identifier)
# /wiki/Full-text_search
# /wiki/Basis_database
# /wiki/Thesaurus
# /wiki/Encyclopedia
# /wiki/World_Book
# /wiki/NetJets
# /wiki/IATA_airline_designator
# /wiki/Call_signs_in_Barbados
# /wiki/Call_signs_in_the_United_Kingdom
# /wiki/Ascension_Island
# /wiki/Belarus
# /wiki/Polish_people
# /wiki/Polish_Brazilians
# /wiki/Portuguese_language
# /wiki/Portuguese-based_creole_languages
# /wiki/Dili
# /wiki/Maluku_(province)
# /wiki/Islam
# /wiki/Islamist
# /wiki/David_Hume
# /wiki/Robert_Filmer
# /wiki/Alexis_de_Tocqueville
# /wiki/Liberalism_in_Australia
# /wiki/Richard_Marles
# /wiki/1982_Australian_Labor_Party_leadership_spill
# /wiki/Chris_Watson
# /wiki/Museum_of_Australian_Democracy
# /wiki/Captain_James_Cook_Memorial
# /wiki/Blundells_Cottage
# /wiki/Australian_National_University
# /wiki/University_of_Tasmania
# /wiki/Visitor
# /wiki/Rector_(academia)#United_States
# /wiki/Perak
# /wiki/Straits_Settlements
# /wiki/Water_supply_and_sanitation_in_Malaysia
# /wiki/Agriculture_in_Malaysia
# /wiki/Religion_in_Malaysia
# /wiki/Tengku_Ampuan_Afzan_Mosque
# /wiki/Seremban_Jamek_Mosque
# /wiki/Putra_Mosque
# /wiki/Saidina_Umar_Al_Khattab_Mosque
# /wiki/Senai_Airport_Mosque
# /wiki/Alaeddin_Mosque_(Jugra,_Malaysia)
# /wiki/Sultan_Ibrahim_Mosque
# /wiki/Mosque
# /wiki/Qa%27a_(room)
# /wiki/Girih
# /wiki/Azizos
# /wiki/Julian_(emperor)
# /wiki/The_Death_of_the_Gods
# /wiki/Restoration_of_paganism_from_Julian_until_Valens
# /wiki/Julian_Romance
# /wiki/The_Dragon_Waiting
# /wiki/Worship_of_the_Gods
# /wiki/Battle_of_Durocortorum
# /wiki/Battle_of_Strasbourg
# /wiki/Julian_(novel)
# /wiki/Libanius
# /wiki/Turkey
# /wiki/Monaco
# /wiki/Le_Portier
# /wiki/La_Condamine
# /wiki/Middle_Ages
# /wiki/Zoroastrianism
# /wiki/Thracian_religion
# /wiki/Nike_(mythology)
# /wiki/Perses_(Titan)
# /wiki/Animal_sacrifice#Ancient_Greece
# /wiki/Cryopreservation
# /wiki/SCID_mice
# /wiki/IL2RG
# /wiki/TNFRSF14
# /wiki/PMID_(identifier)
# /wiki/PMC_(identifier)
# /wiki/NIH_Public_Access_Policy
# /wiki/Open_access_in_Canada
# /wiki/Transportation_in_Canada
# /wiki/Tram
# /wiki/Sunshine_Coast_Light_Rail
# /wiki/Northern_Busway,_Brisbane
# /wiki/Mater_Hill_busway_station
# /wiki/Griffith_University_busway_station
# /wiki/Rochedale_busway_station
# /wiki/Buranda_busway_station
# /wiki/Langlands_Park_busway_station
# /wiki/Translink_(Queensland)
# /wiki/University_of_the_Sunshine_Coast_bus_station
# /wiki/Buranda_busway_station
# /wiki/Langlands_Park_busway_station
# /wiki/UQ_Lakes_busway_station
# /wiki/Eastern_Busway
# /wiki/Clarks_Logan_City_Bus_Service
# /wiki/Cultural_Centre_busway_station
# /wiki/Holland_Park,_Queensland
# /wiki/Hendra,_Queensland
# /wiki/Upper_Kedron,_Queensland
# /wiki/2011_Australian_census
# /wiki/ISBN_(identifier)
# /wiki/ISO_10303
# /wiki/ISO/IEC_15504
# /wiki/ISO_10161
# /wiki/ISO_639
# /wiki/ISO/IEC_17025
# /wiki/ISO_15924
# /wiki/Palmyrene_alphabet
# /wiki/Woleai_script
# /wiki/Denglisch
# /wiki/Malay_trade_and_creole_languages#Baba_Malay
# /wiki/Bukar%E2%80%93Sadong_language
# /wiki/Masimasi_language
# /wiki/Pohnpeian_language
# /wiki/Dusun_Witu_language
# /wiki/Lara%27_language
# /wiki/Unubahe_language
# /wiki/Babar_languages
# /wiki/Asilulu_language
# /wiki/Tombulu_language
# /wiki/Tonsawang_language
# /wiki/Solong_language
# /wiki/Andio_language
# /wiki/Kendayan_language
# /wiki/Sian_language
# /wiki/Halmahera_Sea_languages
# /wiki/Semandang_language
# /wiki/Tobian_language
# /wiki/Tuwali_language
# /wiki/Saluan_language
# /wiki/Bambam_language
# /wiki/Kayan%E2%80%93Murik_languages
# /wiki/Tongic_languages
# /wiki/Piu_language
# /wiki/Patpatar_language
# /wiki/Bilba_language
# /wiki/Nakai_language
# /wiki/Pagu_language
# /wiki/Mentawai_language
# /wiki/Karao_language
# /wiki/Cordillera_Administrative_Region
# /wiki/Kabayan,_Benguet
# /wiki/List_of_sovereign_states
# /wiki/Political_divisions_of_the_United_States#States_and_their_subdivisions
# /wiki/Agriculture_commissioner
# /wiki/Florida_Department_of_Agriculture_and_Consumer_Services
# /wiki/Government_of_Florida
# /wiki/East_Florida
# /wiki/Lancaster_House_Agreement
# /wiki/The_Christian_Science_Monitor
# /wiki/Christian_Science_(book)
# /wiki/The_Private_History_of_a_Campaign_That_Failed
# /wiki/A_Dog%27s_Tale
# /wiki/Letters_from_the_Earth
# /wiki/A_Double_Barrelled_Detective_Story
# /wiki/Sherlock_Holmes_and_the_Shadwell_Shadows
# /wiki/Solar_Pons
# /wiki/The_Night_Side
# /wiki/Some_Notes_on_H._P._Lovecraft
# /wiki/The_Memoirs_of_Solar_Pons
# /wiki/Someone_in_the_Dark
# /wiki/August_Derleth
# /wiki/Tsathoggua
# /wiki/A_Night_in_Maln%C3%A9ant
# /wiki/Clark_Ashton_Smith_bibliography
# /wiki/Out_of_Space_and_Time
# /wiki/Clark_Ashton_Smith_bibliography
# /wiki/Genius_Loci_and_Other_Tales
# /wiki/Short_story
# /wiki/A_Legend_of_Old_Egypt
# /wiki/The_Barrel_Organ
# /wiki/Warsaw_Old_Town
# /wiki/Hugo_Ko%C5%82%C5%82%C4%85taj
# /wiki/Historian
# /wiki/ISBN_(identifier)
# /wiki/Lexical_Markup_Framework
# /wiki/Fiber_Distributed_Data_Interface
# /wiki/Hot_shoe
# /wiki/Color_space
# /wiki/Rec._601
# /wiki/Primary_color
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_27002
# /wiki/ISO_15919
# /wiki/ISO/IEC_8859
# /wiki/Gje
# /wiki/Yus
# /wiki/Romanian_language
# /wiki/Gallo-Italic_languages
# /wiki/Piedmontese_language
# /wiki/Uruguayan_Portuguese
# /wiki/Arabic
# /wiki/Ajami_script
# /wiki/Maore_dialect
# /wiki/Mayotte
# /wiki/European_Union
# ...
# /wiki/Hield
# /wiki/Buddy_Hield
# /wiki/Shane_Battier
# /wiki/Shelden_Williams
# /wiki/Free_throw
# /wiki/Jump_shot_(basketball)
# /wiki/Flagrant_foul
# /wiki/Buzzer_beater
# /wiki/Boston_Celtics
# /wiki/John_Havlicek
# /wiki/Charles_Barkley
# /wiki/Tim_Duncan
# /wiki/Marc_Jackson
# /wiki/2005%E2%80%9306_NBA_season
# /wiki/Andrew_Bogut
# /wiki/Clifton_McNeely
# /wiki/Ben_Simmons
# /wiki/Tiffany_Jackson_(basketball)
# /wiki/University_of_Texas_at_Austin
# /wiki/Windsor_Park,_Austin,_Texas
# /wiki/Round_Rock_Express
# /wiki/Texas_Capitol_View_Corridors
# /wiki/Texas_School_for_the_Deaf
# /wiki/Cheyenne-Eagle_Butte_School
# /wiki/Oregon_School_for_the_Deaf
# /wiki/Kaibeto_Boarding_School
# /wiki/Red_Valley/Cove_High_School
# /wiki/Chapter_house_(Navajo_Nation)
# /wiki/Wayback_Machine
# /wiki/Democracy_Now!#Democracy_Now!_collection_at_the_Internet_Archive
# /wiki/Dershowitz%E2%80%93Finkelstein_affair
# /wiki/Anti-Semitism
# /wiki/Ethnic_conflict
# /wiki/Nepotism
# /wiki/Boris_Johnson
# /wiki/1989_Conservative_Party_leadership_election
# /wiki/The_Crown_(season_4)
# /wiki/Playhouse_90
# /wiki/ER_(season_2)
# /wiki/USA_Today
# /wiki/The_Daily_Progress
# /wiki/The_News_Virginian
# /wiki/Winston-Salem_Journal
# /wiki/Brooklyn_Eagle
# /wiki/St._Louis_Post-Dispatch
# /wiki/S._Carlisle_Martin
# /wiki/Missouri_Meerschaum
# /wiki/Smoking_pipe_(tobacco)
# /wiki/Catlinite
# /wiki/Tobacco_pipe
# /wiki/Dottle
# /wiki/Sherlock_Holmes
# /wiki/Pablo_de_Sarasate
# /wiki/Spanish_Dances
# /wiki/Saint_Petersburg
# /wiki/Road_of_Life
# /wiki/Steam_locomotive
# /wiki/Chemins_de_Fer_de_l%27Ouest
# /wiki/Gare_de_Dieppe
# /wiki/Rouen-Rive-Droite_station
# /wiki/TGV
# /wiki/Geneva
# /wiki/Historical_Dictionary_of_Switzerland
# /wiki/ISBN_(identifier)
# /wiki/Check_digit
# /wiki/International_Bank_Account_Number
# /wiki/Equal-loudness_contour
# /wiki/ISO_639-1
# /wiki/ISO_37001
# /wiki/Vicat_softening_point
# /wiki/ISO_690
# /wiki/ISO_22000
# /wiki/British_Standard_Pipe
# /wiki/ISO_3166-2
# /wiki/Republic_of_the_Congo
# /wiki/Central_Africa
# /wiki/Middle_Egypt
# /wiki/Giza
# /wiki/Rashidun_Caliphate
# /wiki/Hadith
# /wiki/Islam_and_Mormonism
# /wiki/Commentary_(philology)
# /wiki/Close_reading
# /wiki/Phonemic_awareness
# /wiki/Literacy
# /wiki/Salvador,_Bahia
# /wiki/Pelourinho
# /wiki/Afro-Brazilians
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/List_of_scientific_journals
# /wiki/ORCID
# /wiki/Alphanumeric
# /wiki/Alphabetical
# /wiki/Pinakes
# /wiki/Melvil_Dewey
# /wiki/Choice_Reviews
# /wiki/Middletown,_Connecticut
# /wiki/Connecticut#Education
# /wiki/New_Canaan,_Connecticut
# /wiki/Torrington,_Connecticut
# /wiki/Downtown_Torrington
# /wiki/National_Register_of_Historic_Places_listings_in_Idaho
# /wiki/Canyon_County,_Idaho
# /wiki/Coeur_d%27Alene,_Idaho
# /wiki/Fremont_County,_Idaho
# /wiki/Adams_County,_Idaho
# /wiki/National_Register_of_Historic_Places_listings_in_Madison_County,_Idaho
# /wiki/National_Register_of_Historic_Places_listings_in_Clearwater_County,_Idaho
# /wiki/Contributing_property
# /wiki/National_Register_of_Historic_Places_listings_in_California
# /wiki/Music_of_California
# /wiki/X_(American_band)
# /wiki/Woody_Guthrie
# /wiki/Bruce_Springsteen
# /wiki/Point_Blank_(Bruce_Springsteen_song)
# /wiki/Spirit_in_the_Night
# /wiki/Record_World
# /wiki/Casablanca_Records
# /wiki/Columbia_Pictures
# /wiki/Sony_Lissa
# /wiki/Sony_Pictures
# /wiki/Flower_Films
# /wiki/Cinergi_Pictures
# /wiki/Fox_Networks_Group
# /wiki/Fox_Action_Movies
# /wiki/Fox_Reality_Channel
# /wiki/DirecTV
# /wiki/Hulu
# /wiki/Tvigle
# /wiki/Sky_Deutschland#Defunct
# /wiki/Lifetime_(British_and_Irish_TV_channel)
# /wiki/BT_TV
# /wiki/Animal_Planet_(British_TV_channel)
# /wiki/Dplay
# /wiki/Streaming_media
# /wiki/List_of_viral_music_videos
# /wiki/Canada
# /wiki/Kingdom_of_Bavaria
# /wiki/Saxe-Gotha-Altenburg
# /wiki/Germany
# /wiki/European_Bronze_Age
# /wiki/List_of_European_folk_music_traditions
# /wiki/Kingosalmar
# /wiki/Konrad_Hubert
# /wiki/Basel
# /wiki/Oberrhein
# /wiki/Strasbourg
# /wiki/Gundershoffen
# /wiki/Communes_of_France
# /wiki/Marne_(department)
# /wiki/Gers
# /wiki/Prefectures_in_France
# /wiki/French_language
# /wiki/Middle_French
# /wiki/Walloon_language
# /wiki/Low_German
# /wiki/Verner%27s_law
# /wiki/Transylvanian_Saxon_dialect
# /wiki/Hungarian_language
# /wiki/Periphrasis
# /wiki/Ghil%27ad_Zuckermann
# /wiki/English_language
# /wiki/Walser_German
# /wiki/Vastese
# /wiki/Catalan_language
# /wiki/County_of_Barcelona
# /wiki/War_of_the_Spanish_Succession
# /wiki/Battle_of_Almansa
# /wiki/Region_of_Murcia
# /wiki/Cant%C3%B3n_de_Cartagena
# /wiki/Cartagena_Naval_Base
# /wiki/Mediterranean_Sea
# /wiki/Montenegro
# /wiki/Montenegrin_Orthodox_Church
# /wiki/Jesus_Prayer
# /wiki/Autocephaly
# /wiki/Episcopal_polity#Eastern_Orthodox_Church
# /wiki/Gallican_Rite
# /wiki/Veneration_of_Mary_in_the_Catholic_Church
# /wiki/Roman_Curia
# /wiki/Alphonsian_Academy
# /wiki/John_Clayton_Nienstedt
# /wiki/Bernard_Hebda
# /wiki/Patrick_R._Cooney
# /wiki/Monsignor
# /wiki/ISBN_(identifier)
# /wiki/International_Standard_Text_Code
# /wiki/Open_Document_Architecture
# /wiki/List_of_ISO_romanizations
# /wiki/ISO_233
# /wiki/ISO_3166-2
# /wiki/United_Nations
# /wiki/ISSN_(identifier)
# /wiki/List_of_ISO_romanizations
# /wiki/ISO_233
# /wiki/ISO_22000
# /wiki/ISO_10303-21
# /wiki/ISO_2852
# /wiki/ISO_15022
# /wiki/ISO/IEC_9126
# /wiki/ISO_14617
# /wiki/Object_Constraint_Language
# /wiki/ISO_639-3
# /wiki/Linguist_List
# /wiki/Natural_Language_Processing
# /wiki/ISBN_(identifier)
# /wiki/List_of_IEC_standards
# /wiki/International_Standard_Recording_Code
# /wiki/ISO/IEC_27002
# /wiki/ISO/IEC_7064
# /wiki/ISO/IEC_8859-3
# /wiki/Code_page_1019
# /wiki/Equal_sign
# /wiki/JavaScript
# /wiki/Naver_Whale
# /wiki/Gecko_(software)
# /wiki/Trident_(software)
# /wiki/Channel_Definition_Format
# /wiki/Internet_Explorer_Administration_Kit
# /wiki/Installable_File_System
# /wiki/Interix
# /wiki/Driver_Verifier
# /wiki/NTBackup
# /wiki/Cmd.exe
# /wiki/POPD
# /wiki/Env
# /wiki/Man_page
# /wiki/Main_page
# /wiki/Yevgeny_Prigozhin
# /wiki/Disinformation_in_the_Russian_invasion_of_Ukraine
# /wiki/Hero_City_of_Ukraine
# /wiki/Kharkiv_government_building_airstrike
# /wiki/Sweden%E2%80%93NATO_relations
# /wiki/Spain
# /wiki/Europe
# /wiki/Anabaptists
# /wiki/G._P._Putnam%27s_Sons
# /wiki/Price_Stern_Sloan
# /wiki/Alfaguara
# /wiki/The_Bodley_Head
# /wiki/Bantam_Books
# /wiki/Bantam_Press
# /wiki/RTL_II_(Hungary)
# /wiki/MCM_(TV_channel)
# /wiki/Paris_Premi%C3%A8re
# /wiki/Tiji
# /wiki/RTL_II_(Hungary)
# /wiki/RTL_(Hungarian_TV_channel)
# /wiki/E!
# /wiki/Hillsong_Channel
# /wiki/Theater_Television_Network
# /wiki/Television_broadcasting
# /wiki/Noovo
# /wiki/RDS_Info
# /wiki/Noovo
# /wiki/CTV_2_Atlantic
# /wiki/Global_Television_Network
# /wiki/Reality_series
# /wiki/Hardcore_Pawn
# /wiki/Branson_Famous
# /wiki/Reality_television
# /wiki/Storage_Wars
# /wiki/Casting_(performing_arts)#Cast_types
# /wiki/Clapper_loader
# /wiki/Fujifilm
# /wiki/Instant_film
# /wiki/Film_developing
# /wiki/Photography_in_Taiwan
# /wiki/Philosophy_in_Taiwan
# /wiki/Two_Chinas
# /wiki/Taipei
# /wiki/Sinhua_District
# /wiki/Guishan_District
# /wiki/Beitou_District
# /wiki/Sanmin_District
# /wiki/Kaohsiung
# /wiki/Global_city
# /wiki/Capital_city
# /wiki/Overseas_region
# /wiki/Territory
# /wiki/Federal_territory
# /wiki/Seni%C5%ABnija
# /wiki/Administrative_divisions_of_Lithuania
# /wiki/List_of_cities_in_Lithuania
# /wiki/Bir%C5%BEai
# /wiki/Polish_language
# /wiki/Attributive_adjective
# /wiki/Part_of_speech#History
# /wiki/Pronoun
# /wiki/Personal_pronoun
# /wiki/Object_(grammar)
# /wiki/Systemic_functional_linguistics
# /wiki/Historical_linguistics
# /wiki/Aviation_archaeology
# /wiki/Greenland
# /wiki/Haiti
# /wiki/Cit%C3%A9_Soleil
# /wiki/Anse-d%27Hainault
# /wiki/C%C3%B4tes-de-Fer
# /wiki/Verrettes
# /wiki/Mombin-Crochu
# /wiki/Petite-Rivi%C3%A8re-de-Nippes
# /wiki/Perches,_Haiti
# /wiki/Sainte-Suzanne,_Haiti
# /wiki/Ouest_(department)
# /wiki/J%C3%A9r%C3%A9mie_Arrondissement
# /wiki/Delmas,_Ouest
# /wiki/Haiti
# /wiki/Human_rights_abuse
# /wiki/Model_United_Nations
# /wiki/Military_Staff_Committee
# /wiki/World_Federation_of_Engineering_Organizations
# /wiki/United_Nations_High_Commissioner_for_Refugees
# /wiki/International_Bank_for_Reconstruction_and_Development
# /wiki/Alfred_W._Crosby
# /wiki/Washington_State_University
# /wiki/Western_United_States
# /wiki/Treaty_of_Cession_of_Tutuila
# /wiki/List_of_bays_in_Samoa
# /wiki/Samoan_culture
# /wiki/Church_(building)
# /wiki/Sacral_architecture
# /wiki/Tower
# /wiki/Express_Lift_Tower
# /wiki/Otis_Elevator_Company
# /wiki/The_Wall_Street_Journal
# /wiki/Conservatism_in_the_United_States
# /wiki/Conservatism_in_North_America#Cuba
# /wiki/Abortion
# /wiki/OCLC_(identifier)
# /wiki/Integrated_library_system
# /wiki/Roomba
# /wiki/IRobot_Warrior
# /wiki/PackBot
# /wiki/Doi_(identifier)
# /wiki/ISO_11783
# /wiki/ISO_843
# /wiki/TIFF/EP
# /wiki/List_of_ISO_standards
# /wiki/ISO_13485
# /wiki/POSIX
# /wiki/IEEE_802.11b-1999
# /wiki/SystemVerilog
# /wiki/Nios_embedded_processor
# /wiki/VHDL
# /wiki/IEEE_754
# /wiki/ANSI_C
# /wiki/Gets()
# /wiki/Printf_format_string
# /wiki/Raku_(programming_language)
# /wiki/Libera_Chat
# /wiki/Bersirc
# /wiki/WeeChat
# /wiki/EFnet
# /wiki/ISBN_(identifier)
# /wiki/TIFF/EP
# /wiki/ISO_5428
# /wiki/Wang_International_Standard_Code_for_Information_Interchange
# /wiki/Code_page_737
# /wiki/Code_page_1018
# /wiki/Group_separator
# /wiki/ISO_5426
# /wiki/Mac_OS_Turkish_encoding
# /wiki/SQUOZE
# /wiki/IBM_7094
# /wiki/ISBN_(identifier)
# /wiki/Isofix
# /wiki/ISO-8859-8-I
# /wiki/ISO/IEC_19794-5
# /wiki/ISO/IEC_21827
# /wiki/ISO_7736
# /wiki/Romanization_of_Armenian
# /wiki/ISO_5964
# /wiki/ISO/IEC_20000
# /wiki/MP4_file_format
# /wiki/Software_maintenance
# /wiki/International_Standard_Text_Code
# /wiki/Shock-resistant_watch#ISO_1413_shock-resistant_standard
# /wiki/ISO_19600
# /wiki/ISO_31-3
# /wiki/ISO_18245
# /wiki/ISO_639-5
# /wiki/Film_speed
# /wiki/Fireworks_photography
# /wiki/Afocal_photography
# /wiki/Conservation_and_restoration_of_photographs
# /wiki/Contre-jour
# /wiki/Color_photography
# /wiki/Diagonal_method
# /wiki/Intentional_camera_movement
# /wiki/Tilt%E2%80%93shift_photography
# /wiki/Nikon_F_mount#Perspective_control_.28PC.29_lenses
# /wiki/Nikon_D3200
# /wiki/Nikon_D7200
# /wiki/Autofocus
# /wiki/Nokia_Lumia_1020
# /wiki/Enhanced_Data_Rates_for_GSM_Evolution
# /wiki/E-UTRA
# /wiki/Mobitex
# /wiki/High_Speed_Packet_Access
# /wiki/Hybrid_automatic_repeat_request
# /wiki/HSUPA
# /wiki/Evolved_High_Speed_Packet_Access#Dual-Carrier_HSDPA_(DC-HSDPA)
# /wiki/LTE_Advanced_Pro
# /wiki/List_of_mobile_phone_generations
# /wiki/Mobile_phone_feature
# /wiki/Ringtone
# /wiki/Mobile_operating_system
# /wiki/IPad_Mini_4
# /wiki/MacBook_Pro_(Intel-based)
# /wiki/Dual-layer_DVD
# /wiki/Optical_disc_drive
# /wiki/Advanced_Technology_Attachment
# /wiki/Parallel_SCSI
# /wiki/Multibus
# /wiki/Institute_of_Electrical_and_Electronics_Engineers
# /wiki/Institute_of_Radio_Engineers
# /wiki/Radio
# /wiki/VLBI
# /wiki/Lunar_Flashlight
# /wiki/LunIR
# /wiki/Yaogan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c0a283baed49> in <module>
#      16     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      17     print(newArticle)
# ---> 18     links = getLinks(newArticle)
#
# <ipython-input-1-c0a283baed49> in getLinks(articleUrl)
#       7 random.seed(datetime.datetime.now())
#       8 def getLinks(articleUrl):
# ----> 9     html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
#      10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a',
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Crawling an Entire Site

# %%
# To avoid crawling the same page twice, it is extremely important that all internal links
# discovered are formatted consistently, and kept in a running set for easy lookups,
# while the program is running. A set is similar to a list, but elements do not have a
# specific order, and only unique elements will be stored, which is ideal for our needs

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

#scraper here is only limited to article pages i.e. begins with /wiki/ regardless
#of where they are on the page, and regardless of whether they contain colons
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:Search
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Special:WhatLinksHere/User_talk:188.214.12.120
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-6dac710dd81c> in <module>
#      21                 pages.add(newPage)
#      22                 getLinks(newPage)
# ---> 23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      20                 print(newPage)
#      21                 pages.add(newPage)
# ---> 22                 getLinks(newPage)
#      23 getLinks('')
#
# <ipython-input-5-6dac710dd81c> in getLinks(pageUrl)
#      11 def getLinks(pageUrl):
#      12     global pages
# ---> 13     html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
#      14     bs = BeautifulSoup(html, 'html.parser')
#      15     for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# Initially, getLinks is called with an empty URL. This is translated as “the front page
# of Wikipedia” as soon as the empty URL is prepended with http://en.wikipe
# dia.org inside the function. Then, each link on the first page is iterated through and
# a check is made to see whether it is in the global set of pages (a set of pages that the
# script has encountered already). If not, it is added to the list, printed to the screen,
# and the getLinks function is called recursively on it.

# %%
# Collecting Data Across an Entire Site

# Let’s look at how to build a scraper that collects the title, the first para‐
# graph of content, and the link to edit the page (if available).

#commonalities in wiki web pages: 

# All titles (on all pages, regardless of their status as an article page, an edit history
# page, or any other page) have titles under h1 → span tags, and these are the only h1 tags on the page.

# As mentioned before, all body text lives under the div#bodyContent tag. How‐
# ever, if you want to get more specific and access just the first paragraph of text,
# you might be better off using div#mw-content-text → p (selecting the first para‐
# graph tag only)

# Edit links occur only on article pages. If they occur, they will be found in the li#ca-edit tag, under li#ca-edit → span → a.

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl): #get each link in article
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text()) #find titles
        print(bs.find(id ='mw-content-text').find_all('p')[0]) #find text following title up until next link
        print(bs.find(id='ca-edit').find('span') #find edit links
            .find('a').attrs['href'])
        
    except AttributeError:
        print('This page is missing something! Continuing.')

    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20) 
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# each print statement is arranged in the order that it is likeliest to appear on the site. That is, the
# h1 title tag appears on every page, The text content appears on most pages (except for file pages), so that
# is the second piece of data retrieved, The Edit button appears only on pages in which
# both titles and text content already exist, but it does not appear on all of those pages
# Out:
# Main Page
# <p><b><a href="/wiki/Thomas_A._Spragens" title="Thomas A. Spragens">Thomas A. Spragens</a></b> (1917–2006) was an American administrator who was the 17th president of <a href="/wiki/Centre_College" title="Centre College">Centre College</a> in <a href="/wiki/Danville,_Kentucky" title="Danville, Kentucky">Danville, Kentucky</a>. A graduate of the <a href="/wiki/University_of_Kentucky" title="University of Kentucky">University of Kentucky</a>, Spragens worked for the <a href="/wiki/Government_of_Kentucky" title="Government of Kentucky">state</a> and <a href="/wiki/Federal_government_of_the_United_States" title="Federal government of the United States">federal government</a> early in his career before joining the staff at <a href="/wiki/Stanford_University" title="Stanford University">Stanford University</a> as a presidential advisor. He was the president of <a href="/wiki/Stephens_College" title="Stephens College">Stephens College</a> in <a href="/wiki/Columbia,_Missouri" title="Columbia, Missouri">Columbia, Missouri</a>, for a five-year term, and left Stephens for Centre in 1957. He was an effective fundraiser and was instrumental in the school's <a href="/wiki/Racial_integration" title="Racial integration">integration</a>; Centre admitted its first black student in 1962 and hired its first black faculty member in 1971. While in office, he helped to facilitate the founding of what is now the <a href="/wiki/Southern_Collegiate_Athletic_Conference" title="Southern Collegiate Athletic Conference">Southern Collegiate Athletic Conference</a>, and he attended the <a href="/wiki/1968_Democratic_National_Convention" title="1968 Democratic National Convention">1968 Democratic National Convention</a> as a delegate to support Senator <a href="/wiki/Eugene_McCarthy" title="Eugene McCarthy">Eugene McCarthy</a>. He resigned in 1981, at which point Centre's enrollment and faculty numbers had both nearly doubled and its <a href="/wiki/Financial_endowment" title="Financial endowment">endowment</a> had grown. (<b><a href="/wiki/Thomas_A._Spragens" title="Thomas A. Spragens">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Main_Page
# Main Page
# <p><b><a href="/wiki/Thomas_A._Spragens" title="Thomas A. Spragens">Thomas A. Spragens</a></b> (1917–2006) was an American administrator who was the 17th president of <a href="/wiki/Centre_College" title="Centre College">Centre College</a> in <a href="/wiki/Danville,_Kentucky" title="Danville, Kentucky">Danville, Kentucky</a>. A graduate of the <a href="/wiki/University_of_Kentucky" title="University of Kentucky">University of Kentucky</a>, Spragens worked for the <a href="/wiki/Government_of_Kentucky" title="Government of Kentucky">state</a> and <a href="/wiki/Federal_government_of_the_United_States" title="Federal government of the United States">federal government</a> early in his career before joining the staff at <a href="/wiki/Stanford_University" title="Stanford University">Stanford University</a> as a presidential advisor. He was the president of <a href="/wiki/Stephens_College" title="Stephens College">Stephens College</a> in <a href="/wiki/Columbia,_Missouri" title="Columbia, Missouri">Columbia, Missouri</a>, for a five-year term, and left Stephens for Centre in 1957. He was an effective fundraiser and was instrumental in the school's <a href="/wiki/Racial_integration" title="Racial integration">integration</a>; Centre admitted its first black student in 1962 and hired its first black faculty member in 1971. While in office, he helped to facilitate the founding of what is now the <a href="/wiki/Southern_Collegiate_Athletic_Conference" title="Southern Collegiate Athletic Conference">Southern Collegiate Athletic Conference</a>, and he attended the <a href="/wiki/1968_Democratic_National_Convention" title="1968 Democratic National Convention">1968 Democratic National Convention</a> as a delegate to support Senator <a href="/wiki/Eugene_McCarthy" title="Eugene McCarthy">Eugene McCarthy</a>. He resigned in 1981, at which point Centre's enrollment and faculty numbers had both nearly doubled and its <a href="/wiki/Financial_endowment" title="Financial endowment">endowment</a> had grown. (<b><a href="/wiki/Thomas_A._Spragens" title="Thomas A. Spragens">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Contents
# Wikipedia:Contents
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Portal:Current_events
# Portal:Current events
# <p><span class="noprint" id="coordinates"><a href="/wiki/Portal:Current_events/Edit_instructions" title="Portal:Current events/Edit instructions">Edit instructions</a></span>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Random
# Shonagh Daly
# <p>
# <b>Shonagh Daly</b> (born 1980 in <a href="/wiki/Castletroy" title="Castletroy">Castletroy</a>, Co. Limerick) is an Irish singer and musical performer
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:About
# Wikipedia:About
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Contents
# Help:Contents
# <p><br/>
# <style data-mw-deduplicate="TemplateStyles:r1012508797">.mw-parser-output .helpContents-wrapper{display:flex;flex-wrap:wrap}.mw-parser-output .helpContents-header{flex:1 0 100%;padding-bottom:1em;border-bottom:1px solid #a2a9b1;text-align:center}.mw-parser-output .helpContents-section{position:relative;flex:1 0 50%;min-width:380px;box-sizing:border-box;margin:1em 0;padding-left:30px;padding-right:20px}.mw-parser-output .helpContents-section h2{font-size:21px;padding:0;margin-top:1em;margin-bottom:0.25em;line-height:1.5}.mw-parser-output .helpContents-section ul{margin-left:0;padding-left:0}.mw-parser-output .helpContents-icon{position:absolute;top:25px;left:0;line-height:1;opacity:0.7}.mw-parser-output .helpContents-additional-search{text-align:center;margin-bottom:1em}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Introduction
# Help:Introduction
# <p><style data-mw-deduplicate="TemplateStyles:r1156591132">.mw-parser-output .introtosingle__main{position:relative;box-sizing:border-box;box-shadow:2px 2px 2px #CCC;max-width:100%;overflow:hidden;border:1px solid black;margin:auto;padding-bottom:20px}.mw-parser-output .introtosingle__main p{margin-bottom:2.0em}.mw-parser-output .introtosingle__main-withbackground{background-image:url("https://upload.wikimedia.org/wikipedia/commons/d/d9/Wikipedia-logo-v2-o10.svg");background-position:center -500px;background-repeat:no-repeat;background-size:auto 150%}.mw-parser-output .introtosingle__main-title{font-size:250%;line-height:150%;background:#777;color:#FFF;text-align:center;align-items:center;justify-content:center}.mw-parser-output .introtosingle__lead{background-color:#EEE;background-color:rgba(221,221,221,0.5);padding:30px 60px;margin-bottom:15px}.mw-parser-output .introtosingle__base{box-sizing:border-box;max-width:1100px;min-height:55px;margin:auto;padding:5px 20px;font-size:1.1em;background:#EEE;border:1px solid lightgrey}.mw-parser-output .introtosingle__columns{display:flex;flex-direction:row;flex-wrap:wrap-reverse;justify-content:center}.mw-parser-output .introtosingle__columns-left,.mw-parser-output .introtosingle__columns-left-noborder,.mw-parser-output .introtosingle__columns-right{display:inline-block;flex:1 1 0;align-self:flex-end;vertical-align:top;min-width:200px;max-width:300px;padding:10px}.mw-parser-output .introtosingle__columns-left{text-align:right;justify-content:right;border-right:solid 1px #ddd}.mw-parser-output .introtosingle__columns-left-noborder{text-align:right;justify-content:right}.mw-parser-output .introtosingle__columns-right{text-align:left;justify-content:left}@media screen and (min-width:1101px){.mw-parser-output .introtosingle__main{max-width:1100px}}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Community_portal
# Wikipedia:Community portal
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:RecentChanges
# Recent changes
# <p>This is a list of recent changes to Wikipedia.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# Wikipedia:File upload wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Search
# Search
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-33cca169fc0f> in <module>
#      43                 pages.add(newPage)
#      44                 getLinks(newPage)
# ---> 45 getLinks('')
#      46
#      47
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      42                 print(newPage)
#      43                 pages.add(newPage)
# ---> 44                 getLinks(newPage)
#      45 getLinks('')
#      46
#
# <ipython-input-7-33cca169fc0f> in getLinks(pageUrl)
#      27     try:
#      28         print(bs.h1.get_text())
# ---> 29         print(bs.find(id ='mw-content-text').find_all('p')[0])
#      30         print(bs.find(id='ca-edit').find('span')
#      31             .find('a').attrs['href'])
#
# IndexError: list index out of range
